# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import re

encoding = "ISO-8859-1"
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /home/eugene/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eugene/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/eugene/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion

# %%
train = pd.read_csv('train_processed.csv', index_col=['id'])
train['search_term'] = train['search_term'].apply(str)
test = pd.read_csv('test_processed.csv', index_col=['id'])
test['search_term'] = test['search_term'].apply(str)

# %%
@np.vectorize
def word_match_std(search_term, text):
    indexes = []
    search_term = search_term.split()
    text = text.split()    
    n = len(text)
    if len(search_term) == 0:
        return 0
    for word in set(search_term):
        if word in text:
            indexes.append(text.index(word))
    if len(indexes) > 0:
        return np.var(indexes)
    else:
        return 0

# %%
train['words_std_title'] = word_match_std(train['search_term'], train['product_title'])
train['words_std_descr'] = word_match_std(train['search_term'], train['descr'])
test['words_std_title'] = word_match_std(test['search_term'], test['product_title'])
test['words_std_descr'] = word_match_std(test['search_term'], test['descr'])

# %%
class cust_regression_vals(BaseEstimator, TransformerMixin):
    def fit(self, x, y=None):
        return self
    def transform(self, train):
        return train[tree_cols].values


class cust_txt_col(BaseEstimator, TransformerMixin):
    def __init__(self, col):
        self.col = col
    def fit(self, x, y=None):
        return self
    def transform(self, dataset):
        return dataset[self.col].apply(str)

tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=30))]))
                    ]
            ))])

clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])

# %%
y = train['relevance'].values

# %%
from lightgbm import LGBMRegressor
params = {
    'n_estimators': [600, 700],
    'num_leaves': [60, 70]
}
gbm = lgb.LGBMRegressor(learning_rate=0.04, colsample_bytree=0.7)
model = GridSearchCV(gbm, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] n_estimators=600, num_leaves=60 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................. n_estimators=600, num_leaves=60, total=  16.8s
# [CV] n_estimators=600, num_leaves=60 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.8s remaining:    0.0s
# [CV] .................. n_estimators=600, num_leaves=60, total=  15.7s
# [CV] n_estimators=600, num_leaves=60 .................................
# [CV] .................. n_estimators=600, num_leaves=60, total=  16.3s
# [CV] n_estimators=600, num_leaves=70 .................................
# [CV] .................. n_estimators=600, num_leaves=70, total=  21.1s
# [CV] n_estimators=600, num_leaves=70 .................................
# [CV] .................. n_estimators=600, num_leaves=70, total=  21.7s
# [CV] n_estimators=600, num_leaves=70 .................................
# [CV] .................. n_estimators=600, num_leaves=70, total=  18.0s
# [CV] n_estimators=700, num_leaves=60 .................................
# [CV] .................. n_estimators=700, num_leaves=60, total=  23.6s
# [CV] n_estimators=700, num_leaves=60 .................................
# [CV] .................. n_estimators=700, num_leaves=60, total=  18.0s
# [CV] n_estimators=700, num_leaves=60 .................................
# [CV] .................. n_estimators=700, num_leaves=60, total=  16.9s
# [CV] n_estimators=700, num_leaves=70 .................................
# [CV] .................. n_estimators=700, num_leaves=70, total=  17.6s
# [CV] n_estimators=700, num_leaves=70 .................................
# [CV] .................. n_estimators=700, num_leaves=70, total=  17.4s
# [CV] n_estimators=700, num_leaves=70 .................................
# [CV] .................. n_estimators=700, num_leaves=70, total=  17.3s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  3.7min finished
#    std_score_time param_n_estimators param_num_leaves  \
# 3        0.003763                700               70
# 2        0.005239                700               60
# 0        0.005139                600               60
# 1        0.009295                600               70
#
#                                     params  split0_test_score  \
# 3  {'n_estimators': 700, 'num_leaves': 70}          -0.213938
# 2  {'n_estimators': 700, 'num_leaves': 60}          -0.214339
# 0  {'n_estimators': 600, 'num_leaves': 60}          -0.214610
# 1  {'n_estimators': 600, 'num_leaves': 70}          -0.214286
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 3          -0.204591          -0.233849        -0.217459        0.012201
# 2          -0.205009          -0.233182        -0.217510        0.011718
# 0          -0.205289          -0.233485        -0.217795        0.011729
# 1          -0.205190          -0.234034        -0.217837        0.012040
#
#    rank_test_score
# 3                1
# 2                2
# 0                3
# 1                4

# %%
X_test = clf.transform(test[use_cols])
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47560

# %%
train['len_title'] = train['product_title'].apply(lambda x: len(x.split()))
train['len_descr'] = train['descr'].apply(lambda x: len(x.split()))
test['len_title'] = test['product_title'].apply(lambda x: len(x.split()))
test['len_descr'] = test['descr'].apply(lambda x: len(x.split()))

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr', 'len_title', 'len_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=30))]))
                    ]
            ))])

clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])

# %%
gbm = lgb.LGBMRegressor(n_estimators=700, num_leaves=70, colsample_bytree=0.7)
params = {
    'learning_rate': [0.03, 0.04]
}
model = GridSearchCV(gbm, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV] learning_rate=0.03 ..............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................... learning_rate=0.03, total=  20.7s
# [CV] learning_rate=0.03 ..............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   20.7s remaining:    0.0s
# [CV] ............................... learning_rate=0.03, total=  29.6s
# [CV] learning_rate=0.03 ..............................................
# [CV] ............................... learning_rate=0.03, total=  29.3s
# [CV] learning_rate=0.04 ..............................................
# [CV] ............................... learning_rate=0.04, total=  27.8s
# [CV] learning_rate=0.04 ..............................................
# [CV] ............................... learning_rate=0.04, total=  26.8s
# [CV] learning_rate=0.04 ..............................................
# [CV] ............................... learning_rate=0.04, total=  30.4s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  2.7min finished
#    std_score_time param_learning_rate                   params  \
# 0        0.052053                0.03  {'learning_rate': 0.03}
# 1        0.016509                0.04  {'learning_rate': 0.04}
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0          -0.213347          -0.204404          -0.232452        -0.216734
# 1          -0.213428          -0.204081          -0.232858        -0.216789
#
#    std_test_score  rank_test_score
# 0        0.011698                1
# 1        0.011986                2

# %%
X_test = clf.transform(test[use_cols])
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47469

# %%
model.best_estimator_.feature_importances_
# Out:
# array([367, 207, 171, 539, 301,  47, 175, 530, 354, 164, 181, 300, 209,
#        291, 303, 264, 232, 208, 212, 201, 221, 164, 262, 205, 242, 172,
#        193, 227, 143, 177, 180, 193, 214, 204, 201, 184, 161, 195, 248,
#        209, 167, 169, 183, 174, 218, 223, 223, 209, 199, 217, 244, 245,
#        191, 209, 211, 199, 209, 177, 223, 200, 212, 211, 199, 244, 223,
#        228, 237, 207, 203, 217, 207, 190, 192, 237, 233, 200, 267, 284,
#        215, 215, 245, 197, 241, 206, 238, 230, 264, 282, 249, 249, 192,
#        279, 255, 226, 188, 188, 170, 164, 176, 154, 187, 129, 157, 185,
#        160, 170, 138, 163, 153, 137, 156, 184, 148, 176, 179, 125, 147,
#        141, 175, 121, 190, 193, 151, 151, 158, 166, 152, 179, 187, 174,
#        197, 156, 193, 155, 148, 173, 208, 150, 150, 191, 185, 170, 184,
#        194, 139, 182, 186, 172, 154, 169, 198, 286, 233, 180, 162, 185,
#        189, 198, 182, 200, 181, 175, 172, 192, 206, 184, 180, 228, 184,
#        252, 188, 188, 214, 291, 158, 196, 138, 177, 142, 177, 190, 146,
#        160, 159, 181, 197, 165, 171, 158, 163, 167, 199, 184, 171, 172,
#        187, 152, 187, 197, 163, 177, 181, 193, 199, 172, 174, 180, 177,
#        190, 161, 182, 158, 161, 164, 165, 189, 233, 179, 193, 163, 237,
#        172, 236, 200, 186, 186, 181, 176, 194, 171, 203, 186, 154, 187,
#         86,  78,  70, 144,  80,  70,  90,  69,  66,  80,  64,  92,  81,
#         81,  79,  63,  76,  96,  72,  79, 102,  54,  73,  82,  53,  93,
#         59,  86,  74])

# %%
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=20))]))
                    ]
            ))])

# %%
clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])

# %%
gbm = lgb.LGBMRegressor(learning_rate=0.03, n_estimators=700, num_leaves=70)
params = {
    'colsample_bytree': [0.5, 0.7]
}
model = GridSearchCV(gbm, params,
                     cv=4,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 4 folds for each of 2 candidates, totalling 8 fits
# [CV] colsample_bytree=0.5 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................. colsample_bytree=0.5, total=  15.3s
# [CV] colsample_bytree=0.5 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.3s remaining:    0.0s
# [CV] ............................. colsample_bytree=0.5, total=  14.1s
# [CV] colsample_bytree=0.5 ............................................
# [CV] ............................. colsample_bytree=0.5, total=  13.3s
# [CV] colsample_bytree=0.5 ............................................
# [CV] ............................. colsample_bytree=0.5, total=  13.8s
# [CV] colsample_bytree=0.7 ............................................
# [CV] ............................. colsample_bytree=0.7, total=  19.0s
# [CV] colsample_bytree=0.7 ............................................
# [CV] ............................. colsample_bytree=0.7, total=  26.9s
# [CV] colsample_bytree=0.7 ............................................
# [CV] ............................. colsample_bytree=0.7, total=  28.5s
# [CV] colsample_bytree=0.7 ............................................
# [CV] ............................. colsample_bytree=0.7, total=  32.9s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  2.7min finished
#    std_score_time param_colsample_bytree                     params  \
# 0        0.019705                    0.5  {'colsample_bytree': 0.5}
# 1        0.016014                    0.7  {'colsample_bytree': 0.7}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.213362          -0.205561          -0.202458          -0.235457
# 1          -0.213185          -0.205152          -0.202239          -0.236585
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.214209        0.012894                1
# 1        -0.214290        0.013482                2

# %%
X_test = clf.transform(test[use_cols])
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %%
train['pred_diff'] = (train['relevance'] - model.predict(X_train)).abs()
train.sort_values(['pred_diff'], ascending=False)
# Out:
#         product_uid                                      product_title  \
# id
# 69679        119478           romano 4 ft. boxwood spiral topiari tree
# 136808       148897   earthquak 212cc tiller rear tine crt side shield
# 120624       140844                  rachael ray 10 qt. cover stockpot
# 104722       133520                    danco low lead 1a-3c stem crane
# 92432        128292  mont blanc northbrook drop-in composit granit ...
# 85851        125582   oakland live 26 in. metal grape tabl plant stand
# 134028       147467  master flow 24 vdc replac motor solar dual-pow...
# 9508         101618  sure comfort 40 gal. tall 3 year 34,000 btu na...
# 204530       192555        heath bird stop blue ceram wild bird feeder
# 83392        124633             rubbermaid fasttrack garag cooler hook
# 17236        103041  ortho home defens max 1.33 gal. perimet indoor...
# 176724       172318  green matter 3-light mahogani bronz vaniti fixtur
# 198022       187480         alpin 15 in. larg red bowl plastic planter
# 156918       160006  werner 14 ft. fiberglass round rung straight l...
# 93622        128763  daylili grape magic bare root dormant plant (8...
# 101448       132055  warehous tiffani 21 in. jewel white/brown tabl...
# 73919        121054  eaton 125-amp ring type underground group mete...
# 3909         100682    19/32 in. x 24 in. x 4 ft. osb attic deck board
# 188479       180470  laura ashley freya 3-light weather cognac vani...
# 45195        111119  lincoln electr 1-1/2 in. circular coars wire b...
# 97371        130326   norcal potteri 6 in. terra cotta clay azalea pot
# 151606       156981  ge 36 in. over-the-rang microwav accessori fil...
# 109498       135608  gilbert &amp; bennett 42 in. galvan steel toma...
# 45248        111134  globalros red mini carnat (160 stems) includ f...
# 37816        108848     behr premium plus ultra #ppu6-16 cup tea paint
# 39795        109474  winchest 3 ton 13 seer sweat a/c system 21 in....
# 108375       135102  speedi-grill 24 in. x 6 in. base board return ...
# 58986        115722  lincoln electr wire feed .030 welder contact t...
# 76169        121880  zamma beech block 5/8 in. thick x 3/4 in. wide...
# 211891       198538     ce tech 6 ft. 8-outlet usb rj45 surg protector
# ...             ...                                                ...
# 164484       164541  leviton section 1-gang center decora nylon wal...
# 174075       170566  kohler choreograph 1.25 in. x 96 in. shower wa...
# 145930       153780     rubbermaid 47-1/2 in. black twin track upright
# 115464       138363  lockstat 10 code digit keyless singl cylind si...
# 10408        101791  eleg home fashion albion 22 in. w mdf white wa...
# 142748       152089  progress light pavilion collect 2-light antiqu...
# 151474       156904  storabl 33 in. l x 63 in. h locboard wall moun...
# 216779       202610            stanley spray gun electr pressur washer
# 161033       162433                       linzer 4 in. flat chip brush
# 23991        104755   echo 12 in. 25.4 cc bar telescop gas pole pruner
# 96888        130116  leviton 5 amp humid sensor fan speed control -...
# 181109       175282  lyon industri simplic apron front acryl 34 in....
# 154808       158794  salsburi industri heavi duti plastic side pane...
# 69831        119532  everbilt 1/2 in.-13 tpi galvan hex nut (25-pie...
# 69270        119325  stiebel eltron tempra 20 plus 19.2 kw 2.91 gpm...
# 197660       187208     charlott pipe 10 in. x 6 in. pvc dwv cross tee
# 145654       153611    wright product heavi duti tap n go closer black
# 149615       155824            dremel multi-max carbid flush cut blade
# 27012        105585  liberti 1-3/8 in. harmon cabinet hardwar knob ...
# 85713        125523  durav durablack 6 in. 45-degre elbow single-wa...
# 90390        127436  bruce oak honey parquet 5/16 in. thick x 12 in...
# 184687       177798  behr premium plus ultra #ppu14-2 glass sapphir...
# 119760       140400                      powerm 1-1/2 in. pressur gaug
# 83835        124803  price pfister s10-030 4-9/16 in. hot cold repl...
# 3640         100635  ridgid gen5x brushless 18-volt compact hammer ...
# 156952       160034  steel citi 12 in. 7.5 hp 50 in. industri t-squ...
# 73579        120934  weathershield 2 in. x 6 in. x 16 ft. #2 prime ...
# 147932       154883                 black kow 50 lb. compost cow manur
# 61293        116524  emco 32 in. x 80 in. 100 seri white self-stor ...
# 61079        116445  durav pelletv 8 in. x 8 in. fix vertic chimney...
#
#                                               search_term  relevance  \
# id
# 69679                                        topiari tree       1.00
# 136808                                        side shield       1.00
# 120624                                        rachael ray       1.00
# 104722                                       101-1h crane       1.00
# 92432                                         granit sand       1.00
# 85851                                         grape plant       1.00
# 134028                                         solar vent       1.00
# 9508                                   hot water tank gas       1.00
# 204530                                          bird stop       1.00
# 83392                                   rubbermaid cooler       1.33
# 17236                                          ant killer       1.00
# 176724                                        bronz green       1.00
# 198022                                         alpin larg       1.00
# 156918                                       14 ft ladder       1.00
# 93622                                         grape plant       1.00
# 101448                                       inlin switch       1.00
# 73919                                         socket ring       1.00
# 3909                                         attic ladder       1.00
# 188479                                 laura ashley light       1.33
# 45195                                     circular sander       1.00
# 97371                                terra cotta clay pot       1.33
# 151606                                  ge slate microwav       1.00
# 109498                                       tomato plant       1.00
# 45248                                           free ship       1.00
# 37816                                           paint cup       1.00
# 39795                                      line condition       1.00
# 108375                                    2.4 white board       1.00
# 58986                                     elrctric welder       1.00
# 76169                                         round beech       1.00
# 211891                                       ce tech ipad       1.00
# ...                                                   ...        ...
# 164484  leviton 6-gang decora/gfci devic decora wallpl...       2.33
# 174075                                        size shower       2.33
# 145930                      twin track bracket cloth pole       2.33
# 115464                                        door cylind       2.67
# 10408                             bathroom cabinet toilet       2.33
# 142748                          progress light 94356211eb       2.33
# 151474                        wall mount vinyl shelf rack       2.33
# 216779                     stanley fatmax paint spray gun       2.33
# 161033                                      4 paint brush       2.33
# 23991                                              pruner       2.33
# 96888                                          fan switch       2.67
# 181109                            short apron front skirt       2.00
# 154808                                 heavi duti plastic       2.67
# 69831                                         galvan bolt       2.33
# 69270                   tankless water heater ecoh200dv2n       2.33
# 197660                            small pvc dwv cross tee       2.67
# 145654                                  storm door closer       2.33
# 149615                              tile blade multi tool       2.33
# 27012                                        knob cabinet       2.67
# 85713                                     shed stove pipe       2.33
# 90390                                    bruce oak butter       2.33
# 184687                   quart exterior semi glass enamel       2.00
# 119760                            hous water pressur gaug       2.33
# 83835                       price pfister 130489 cartridg       2.33
# 3640                                            brushless       2.67
# 156952                                steel citi tabl saw       2.67
# 73579                                          16 ft. alu       2.00
# 147932                                         organ soil       2.33
# 61293                                    glass storm door       2.67
# 61079                                         chimney cap       2.67
#
#                                          orig_search_term  \
# id
# 69679                                        topiary tree
# 136808                                       side shields
# 120624                                        rachael ray
# 104722                                   101-1h for crane
# 92432                                       granite  sand
# 85851                                         grape plant
# 134028                                        solar vents
# 9508                                   hot water tank gas
# 204530                                         bird stops
# 83392                                   rubbermaid cooler
# 17236                                          ant killer
# 176724                                       bronze green
# 198022                                       alpine large
# 156918                                       14 ft ladder
# 93622                                         grape plant
# 101448                                      inline switch
# 73919                                         socket ring
# 3909                                         attic ladder
# 188479                              laura ashley lighting
# 45195                                     circular Sander
# 97371                               terra cotta clay pots
# 151606                                 ge slate microwave
# 109498                                      tomato plants
# 45248                                       free shipping
# 37816                                          paint cups
# 39795                                    line conditioner
# 108375                                    2.4 white board
# 58986                                    elrctric welders
# 76169                                         round beech
# 211891                                       ce tech ipad
# ...                                                   ...
# 164484  leviton 6-gang decora/gfci device decora wallp...
# 174075                                   Sizes of showers
# 145930                twin track bracket for clothes pole
# 115464                                      door cylinder
# 10408                      a bathroom cabinet over toilet
# 142748                       progress lighting 94356211eb
# 151474                      wall mounted vinyl shelf rack
# 216779                     stanley fatmax paint spray gun
# 161033                                      4 paint brush
# 23991                                             pruners
# 96888                                          fan switch
# 181109                            short apron front skirt
# 154808                                 heavy duty plastic
# 69831                                    galvanized bolts
# 69270                   tankless water heater ecoh200dv2n
# 197660                            small pvc dwv cross tee
# 145654                                  storm door closer
# 149615                         tile blades for multi tool
# 27012                                   knobs for cabinet
# 85713                                shed with stove pipe
# 90390                                   bruce oak butters
# 184687                   quart exterior semi glass enamel
# 119760                         house water pressure gauge
# 83835                      price pfister 130489 cartridge
# 3640                                            brushless
# 156952                               steel city table saw
# 73579                                         16 ft.  alu
# 147932                                       organic soil
# 61293                                   glass storm doors
# 61079                                        chimney caps
#
#                                        orig_product_title  \
# id
# 69679            Romano 4 ft. Boxwood Spiral Topiary Tree
# 136808  Earthquake 212cc Tiller Rear Tine CRT with Sid...
# 120624                Rachael Ray 10 qt. Covered Stockpot
# 104722                DANCO Low Lead 1A-3C Stem for Crane
# 92432   Mont Blanc Northbrook Drop-in Composite Granit...
# 85851   Oakland Living 26 in. Metal Grape Table Plant ...
# 134028  Master Flow 24 VDC Replacement Motor for Solar...
# 9508    Sure Comfort 40 Gal. Tall 3 Year 34,000 BTU Na...
# 204530      Heath Bird Stop Blue Ceramic Wild Bird Feeder
# 83392             Rubbermaid FastTrack Garage Cooler Hook
# 17236   Ortho Home Defense Max 1.33 Gal. Perimeter and...
# 176724  Green Matters 3-Light Mahogany Bronze Vanity F...
# 198022       Alpine 15 in. Large Red Bowl Plastic Planter
# 156918  Werner 14 ft. Fiberglass Round Rung Straight L...
# 93622   Daylily Grape Magic Bare Root Dormant Plants (...
# 101448  Warehouse of Tiffany 21 in. Jewel Off White/Br...
# 73919   Eaton 125-Amp Ring Type Underground Group Mete...
# 3909    19/32 in. x 24 in. x 4 ft. OSB Attic Decking B...
# 188479  Laura Ashley Freya 3-Light Weathered Cognac Va...
# 45195   Lincoln Electric 1-1/2 in. Circular Coarse Wir...
# 97371    Norcal Pottery 6 in. Terra Cotta Clay Azalea Pot
# 151606  GE 36 in. Over-the-Range Microwave Accessory F...
# 109498  Gilbert &amp; Bennett 42 in. Galvanized Steel ...
# 45248   Globalrose Red Mini Carnations (160 Stems) Inc...
# 37816   BEHR Premium Plus Ultra #PPU6-16 Cup of Tea Paint
# 39795   Winchester 3 Ton 13 SEER Sweat A/C System with...
# 108375  SPEEDI-GRILLE 24 in. x 6 in. Base Board Return...
# 58986   Lincoln Electric Wire Feed .030 Welder Contact...
# 76169   Zamma Beech Blocked 5/8 in. Thick x 3/4 in. Wi...
# 211891    CE TECH 6 ft. 8-Outlet USB RJ45 Surge Protector
# ...                                                   ...
# 164484  Leviton Sectional 1-Gang Center Decora Nylon W...
# 174075  KOHLER Choreograph 1.25 in. x 96 in. Shower Wa...
# 145930     Rubbermaid 47-1/2 in. Black Twin Track Upright
# 115464  LockState 10 Code Digital Keyless Single Cylin...
# 10408   Elegant Home Fashions Albion 22 in. W MDF Whit...
# 142748  Progress Lighting Pavilion Collection 2-Light ...
# 151474  Storability 33 in. L x 63 in. H LocBoard Wall ...
# 216779     Stanley Spray Gun for Electric Pressure Washer
# 161033                       Linzer 4 in. Flat Chip Brush
# 23991   ECHO 12 in. 25.4 cc Bar Telescoping Gas Pole P...
# 96888   Leviton 5 Amp Humidity Sensor Fan Speed Contro...
# 181109  Lyons Industries Simplicity Apron Front Acryli...
# 154808  Salsbury Industries Heavy Duty Plastic Side Pa...
# 69831   Everbilt 1/2 in.-13 tpi Galvanized Hex Nut (25...
# 69270   Stiebel Eltron Tempra 20 Plus 19.2 kW 2.91 GPM...
# 197660    Charlotte Pipe 10 in. x 6 in. PVC DWV Cross Tee
# 145654  Wright Products Heavy Duty Tap N Go Closer in ...
# 149615           Dremel Multi-Max Carbide Flush Cut Blade
# 27012   Liberty 1-3/8 in. Harmon Cabinet Hardware Knob...
# 85713   DuraVent DuraBlack 6 in. 45-Degree Elbow Singl...
# 90390   Bruce Oak Honey Parquet 5/16 in. Thick x 12 in...
# 184687  BEHR Premium Plus Ultra #PPU14-2 Glass Sapphir...
# 119760                 Powermate 1-1/2 in. Pressure Gauge
# 83835   Price Pfister S10-030 4-9/16 in. Hot and Cold ...
# 3640    RIDGID GEN5X Brushless 18-Volt Compact Hammer ...
# 156952  Steel City 12 in. 7.5 HP 50 in. Industrial T-S...
# 73579   WeatherShield 2 in. x 6 in. x 16 ft. #2 Prime ...
# 147932              Black Kow 50 lb. Composted Cow Manure
# 61293   EMCO 32 in. x 80 in. 100 Series White Self-Sto...
# 61079   DuraVent PelletVent 8 in. x 8 in. Fixed Vertic...
#
#                                                     descr  \
# id
# 69679   enhanc home romano boxwood spiral topiari tree...
# 136808  earthquak 6015v rear tine rototil deliv ultim ...
# 120624  whether boil pasta, make batch chili cook grai...
# 104722  repair leaki faucet easi inexpens altern repla...
# 92432   durabl granit composit materi provid mont blan...
# 85851   oakland live 26 in. metal grape tabl plant sta...
# 134028  slrm105 replac motor master flow green machin ...
# 9508    sure comfort 40 gal. natur gas tall water heat...
# 204530  bird stop blue ceram wild bird feeder featur b...
# 83392   part fasttrack system, cooler hook perfect sol...
# 17236   ortho home defens max 1.33 gal. ready-to-us pe...
# 176724  cornerston collect quality, incandesc vaniti e...
# 198022  bowl planter perfect patio decks. avail variet...
# 156918  7114-1 one-sect round rung 14 ft. straight lad...
# 93622   daylili vigor perenni requir littl care garden...
# 101448  tiffani style 21 in. jewel 1 light white tabl ...
# 73919   group metering, also known multipl metering, u...
# 3909    osb attic deck 24 in. x 48 in. attic deck 8 sq...
# 188479  found 1953, laura ashley becom quintessenti en...
# 45195   lincoln electr 1-1/2 in. circular coars wire b...
# 97371   6.75 in. terra cotta pot craft porous terra co...
# 151606  36 in. over-the-rang microwav trim kit provid ...
# 109498  help tomato plant grow lush tall 42 in. tomato...
# 45248   mini red carnat grown environment greenhouses,...
# 37816   behr premium plus ultra interior paint primer ...
# 39795   singl phase 13 seer sweat air condit system de...
# 108375  bbrag (base board return grille) durabl steel ...
# 58986   lincoln electr wire feed welder contact tip (1...
# 76169   beech block quarter round use accent transit b...
# 211891  ce tech hdc806nuwh surg protector ideal home/o...
# ...                                                   ...
# 164484  leviton offer comprehens select wall plate des...
# 174075  choreograph collect make easier ever creat sho...
# 145930  design extrem durabl high weight capacity, 47-...
# 115464  10-user code digit keyless singl cylind silver...
# 10408   albion mdf white wall cabinet eleg home fashio...
# 142748  add ambient light hallway, foyer sit room pavi...
# 151474  storabl modular wall storag ideal way store or...
# 216779  spray gun specif design replac use stanley ele...
# 161033  4 in. flat chip brush perfect touch up one use...
# 23991   echo ppt-266 provid fast, easi safe prune hard...
# 96888   new leviton humid sensor fan control automat d...
# 181109  lyon industri high-gloss acryl sink manufactur...
# 154808  salsburi heavi duti plastic side panel provid ...
# 69831   hex nut intern thread hex drive near general a...
# 69270   stiebel eltron develop tankless electr water h...
# 197660  pvc fit drain, wast vent purposes. use gravity...
# 145654  heavi duti tap n go closer wright product made...
# 149615  dremel multi-max mm485 carbid flush cut blade ...
# 27012   liberti hardware, harmon knob classic design c...
# 85713   durabl craft 24-gaug steel, durablack 45-degre...
# 90390   bruce american home 5/16 in. thick x 12 in. x ...
# 184687  behr premium plus ultra exterior paint primer ...
# 119760  powerm pressur gaug part larg line powerm genu...
# 83835   oem (origin equip manufacturer) s10-030 4-9/16...
# 3640    ridgid introduc next generat cordless tool gen...
# 156952  steel citi 12 in. industri tabl saw featur pow...
# 73579   everi piec meet highest grade standard strengt...
# 147932  black kow 50 lb. compost cow manur organ soil ...
# 61293   emco 100 seri 32 in. white woodcor self-stor s...
# 61079   pelletv vent system stove insert use multi-fue...
#
#                                                orig_descr  \
# id
# 69679   Enhance your home with a Romano Boxwood Spiral...
# 136808  The Earthquake 6015V rear tine rototiller deli...
# 120624  Whether you're boiling pasta, making a batch o...
# 104722  Repairing a leaky faucet is an easy and inexpe...
# 92432   Durable granite composite material provides th...
# 85851   The Oakland Living 26 in. Metal Grape Table Pl...
# 134028  The SLRM105 is the replacement motor for all M...
# 9508    The Sure Comfort 40 Gal. Natural Gas Tall Wate...
# 204530  The Bird Stop Blue Ceramic Wild Bird Feeder fe...
# 83392   Part of the FastTrack system, the Cooler Hook ...
# 17236   The Ortho Home Defense Max 1.33 Gal. Ready-to-...
# 176724  The cornerstone of this collection is quality,...
# 198022  These bowl planters are perfect for patios and...
# 156918  The 7114-1 one-section round rung 14 ft. Strai...
# 93622   Daylilies are vigorous perennial that require ...
# 101448  The Tiffany Style 21 in. Jewel 1 Light off Whi...
# 73919   Group metering, also known as multiple meterin...
# 3909    The OSB Attic Decking 24 in. x 48 in. Attic De...
# 188479  Founded in 1953, Laura Ashley has become a qui...
# 45195   The Lincoln Electric 1-1/2 in. Circular Coarse...
# 97371   The 6.75 in. Terra Cotta Pot is crafted with p...
# 151606  Your 36 in. Over-the-Range Microwave Trim Kit ...
# 109498  Help your tomato plant grow lush and tall with...
# 45248   Mini Red carnations are grown in environmental...
# 37816   BEHR Premium Plus Ultra Interior Paint and Pri...
# 39795   This single phase 13 SEER sweat air conditioni...
# 108375  BBRAG (Base Board Return Grille) is out of a d...
# 58986   The Lincoln Electric Wire Feed Welder Contact ...
# 76169   Beech Blocked Quarter Round is used to accent ...
# 211891  The CE TECH HDC806NUWH Surge Protector is idea...
# ...                                                   ...
# 164484  Leviton offers a comprehensive selection of wa...
# 174075  The Choreograph collection makes it easier tha...
# 145930  Designed to be extremely durable with a high w...
# 115464  The 10-User Code Digital Keyless Single Cylind...
# 10408   The Albion MDF White Wall Cabinet from Elegant...
# 142748  Add ambient lighting to your hallway, foyer or...
# 151474  Storability modular wall storage is the ideal ...
# 216779  This spray gun is specifically designed to rep...
# 161033  The 4 in. Flat Chip Brush is perfect for touch...
# 23991   The ECHO PPT-266 provides fast, easy and safe ...
# 96888   The new Leviton Humidity Sensor and Fan Contro...
# 181109  Lyons Industries high-gloss acrylic sinks are ...
# 154808  Salsbury Heavy Duty Plastic side panels provid...
# 69831   These hex nuts are internally threaded and hav...
# 69270   Stiebel Eltron developed tankless electric wat...
# 197660  PVC fittings are for drain, waste and vent pur...
# 145654  The Heavy Duty Tap N Go Closer from Wright Pro...
# 149615  The Dremel Multi-Max MM485 Carbide Flush Cut B...
# 27012   From Liberty Hardware, the Harmon Knob is a cl...
# 85713   Durably crafted with 24-gauge steel, the DuraB...
# 90390   This Bruce American Home 5/16 in. Thick x 12 i...
# 184687  BEHR Premium Plus Ultra Exterior Paint and Pri...
# 119760  The Powermate pressure gauge is part of a larg...
# 83835   This OEM (original equipment manufacturer) S10...
# 3640    RIDGID introduces their next generation of cor...
# 156952  The Steel City 12 in. Industrial Table Saw fea...
# 73579   Every piece meets the highest grading standard...
# 147932  Black Kow 50 lb. Composted Cow Manure is an or...
# 61293   The EMCO 100 Series 32 in. White Woodcore Self...
# 61079   PelletVent is a venting system for stoves and ...
#
#         match_product_title  match_descr    ...      match_pos_descr  \
# id                                          ...
# 69679              1.000000     1.000000    ...             1.000000
# 136808             1.000000     0.000000    ...             0.000000
# 120624             1.000000     0.500000    ...             0.500000
# 104722             0.500000     0.500000    ...             0.250000
# 92432              1.000000     1.000000    ...             0.500000
# 85851              1.000000     1.000000    ...             1.000000
# 134028             1.000000     1.000000    ...             1.000000
# 9508               0.500000     1.000000    ...             1.000000
# 204530             1.000000     1.000000    ...             0.500000
# 83392              1.000000     0.500000    ...             0.500000
# 17236              0.500000     0.500000    ...             0.500000
# 176724             1.000000     0.500000    ...             0.500000
# 198022             1.000000     0.000000    ...             0.000000
# 156918             0.666667     0.666667    ...             1.000000
# 93622              1.000000     1.000000    ...             1.000000
# 101448             1.000000     0.000000    ...             0.000000
# 73919              1.000000     0.500000    ...             0.000000
# 3909               0.500000     0.500000    ...             0.500000
# 188479             1.000000     1.000000    ...             0.666667
# 45195              0.500000     0.500000    ...             0.500000
# 97371              1.000000     1.000000    ...             0.500000
# 151606             1.000000     0.666667    ...             0.666667
# 109498             0.500000     1.000000    ...             0.500000
# 45248              1.000000     0.500000    ...             0.500000
# 37816              1.000000     0.500000    ...             0.500000
# 39795              0.500000     0.500000    ...             0.500000
# 108375             0.666667     0.666667    ...             0.666667
# 58986              0.500000     0.500000    ...             0.500000
# 76169              1.000000     1.000000    ...             1.000000
# 211891             0.666667     0.666667    ...             0.666667
# ...                     ...          ...    ...                  ...
# 164484             0.333333     0.166667    ...             0.250000
# 174075             0.500000     0.500000    ...             0.333333
# 145930             0.400000     0.400000    ...             0.500000
# 115464             1.000000     1.000000    ...             1.000000
# 10408              0.333333     0.666667    ...             0.600000
# 142748             0.666667     0.666667    ...             0.666667
# 151474             0.600000     0.600000    ...             0.400000
# 216779             0.600000     0.600000    ...             0.600000
# 161033             0.666667     0.666667    ...             0.333333
# 23991              1.000000     0.000000    ...             0.000000
# 96888              0.500000     1.000000    ...             1.000000
# 181109             0.500000     0.250000    ...             0.250000
# 154808             1.000000     1.000000    ...             1.000000
# 69831              0.500000     0.500000    ...             0.500000
# 69270              0.750000     0.750000    ...             0.500000
# 197660             0.800000     0.200000    ...             0.400000
# 145654             0.333333     0.666667    ...             0.666667
# 149615             0.250000     0.500000    ...             0.200000
# 27012              1.000000     0.500000    ...             0.333333
# 85713              0.666667     0.666667    ...             0.750000
# 90390              0.666667     0.666667    ...             0.333333
# 184687             0.200000     0.400000    ...             0.400000
# 119760             0.500000     0.500000    ...             0.500000
# 83835              0.750000     0.250000    ...             0.250000
# 3640               1.000000     1.000000    ...             1.000000
# 156952             0.750000     1.000000    ...             1.000000
# 73579              0.666667     0.000000    ...             0.000000
# 147932             0.000000     1.000000    ...             1.000000
# 61293              0.666667     1.000000    ...             0.666667
# 61079              1.000000     1.000000    ...             0.500000
#
#                           brand  match_brand  prod_title_ind  descr_ind  \
# id
# 69679                       NaN     0.000000        0.714286   0.092593
# 136808                      NaN     0.000000        0.750000   1.000000
# 120624                      NaN     0.000000        0.000000   0.440367
# 104722                      NaN     0.000000        0.833333   0.514286
# 92432                mont blanc     0.000000        0.333333   0.008130
# 85851                       NaN     0.000000        0.555556   0.084746
# 134028                      NaN     0.000000        0.600000   0.155556
# 9508               sure comfort     0.000000        0.769231   0.027778
# 204530                    heath     0.000000        0.125000   0.000000
# 83392                       NaN     0.000000        0.000000   0.051724
# 17236                     ortho     0.000000        0.818182   0.121951
# 176724             green matter     0.083333        0.000000   0.109756
# 198022                    alpin     0.200000        0.000000   1.000000
# 156918                      NaN     0.000000        0.062500   0.064516
# 93622                       NaN     0.000000        0.125000   0.515625
# 101448                      NaN     0.000000        0.800000   1.000000
# 73919                       NaN     0.000000        0.250000   0.403509
# 3909                    unbrand     0.000000        0.750000   0.014925
# 188479             laura ashley     0.166667        0.000000   0.037037
# 45195            lincoln electr     0.000000        0.500000   0.114286
# 97371                       NaN     0.000000        0.444444   0.035088
# 151606                       ge     0.500000        0.000000   0.035714
# 109498        gilbert & bennett     0.000000        0.777778   0.023810
# 45248                       NaN     0.000000        0.777778   0.712871
# 37816                       NaN     0.000000        0.625000   0.040323
# 39795                  winchest     0.000000        0.866667   0.089385
# 108375                      NaN     0.000000        0.466667   0.018868
# 58986            lincoln electr     0.000000        0.555556   0.088889
# 76169                     zamma     0.000000        0.055556   0.000000
# 211891                      NaN     0.000000        0.000000   0.000000
# ...                         ...          ...             ...        ...
# 164484                  leviton     0.142857        0.000000   0.000000
# 174075                   kohler     0.000000        0.437500   0.095238
# 145930               rubbermaid     0.000000        0.571429   0.153846
# 115464                      NaN     0.000000        0.500000   0.074627
# 10408         eleg home fashion     0.000000        0.909091   0.028777
# 142748           progress light     0.142857        0.000000   0.025316
# 151474                  storabl     0.000000        0.428571   0.013514
# 216779                  stanley     0.142857        0.000000   0.000000
# 161033                   linzer     0.000000        0.166667   0.000000
# 23991                      echo     0.000000        0.900000   1.000000
# 96888                       NaN     0.000000        0.500000   0.027027
# 181109                      NaN     0.000000        0.214286   0.571429
# 154808                      NaN     0.000000        0.142857   0.013699
# 69831                  everbilt     0.000000        0.400000   0.357143
# 69270            stiebel eltron     0.000000        0.733333   0.009119
# 197660            charlott pipe     0.000000        0.636364   0.000000
# 145654                      NaN     0.000000        0.777778   0.092593
# 149615                   dremel     0.000000        0.833333   0.060000
# 27012                   liberti     0.000000        0.500000   0.068182
# 85713                     durav     0.000000        0.800000   0.109756
# 90390                     bruce     0.200000        0.000000   0.000000
# 184687  behr premium plus ultra     0.000000        0.625000   0.030303
# 119760                   powerm     0.000000        0.600000   0.022727
# 83835             price pfister     0.153846        0.000000   0.290323
# 3640                     ridgid     0.000000        0.166667   0.036269
# 156952                      NaN     0.000000        0.000000   0.000000
# 73579             weathershield     0.000000        0.538462   1.000000
# 147932                black kow     0.000000        1.000000   0.114754
# 61293                      emco     0.000000        0.833333   0.085106
# 61079                     durav     0.000000        0.818182   0.304762
#
#         pred_diff words_std_title  words_std_descr  len_title  len_descr
# id
# 69679    1.661656        0.250000        16.000000          7          7
# 136808   1.507517        0.250000         0.000000          8          8
# 120624   1.501380        0.250000         0.000000          6          6
# 104722   1.452257        0.000000         0.000000          6          6
# 92432    1.441053       20.250000       256.000000         15         15
# 85851    1.433580        1.000000         1.000000          9          9
# 134028   1.405220        2.250000        81.000000         10         10
# 9508     1.389258        0.250000       281.187500         13         13
# 204530   1.381526        0.250000         0.250000          8          8
# 83392    1.362543        2.250000         0.000000          5          5
# 17236    1.357681        0.000000         0.000000         11         11
# 176724   1.350129        4.000000         0.000000          7          7
# 198022   1.343646        2.250000         0.000000          8          8
# 156918   1.342024        9.000000         2.250000         16         16
# 93622    1.336181        6.250000         6.250000          8          8
# 101448   1.309585        0.250000         0.000000         10         10
# 73919    1.302296        6.250000         0.000000          8          8
# 3909     1.300569        0.000000         0.000000         12         12
# 188479   1.291698        9.555556       112.666667          8          8
# 45195    1.283956        0.000000         0.000000          8          8
# 97371    1.280558        2.187500       108.500000          9          9
# 151606   1.280189       10.666667        16.000000          9          9
# 109498   1.278646        0.000000         0.250000          9          9
# 45248    1.270127        0.250000         0.000000          9          9
# 37816    1.268887        1.000000         0.000000          8          8
# 39795    1.267095        0.000000         0.000000         15         15
# 108375   1.264437       12.250000        49.000000         15         15
# 58986    1.262266        0.000000         0.000000          9          9
# 76169    1.257817       56.250000         2.250000         18         18
# 211891   1.257238        0.250000         0.250000          9          9
# ...           ...             ...              ...        ...        ...
# 164484   0.000221        4.000000         0.000000         10         10
# 174075   0.000198        0.000000         0.000000         16         16
# 145930   0.000194        0.250000         0.250000          7          7
# 115464   0.000192        4.000000         4.000000         12         12
# 10408    0.000174        0.000000        56.250000         11         11
# 142748   0.000170        0.250000        16.000000          9          9
# 151474   0.000170       12.666667      2574.222222         21         21
# 216779   0.000163        0.666667         6.888889          6          6
# 161033   0.000155        4.000000         4.000000          6          6
# 23991    0.000152        0.000000         0.000000         10         10
# 96888    0.000149        0.000000       650.250000         10         10
# 181109   0.000149        0.250000         0.000000         14         14
# 154808   0.000132        0.666667         0.666667         14         14
# 69831    0.000128        0.000000         0.000000         10         10
# 69270    0.000124        1.555556       854.888889         15         15
# 197660   0.000121        1.250000         0.000000         11         11
# 145654   0.000102        0.000000       462.250000          9          9
# 149615   0.000094        0.000000       812.250000          6          6
# 27012    0.000093        1.000000         0.000000          8          8
# 85713    0.000077        0.250000         0.250000         10         10
# 90390    0.000063        0.250000        56.250000         22         22
# 184687   0.000062        0.000000      2352.250000          8          8
# 119760   0.000033        0.250000         0.250000          5          5
# 83835    0.000030       16.222222         0.000000         12         12
# 3640     0.000027        0.000000         0.000000         12         12
# 156952   0.000021       46.888889         6.500000         16         16
# 73579    0.000020        0.250000         0.000000         13         13
# 147932   0.000017        0.000000         0.250000          7          7
# 61293    0.000014        0.250000       220.666667         12         12
# 61079    0.000002        0.250000         0.250000         11         11
#
# [74067 rows x 25 columns]

# %%
@np.vectorize
def match_last_word(search_term, text):
    last_word = search_term.split()[-1]
    if text.find(last_word) > -1:
        return 1
    else:
        return 0

train['brand'].fillna('', inplace=True)
train['last_word_title'] = match_last_word(train['search_term'], train['product_title'])  
train['last_word_descr'] = match_last_word(train['search_term'], train['descr'])  

test['brand'].fillna('', inplace=True)
test['last_word_title'] = match_last_word(test['search_term'], test['product_title'])  
test['last_word_descr'] = match_last_word(test['search_term'], test['descr'])

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr', 'len_title', 'len_descr', 'last_word_title',
             'last_word_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=20))]))
                    ]
            ))])
clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])
X_test = clf.transform(test[use_cols])

# %%
gbm = lgb.LGBMRegressor(learning_rate=0.03, n_estimators=700, num_leaves=70)
params = {
    'colsample_bytree': [0.5]
}
model = GridSearchCV(gbm, params,
                     cv=5,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] colsample_bytree=0.5 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................. colsample_bytree=0.5, total=  19.2s
# [CV] colsample_bytree=0.5 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   19.2s remaining:    0.0s
# [CV] ............................. colsample_bytree=0.5, total=  22.7s
# [CV] colsample_bytree=0.5 ............................................
# [CV] ............................. colsample_bytree=0.5, total=  21.2s
# [CV] colsample_bytree=0.5 ............................................
# [CV] ............................. colsample_bytree=0.5, total=  17.5s
# [CV] colsample_bytree=0.5 ............................................
# [CV] ............................. colsample_bytree=0.5, total=  21.7s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.7min finished
#    std_score_time param_colsample_bytree                     params  \
# 0        0.020028                    0.5  {'colsample_bytree': 0.5}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.21276          -0.203688          -0.199611          -0.204764
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.229389        -0.210042        0.010571                1

# %%
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47395

# %%
model.best_estimator_.feature_importances_
# Out:
# array([318, 192, 221, 510, 286,  48, 175, 474, 312, 148, 189, 275, 243,
#         75,  48, 352, 271, 223, 207, 236, 213, 233, 183, 185, 210, 221,
#        223, 203, 229, 215, 210, 189, 180, 212, 212, 202, 213, 230, 183,
#        189, 284, 209, 194, 231, 196, 204, 234, 218, 233, 208, 222, 221,
#        212, 246, 209, 200, 187, 228, 199, 201, 211, 203, 201, 198, 232,
#        233, 193, 185, 195, 189, 220, 249, 199, 213, 200, 240, 222, 212,
#        194, 189, 201, 237, 230, 209, 212, 231, 224, 255, 266, 278, 311,
#        227, 274, 279, 264, 221, 192, 185, 195, 157, 164, 159, 248, 155,
#        153, 184, 167, 191, 172, 192, 160, 140, 152, 154, 179, 171, 163,
#        132, 135, 132, 200, 144, 166, 168, 154, 161, 183, 157, 144, 181,
#        176, 189, 193, 177, 185, 153, 169, 153, 167, 148, 154, 180, 180,
#        178, 199, 166, 159, 169, 184, 129, 208, 203, 208, 203, 191, 191,
#        256, 211, 197, 200, 149, 200, 175, 189, 172, 137, 182, 202, 193,
#        221, 190, 187, 201, 182, 145, 312, 150, 213, 151, 209, 169, 162,
#        201, 167, 173, 156, 163, 211, 165, 172, 151, 134, 171, 224, 173,
#        166, 167, 192, 160, 206, 176, 141, 168, 168, 194, 164, 192, 152,
#        201, 197, 163, 175, 167, 172, 169, 170, 173, 189, 187, 178, 182,
#        194, 174, 172, 210, 196, 162, 181, 203, 189, 232, 165, 207, 160,
#        212, 109,  92, 160, 174, 125,  89,  98,  91,  94,  82, 116, 110,
#         78, 146,  86, 114,  84, 108, 114, 115])

# %%
train['pred_diff'] = (train['relevance'] - model.predict(X_train)).abs()
train.sort_values(['pred_diff'], ascending=False)[:50]
# Out:
#         product_uid                                      product_title  \
# id
# 136808       148897   earthquak 212cc tiller rear tine crt side shield
# 69679        119478           romano 4 ft. boxwood spiral topiari tree
# 156918       160006  werner 14 ft. fiberglass round rung straight l...
# 120624       140844                  rachael ray 10 qt. cover stockpot
# 104722       133520                    danco low lead 1a-3c stem crane
# 204530       192555        heath bird stop blue ceram wild bird feeder
# 146582       154163  tuscani coast 2-light weather charcoal outdoor...
# 9508         101618  sure comfort 40 gal. tall 3 year 34,000 btu na...
# 85851        125582   oakland live 26 in. metal grape tabl plant stand
# 93622        128763  daylili grape magic bare root dormant plant (8...
# 742          100129          sundstrom safeti silicon half mask respir
# 200148       189102                          genuin joe dust mop frame
# 98819        130929  prime-lin slide door tandem roller assembly, 1...
# 198022       187480         alpin 15 in. larg red bowl plastic planter
# 17236        103041  ortho home defens max 1.33 gal. perimet indoor...
# 97371        130326   norcal potteri 6 in. terra cotta clay azalea pot
# 92432        128292  mont blanc northbrook drop-in composit granit ...
# 92095        128155  3/4 in. x 1-1/4 in. stainless steel rail mount...
# 101448       132055  warehous tiffani 21 in. jewel white/brown tabl...
# 201869       190460  control brand visbi 12-light gun metal black c...
# 151606       156981  ge 36 in. over-the-rang microwav accessori fil...
# 11984        102095  tire scienc 4 in. x 6 in. wheelbarrow tube sea...
# 50034        112740  thermo-tex 12 ft. x 24 ft. 3-year rectangular ...
# 83392        124633             rubbermaid fasttrack garag cooler hook
# 69064        119252  big ass fan 3600 144 in. yellow silver aluminu...
# 37816        108848     behr premium plus ultra #ppu6-16 cup tea paint
# 188479       180470  laura ashley freya 3-light weather cognac vani...
# 142618       152011  builder&#39; choic richmond 4 ft. x 3-3/4 in. ...
# 73919        121054  eaton 125-amp ring type underground group mete...
# 108146       135002  daylight naturalight 22-watt energi save circu...
# 76169        121880  zamma beech block 5/8 in. thick x 3/4 in. wide...
# 176724       172318  green matter 3-light mahogani bronz vaniti fixtur
# 108375       135102  speedi-grill 24 in. x 6 in. base board return ...
# 130026       145453  galcon 7001d batteri oper control 1.5 in. inli...
# 178971       173827  hillman group 3 in. satin chrome residenti doo...
# 17257        103047    smartbidet electr bidet seat elong toilet white
# 51369        113189      5 ft. x 30 ft. dalen product nylon trelli net
# 45195        111119  lincoln electr 1-1/2 in. circular coars wire b...
# 45248        111134  globalros red mini carnat (160 stems) includ f...
# 125561       143210  laura ashley 6 ft. h lip-stick red palm tree f...
# 94173        129007             john deer 54 in. mower deck drive belt
# 137108       149071           viagrow strawberri planter vertic garden
# 34903        107935  heat stream 60,000 btu forced-air propan porta...
# 141158       151219  wallpap compani 6.83 in. x 15 ft. beig magnoli...
# 128447       144688  philip 100-watt ceramalux high pressur sodium ...
# 109498       135608  gilbert &amp; bennett 42 in. galvan steel toma...
# 88329        126613         k&#39;nex angri bird intro assort (4-pack)
# 135396       148172       whirlpool 16 oz. all-purpos applianc cleaner
# 3909         100682    19/32 in. x 24 in. x 4 ft. osb attic deck board
# 90155        127352       intec force/2 next generat insul blow machin
#
#                          search_term  relevance  \
# id
# 136808                   side shield       1.00
# 69679                   topiari tree       1.00
# 156918                  14 ft ladder       1.00
# 120624                   rachael ray       1.00
# 104722                  101-1h crane       1.00
# 204530                     bird stop       1.00
# 146582               tuscani classic       1.00
# 9508              hot water tank gas       1.00
# 85851                    grape plant       1.00
# 93622                    grape plant       1.00
# 742                        face mask       1.00
# 200148                    swffer mop       1.00
# 98819                    roller bear       1.00
# 198022                    alpin larg       1.00
# 17236                     ant killer       1.00
# 97371           terra cotta clay pot       1.33
# 92432                    granit sand       1.00
# 92095                       fish rod       1.00
# 101448                  inlin switch       1.00
# 201869                      bran gun       1.00
# 151606             ge slate microwav       1.00
# 11984          wheelbarrow tire tube       1.33
# 50034                  solar blanket       1.33
# 83392              rubbermaid cooler       1.33
# 69064                        big ass       1.00
# 37816                      paint cup       1.00
# 188479            laura ashley light       1.33
# 142618                fireplac paint       1.00
# 73919                    socket ring       1.00
# 108146           full spectrum light       1.33
# 76169                    round beech       1.00
# 176724                   bronz green       1.00
# 108375               2.4 white board       1.00
# 130026                 solenoid valv       1.33
# 178971           door hing remov pin       1.33
# 17257                   toilet bidet       1.33
# 51369                   mosquito net       1.00
# 45195                circular sander       1.00
# 45248                      free ship       1.00
# 125561                     red stone       1.00
# 94173     mower deck blade john deer       1.00
# 137108                    strawberri       1.00
# 34903                    heat stream       1.33
# 141158                      magnolia       1.33
# 128447  high pressur laminate12 long       1.00
# 109498                  tomato plant       1.00
# 88329                     bird block       1.00
# 135396            whirlpool applianc       1.33
# 3909                    attic ladder       1.00
# 90155                           next       1.00
#
#                       orig_search_term  \
# id
# 136808                    side shields
# 69679                     topiary tree
# 156918                    14 ft ladder
# 120624                     rachael ray
# 104722                101-1h for crane
# 204530                      bird stops
# 146582                 tuscany classic
# 9508                hot water tank gas
# 85851                      grape plant
# 93622                      grape plant
# 742                         face masks
# 200148                      swffer mop
# 98819                  roller bearings
# 198022                    alpine large
# 17236                       ant killer
# 97371            terra cotta clay pots
# 92432                    granite  sand
# 92095                      fishing rod
# 101448                   inline switch
# 201869                        bran gun
# 151606              ge slate microwave
# 11984         wheelbarrow tire no tube
# 50034                    solar blanket
# 83392                rubbermaid cooler
# 69064                          big ass
# 37816                       paint cups
# 188479           laura ashley lighting
# 142618                 fireplace paint
# 73919                      socket ring
# 108146             full spectrum light
# 76169                      round beech
# 176724                    bronze green
# 108375                 2.4 white board
# 130026                  solenoid valve
# 178971  door hinges with removable pin
# 17257                toilet with bidet
# 51369                     mosquito net
# 45195                  circular Sander
# 45248                    free shipping
# 125561                      red stones
# 94173     mower deck blades john deere
# 137108                    strawberries
# 34903                      heat stream
# 141158                        magnolia
# 128447   high pressure laminate12 long
# 109498                   tomato plants
# 88329                       bird block
# 135396            whirlpool appliances
# 3909                      attic ladder
# 90155                             next
#
#                                        orig_product_title  \
# id
# 136808  Earthquake 212cc Tiller Rear Tine CRT with Sid...
# 69679            Romano 4 ft. Boxwood Spiral Topiary Tree
# 156918  Werner 14 ft. Fiberglass Round Rung Straight L...
# 120624                Rachael Ray 10 qt. Covered Stockpot
# 104722                DANCO Low Lead 1A-3C Stem for Crane
# 204530      Heath Bird Stop Blue Ceramic Wild Bird Feeder
# 146582  Tuscany Coast 2-Light Weathered Charcoal Outdo...
# 9508    Sure Comfort 40 Gal. Tall 3 Year 34,000 BTU Na...
# 85851   Oakland Living 26 in. Metal Grape Table Plant ...
# 93622   Daylily Grape Magic Bare Root Dormant Plants (...
# 742        Sundstrom Safety Silicone Half Mask Respirator
# 200148                         Genuine Joe Dust Mop Frame
# 98819   Prime-Line Sliding Door Tandem Roller Assembly...
# 198022       Alpine 15 in. Large Red Bowl Plastic Planter
# 17236   Ortho Home Defense Max 1.33 Gal. Perimeter and...
# 97371    Norcal Pottery 6 in. Terra Cotta Clay Azalea Pot
# 92432   Mont Blanc Northbrook Drop-in Composite Granit...
# 92095   3/4 in. x 1-1/4 in. Stainless Steel Rail Mount...
# 101448  Warehouse of Tiffany 21 in. Jewel Off White/Br...
# 201869  Control Brand Visby 12-Light Gun Metal Black C...
# 151606  GE 36 in. Over-the-Range Microwave Accessory F...
# 11984   Tire Science 4 in. x 6 in. Wheelbarrow Tube wi...
# 50034   Thermo-Tex 12 ft. x 24 ft. 3-Year Rectangular ...
# 83392             Rubbermaid FastTrack Garage Cooler Hook
# 69064   Big Ass Fans 3600 144 in. Yellow and Silver Al...
# 37816   BEHR Premium Plus Ultra #PPU6-16 Cup of Tea Paint
# 188479  Laura Ashley Freya 3-Light Weathered Cognac Va...
# 142618  Builder&#39;s Choice Richmond 4 ft. x 3-3/4 in...
# 73919   Eaton 125-Amp Ring Type Underground Group Mete...
# 108146  Daylight Naturalight 22-Watt Energy Saving Cir...
# 76169   Zamma Beech Blocked 5/8 in. Thick x 3/4 in. Wi...
# 176724  Green Matters 3-Light Mahogany Bronze Vanity F...
# 108375  SPEEDI-GRILLE 24 in. x 6 in. Base Board Return...
# 130026  Galcon 7001D Battery Operated Controller with ...
# 178971  The Hillman Group 3 in. Satin Chrome Residenti...
# 17257   SmartBidet Electric Bidet Seat for Elongated T...
# 51369   5 ft. x 30 ft. Dalen Products Nylon Trellis Ne...
# 45195   Lincoln Electric 1-1/2 in. Circular Coarse Wir...
# 45248   Globalrose Red Mini Carnations (160 Stems) Inc...
# 125561  Laura Ashley 6 ft. H Lip-Stick Red Palm Tree i...
# 94173             John Deere 54 in. Mower Deck Drive Belt
# 137108         Viagrow Strawberry Planter Vertical Garden
# 34903   Heat Stream 60,000 BTU Forced-Air Propane Port...
# 141158  The Wallpaper Company 6.83 in. x 15 ft. Beige ...
# 128447  Philips 100-Watt Ceramalux High Pressure Sodiu...
# 109498  Gilbert &amp; Bennett 42 in. Galvanized Steel ...
# 88329     K&#39;NEX Angry Birds Intro Assortment (4-Pack)
# 135396     Whirlpool 16 oz. All-Purpose Appliance Cleaner
# 3909    19/32 in. x 24 in. x 4 ft. OSB Attic Decking B...
# 90155   Intec FORCE/2 Next Generation Insulation Blowi...
#
#                                                     descr  \
# id
# 136808  earthquak 6015v rear tine rototil deliv ultim ...
# 69679   enhanc home romano boxwood spiral topiari tree...
# 156918  7114-1 one-sect round rung 14 ft. straight lad...
# 120624  whether boil pasta, make batch chili cook grai...
# 104722  repair leaki faucet easi inexpens altern repla...
# 204530  bird stop blue ceram wild bird feeder featur b...
# 146582  tuscani coast 2-light exterior post lamp weath...
# 9508    sure comfort 40 gal. natur gas tall water heat...
# 85851   oakland live 26 in. metal grape tabl plant sta...
# 93622   daylili vigor perenni requir littl care garden...
# 742     sr 100 half mask air purifi respir intend use ...
# 200148  mop frame design use genuin joe 02310 dust mop...
# 98819   patio door roller construct steel tandem rolle...
# 198022  bowl planter perfect patio decks. avail variet...
# 17236   ortho home defens max 1.33 gal. ready-to-us pe...
# 97371   6.75 in. terra cotta pot craft porous terra co...
# 92432   durabl granit composit materi provid mont blan...
# 92095   adjust rod holder made 316 stainless steel sec...
# 101448  tiffani style 21 in. jewel 1 light white tabl ...
# 201869  visbi chandeli twelv gun metal rod radiat core...
# 151606  36 in. over-the-rang microwav trim kit provid ...
# 11984   infus leak-stopper, tire scienc 4 in. x 6 in. ...
# 50034   thermo-tex solar blanket extend swim season sa...
# 83392   part fasttrack system, cooler hook perfect sol...
# 69064   want air movement without noise. got it. big a...
# 37816   behr premium plus ultra interior paint primer ...
# 188479  found 1953, laura ashley becom quintessenti en...
# 142618  add sens timeless beauti fireplac home decor f...
# 73919   group metering, also known multipl metering, u...
# 108146  naturalight 22w energi save circular tube. nat...
# 76169   beech block quarter round use accent transit b...
# 176724  cornerston collect quality, incandesc vaniti e...
# 108375  bbrag (base board return grille) durabl steel ...
# 130026  galcon 7001d batteri oper irrig control design...
# 178971  residenti door hing design interior residenti ...
# 17257   smartbidet electr bidet seat elong toilet easi...
# 51369   heavy-duti nylon trelli net ideal grow tomatoe...
# 45195   lincoln electr 1-1/2 in. circular coars wire b...
# 45248   mini red carnat grown environment greenhouses,...
# 125561  laura ashley brand known luxuri stylish design...
# 94173   john deer 54 in. deck drive belt design replac...
# 137108  viagrow strawberri planter allow grow strawber...
# 34903   heatstream 60,000 btu forced-air propan heater...
# 141158  whip excit new look walls-quick easier ever. b...
# 128447  philip ceramalux 100-watt high pressur sodium ...
# 109498  help tomato plant grow lush tall 42 in. tomato...
# 88329   bring angri bird app life. introductori set fe...
# 135396  use power clean action purpos applianc cleaner...
# 3909    osb attic deck 24 in. x 48 in. attic deck 8 sq...
# 90155   forc 2 insul blower want need larger, stronger...
#
#                                                orig_descr  \
# id
# 136808  The Earthquake 6015V rear tine rototiller deli...
# 69679   Enhance your home with a Romano Boxwood Spiral...
# 156918  The 7114-1 one-section round rung 14 ft. Strai...
# 120624  Whether you're boiling pasta, making a batch o...
# 104722  Repairing a leaky faucet is an easy and inexpe...
# 204530  The Bird Stop Blue Ceramic Wild Bird Feeder fe...
# 146582  Tuscany Coast 2-Light Exterior Post Lamp In We...
# 9508    The Sure Comfort 40 Gal. Natural Gas Tall Wate...
# 85851   The Oakland Living 26 in. Metal Grape Table Pl...
# 93622   Daylilies are vigorous perennial that require ...
# 742     The SR 100 half mask Air Purifying Respirator ...
# 200148  Mop frame is designed for use with Genuine Joe...
# 98819   This patio door roller is constructed from ste...
# 198022  These bowl planters are perfect for patios and...
# 17236   The Ortho Home Defense Max 1.33 Gal. Ready-to-...
# 97371   The 6.75 in. Terra Cotta Pot is crafted with p...
# 92432   Durable granite composite material provides th...
# 92095   This Adjustable Rod Holder is made of 316 stai...
# 101448  The Tiffany Style 21 in. Jewel 1 Light off Whi...
# 201869  The Visby chandelier has twelve gun metal rods...
# 151606  Your 36 in. Over-the-Range Microwave Trim Kit ...
# 11984   Infused with leak-stopper, this Tire Science 4...
# 50034   Thermo-Tex Solar blankets will extend your Swi...
# 83392   Part of the FastTrack system, the Cooler Hook ...
# 69064   Want air movement without noise. You've got it...
# 37816   BEHR Premium Plus Ultra Interior Paint and Pri...
# 188479  Founded in 1953, Laura Ashley has become a qui...
# 142618  Add a sense of timeless beauty to your firepla...
# 73919   Group metering, also known as multiple meterin...
# 108146  Naturalight 22W energy saving circular tube. N...
# 76169   Beech Blocked Quarter Round is used to accent ...
# 176724  The cornerstone of this collection is quality,...
# 108375  BBRAG (Base Board Return Grille) is out of a d...
# 130026  The Galcon 7001D is a battery operated irrigat...
# 178971  Residential Door Hinges are designed for inter...
# 17257   The SmartBidet Electric Bidet Seat for Elongat...
# 51369   Our heavy-duty nylon trellis netting is ideal ...
# 45195   The Lincoln Electric 1-1/2 in. Circular Coarse...
# 45248   Mini Red carnations are grown in environmental...
# 125561  The Laura Ashley Brand known for luxury and st...
# 94173   The John Deere 54 in. Deck Drive Belt is desig...
# 137108  The Viagrow Strawberry Planter allows you to g...
# 34903   The HeatStream 60,000 BTU Forced-Air Propane H...
# 141158  Whip up an exciting new look for your walls-qu...
# 128447  Philips Ceramalux 100-Watt High Pressure Sodiu...
# 109498  Help your tomato plant grow lush and tall with...
# 88329   Bring the Angry Birds app to life. These intro...
# 135396  Use the powerful cleaning action of All Purpos...
# 3909    The OSB Attic Decking 24 in. x 48 in. Attic De...
# 90155   The Force 2 is the insulation blower you want ...
#
#         match_product_title  match_descr       ...         match_brand  \
# id                                             ...
# 136808             1.000000     0.000000       ...            0.000000
# 69679              1.000000     1.000000       ...            0.000000
# 156918             0.666667     0.666667       ...            0.000000
# 120624             1.000000     0.500000       ...            0.000000
# 104722             0.500000     0.500000       ...            0.000000
# 204530             1.000000     1.000000       ...            0.000000
# 146582             0.500000     1.000000       ...            0.000000
# 9508               0.500000     1.000000       ...            0.000000
# 85851              1.000000     1.000000       ...            0.000000
# 93622              1.000000     1.000000       ...            0.000000
# 742                0.500000     1.000000       ...            0.000000
# 200148             0.500000     0.500000       ...            0.000000
# 98819              0.500000     1.000000       ...            0.000000
# 198022             1.000000     0.000000       ...            0.200000
# 17236              0.500000     0.500000       ...            0.000000
# 97371              1.000000     1.000000       ...            0.000000
# 92432              1.000000     1.000000       ...            0.000000
# 92095              0.500000     1.000000       ...            0.000000
# 101448             1.000000     0.000000       ...            0.000000
# 201869             0.500000     0.500000       ...            0.000000
# 151606             1.000000     0.666667       ...            0.500000
# 11984              1.000000     1.000000       ...            0.090909
# 50034              1.000000     1.000000       ...            0.000000
# 83392              1.000000     0.500000       ...            0.000000
# 69064              1.000000     1.000000       ...            0.000000
# 37816              1.000000     0.500000       ...            0.000000
# 188479             1.000000     1.000000       ...            0.166667
# 142618             0.500000     1.000000       ...            0.000000
# 73919              1.000000     0.500000       ...            0.000000
# 108146             0.333333     1.000000       ...            0.000000
# 76169              1.000000     1.000000       ...            0.000000
# 176724             1.000000     0.500000       ...            0.083333
# 108375             0.666667     0.666667       ...            0.000000
# 130026             1.000000     0.000000       ...            0.000000
# 178971             1.000000     1.000000       ...            0.000000
# 17257              1.000000     1.000000       ...            0.000000
# 51369              0.500000     0.500000       ...            0.000000
# 45195              0.500000     0.500000       ...            0.000000
# 45248              1.000000     0.500000       ...            0.000000
# 125561             1.000000     0.500000       ...            0.000000
# 94173              0.800000     0.800000       ...            0.222222
# 137108             1.000000     1.000000       ...            0.000000
# 34903              1.000000     0.500000       ...            0.000000
# 141158             1.000000     1.000000       ...            0.000000
# 128447             0.500000     0.750000       ...            0.000000
# 109498             0.500000     1.000000       ...            0.000000
# 88329              0.500000     0.500000       ...            0.000000
# 135396             1.000000     0.500000       ...            0.000000
# 3909               0.500000     0.500000       ...            0.000000
# 90155              1.000000     0.000000       ...            0.000000
#
#         prod_title_ind  descr_ind  pred_diff  words_std_title  \
# id
# 136808        0.750000   1.000000   1.583508         0.250000
# 69679         0.714286   0.092593   1.581459         0.250000
# 156918        0.062500   0.064516   1.493323         9.000000
# 120624        0.000000   0.440367   1.484087         0.250000
# 104722        0.833333   0.514286   1.469233         0.000000
# 204530        0.125000   0.000000   1.414796         0.250000
# 146582        0.000000   0.000000   1.389136         0.000000
# 9508          0.769231   0.027778   1.385987         0.250000
# 85851         0.555556   0.084746   1.373430         1.000000
# 93622         0.125000   0.515625   1.371076         6.250000
# 742           0.666667   0.026316   1.360460         0.000000
# 200148        0.600000   0.000000   1.357531         0.000000
# 98819         0.307692   0.057143   1.350273         0.000000
# 198022        0.000000   1.000000   1.334225         2.250000
# 17236         0.818182   0.121951   1.330029         0.000000
# 97371         0.444444   0.035088   1.326870         2.187500
# 92432         0.333333   0.008130   1.306210        20.250000
# 92095         0.642857   0.008475   1.304231         0.000000
# 101448        0.800000   1.000000   1.300923         0.250000
# 201869        0.500000   0.063830   1.297654         0.000000
# 151606        0.000000   0.035714   1.296773        10.666667
# 11984         0.000000   0.036364   1.291009        12.666667
# 50034         0.769231   0.014286   1.290709         1.000000
# 83392         0.000000   0.051724   1.284994         2.250000
# 69064         0.000000   0.052632   1.277676         0.250000
# 37816         0.625000   0.040323   1.273279         1.000000
# 188479        0.000000   0.037037   1.262027         9.555556
# 142618        0.666667   0.039604   1.261892         0.000000
# 73919         0.250000   0.403509   1.256856         6.250000
# 108146        0.777778   0.168421   1.255258         0.000000
# 76169         0.055556   0.000000   1.254573        56.250000
# 176724        0.000000   0.109756   1.252719         4.000000
# 108375        0.466667   0.018868   1.249127        12.250000
# 130026        0.666667   1.000000   1.244480         2.250000
# 178971        0.388889   0.019231   1.243195         9.250000
# 17257         0.285714   0.017391   1.241765         2.250000
# 51369         0.900000   0.045455   1.241598         0.000000
# 45195         0.500000   0.114286   1.238304         0.000000
# 45248         0.777778   0.712871   1.237231         0.250000
# 125561        0.500000   0.153153   1.236303         4.000000
# 94173         0.000000   0.000000   1.234677         4.250000
# 137108        0.200000   0.015385   1.232177         0.000000
# 34903         0.000000   0.087719   1.230479         0.250000
# 141158        0.800000   0.206522   1.221590         0.000000
# 128447        0.333333   0.036145   1.218313         0.250000
# 109498        0.777778   0.023810   1.217020         0.000000
# 88329         0.333333   0.021277   1.216535         0.000000
# 135396        0.000000   0.100000   1.216533         4.000000
# 3909          0.750000   0.014925   1.215780         0.000000
# 90155         0.285714   1.000000   1.215768         0.000000
#
#         words_std_descr len_title  len_descr  last_word_title  last_word_descr
# id
# 136808         0.000000         8         47                1                0
# 69679         16.000000         7         54                1                1
# 156918         2.250000        16         62                1                1
# 120624         0.000000         6        109                1                0
# 104722         0.000000         6         35                1                1
# 204530         0.250000         8         50                1                1
# 146582        20.250000         8         29                0                1
# 9508         281.187500        13        180                1                1
# 85851          1.000000         9         59                1                1
# 93622          6.250000         8         64                1                1
# 742          324.000000         6        114                1                1
# 200148         0.000000         5         70                1                1
# 98819        144.000000        13         35                1                1
# 198022         0.000000         8         33                1                0
# 17236          0.000000        11         82                1                1
# 97371        108.500000         9         57                1                1
# 92432        256.000000        15        123                1                1
# 92095        100.000000        14        118                1                1
# 101448         0.000000        10         71                1                0
# 201869         0.000000         8         47                1                1
# 151606        16.000000         9         84                1                1
# 11984         14.888889        10         55                1                1
# 50034          0.250000        13         70                1                1
# 83392          0.000000         5         58                1                1
# 69064          0.250000        12        133                1                1
# 37816          0.000000         8        124                1                0
# 188479       112.666667         8         54                1                1
# 142618       196.000000        12        101                1                1
# 73919          0.000000         8         57                1                1
# 108146         0.666667         9         95                1                1
# 76169          2.250000        18         83                1                1
# 176724         0.000000         7         82                1                0
# 108375        49.000000        15        106                1                1
# 130026         0.000000        12        162                1                1
# 178971         9.250000        18         52                1                1
# 17257          2.250000         7        115                1                1
# 51369          0.000000        10         66                1                1
# 45195          0.000000         8         35                0                0
# 45248          0.000000         9        101                1                1
# 125561         0.000000        12        111                1                0
# 94173         22.187500         8         44                1                1
# 137108         0.000000         5         65                1                1
# 34903          0.000000         8        114                1                1
# 141158         0.000000        10         92                1                1
# 128447        60.666667         9         83                0                1
# 109498         0.250000         9         42                0                1
# 88329          0.000000         6         94                0                0
# 135396         0.000000         6         50                1                1
# 3909           0.000000        12         67                0                0
# 90155          0.000000         7        185                1                0
#
# [50 rows x 27 columns]

# %%
train[train['pred_diff']>0.7].shape
# Out:
# (3806, 27)

# %%
train['bad'] = train['pred_diff']>0.7

clf_bad = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))]))
                    ]
            ))])
X_train_bad = clf_bad.fit(train[use_cols]).transform(train[use_cols])

# %%
y_bad = train['bad'].values
from lightgbm import LGBMClassifier
gbm_bad = LGBMClassifier()
gbm_bad.fit(X_train_bad, y_bad)
gbm_bad.score(X_train_bad, y_bad)
# Out:
# 0.949343162271997

# %%
train['bad_pred'] = gbm_bad.predict_proba(X_train_bad)[:, 1]
X_test_bad = clf_bad.transform(test[use_cols])
test['bad_pred'] = gbm_bad.predict_proba(X_test_bad)[:, 1]

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr', 'len_title', 'len_descr', 'last_word_title',
             'last_word_descr', 'bad_pred']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=20))]))
                    ]
            ))])
clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])
X_test = clf.transform(test[use_cols])

# %%
gbm = lgb.LGBMRegressor(learning_rate=0.03, n_estimators=700, colsample_bytree=0.5)
params = {
    'num_leaves': [70, 80]
}
model = GridSearchCV(gbm, params,
                     cv=5,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] num_leaves=70 ...................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................................... num_leaves=70, total=  17.9s
# [CV] num_leaves=70 ...................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.9s remaining:    0.0s
# [CV] .................................... num_leaves=70, total=  27.0s
# [CV] num_leaves=70 ...................................................
# [CV] .................................... num_leaves=70, total=  23.5s
# [CV] num_leaves=70 ...................................................
# [CV] .................................... num_leaves=70, total=  23.1s
# [CV] num_leaves=70 ...................................................
# [CV] .................................... num_leaves=70, total=  23.9s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  24.6s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  24.6s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  27.2s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  22.5s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  21.6s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  3.9min finished
#    std_score_time param_num_leaves              params  split0_test_score  \
# 1        0.006844               80  {'num_leaves': 80}          -0.196847
# 0        0.007621               70  {'num_leaves': 70}          -0.196586
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1          -0.190230          -0.185463          -0.188364          -0.213868
# 0          -0.191186          -0.185393          -0.189037          -0.214300
#
#    mean_test_score  std_test_score  rank_test_score
# 1        -0.194954        0.010170                1
# 0        -0.195301        0.010168                2

# %%
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
y_pred[y_pred<1.] = 1.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.48290

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr', 'len_title', 'len_descr', 'last_word_title',
             'last_word_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=20))]))
                    ]
            ))])
clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])
X_test = clf.transform(test[use_cols])

# %%
gbm = lgb.LGBMRegressor(learning_rate=0.03, n_estimators=700, colsample_bytree=0.5)
params = {
    'num_leaves': [70, 80]
}
model = GridSearchCV(gbm, params,
                     cv=5,
                     n_jobs=1,
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] num_leaves=70 ...................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................................... num_leaves=70, total=  17.1s
# [CV] num_leaves=70 ...................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.1s remaining:    0.0s
# [CV] .................................... num_leaves=70, total=  15.6s
# [CV] num_leaves=70 ...................................................
# [CV] .................................... num_leaves=70, total=  14.0s
# [CV] num_leaves=70 ...................................................
# [CV] .................................... num_leaves=70, total=  14.0s
# [CV] num_leaves=70 ...................................................
# [CV] .................................... num_leaves=70, total=  13.9s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  15.5s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  15.4s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  15.5s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  17.8s
# [CV] num_leaves=80 ...................................................
# [CV] .................................... num_leaves=80, total=  18.9s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  2.6min finished
#    std_score_time param_num_leaves              params  split0_test_score  \
# 1        0.001303               80  {'num_leaves': 80}           0.259654
# 0        0.004459               70  {'num_leaves': 70}           0.254528
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1           0.275215           0.273233           0.282373           0.152286
# 0           0.272677           0.272693           0.277876           0.150542
#
#    mean_test_score  std_test_score  rank_test_score
# 1         0.248553        0.048691                1
# 0         0.245664        0.048217                2

# %%
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
y_pred[y_pred<1.] = 1.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47372

# %%
gbm_best = model.best_estimator_
gbm_best.fit(X_train, y)

# %%
y_pred = gbm_best.predict(X_test)
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %%
train['pred_diff'] = (train['relevance'] - model.predict(X_train)).abs()
train.sort_values(['pred_diff'], ascending=False)[:50]
# Out:
#         product_uid                                      product_title  \
# id
# 69679        119478           romano 4 ft. boxwood spiral topiari tree
# 156918       160006  werner 14 ft. fiberglass round rung straight l...
# 136808       148897   earthquak 212cc tiller rear tine crt side shield
# 120624       140844                  rachael ray 10 qt. cover stockpot
# 204530       192555        heath bird stop blue ceram wild bird feeder
# 104722       133520                    danco low lead 1a-3c stem crane
# 176724       172318  green matter 3-light mahogani bronz vaniti fixtur
# 83392        124633             rubbermaid fasttrack garag cooler hook
# 9508         101618  sure comfort 40 gal. tall 3 year 34,000 btu na...
# 92432        128292  mont blanc northbrook drop-in composit granit ...
# 97371        130326   norcal potteri 6 in. terra cotta clay azalea pot
# 17236        103041  ortho home defens max 1.33 gal. perimet indoor...
# 142618       152011  builder&#39; choic richmond 4 ft. x 3-3/4 in. ...
# 101448       132055  warehous tiffani 21 in. jewel white/brown tabl...
# 37816        108848     behr premium plus ultra #ppu6-16 cup tea paint
# 93622        128763  daylili grape magic bare root dormant plant (8...
# 85851        125582   oakland live 26 in. metal grape tabl plant stand
# 96532        129999  brasscraft 3/8 in. o.d. x 36 in. copper faucet...
# 45195        111119  lincoln electr 1-1/2 in. circular coars wire b...
# 45248        111134  globalros red mini carnat (160 stems) includ f...
# 69064        119252  big ass fan 3600 144 in. yellow silver aluminu...
# 188479       180470  laura ashley freya 3-light weather cognac vani...
# 76169        121880  zamma beech block 5/8 in. thick x 3/4 in. wide...
# 157518       160367   hampton bay pine valley tile top patio side tabl
# 11984        102095  tire scienc 4 in. x 6 in. wheelbarrow tube sea...
# 200148       189102                          genuin joe dust mop frame
# 198022       187480         alpin 15 in. larg red bowl plastic planter
# 171923       169203                              ridgid tile saw stand
# 50034        112740  thermo-tex 12 ft. x 24 ft. 3-year rectangular ...
# 51369        113189      5 ft. x 30 ft. dalen product nylon trelli net
# 146217       153944            coleman roadtrip grill wheel carri case
# 188875       180762  artifactori 8 ft. fix length 1 in. dia. metal ...
# 137108       149071           viagrow strawberri planter vertic garden
# 108146       135002  daylight naturalight 22-watt energi save circu...
# 72456        120519  sticki pix remov reposition ultim wall sticker...
# 143520       152517  shanko 2 ft. x 2 ft. lay-in suspend grid ceil ...
# 96946        130140          pyle wall mount rotari volum control knob
# 139648       150400  thermo-tex 30 ft. 7-year round clear ground so...
# 73919        121054  eaton 125-amp ring type underground group mete...
# 201869       190460  control brand visbi 12-light gun metal black c...
# 6907         101183  ego 20 in. 56-volt lithium-ion cordless lawn m...
# 108375       135102  speedi-grill 24 in. x 6 in. base board return ...
# 208607       195824  radion hi tech elsta roma 3-light wood patina ...
# 199586       188671   ge choic alert wireless alarm system alarm siren
# 134157       147541           lithonia light led troffer dimmer switch
# 127467       144177  rustica hardwar 42 in. x 84 in. mountain moder...
# 146582       154163  tuscani coast 2-light weather charcoal outdoor...
# 742          100129          sundstrom safeti silicon half mask respir
# 216595       202450  great outdoor minka laveri kirkham 1-light bro...
# 90155        127352       intec force/2 next generat insul blow machin
#
#                     search_term  relevance          orig_search_term  \
# id
# 69679              topiari tree       1.00              topiary tree
# 156918             14 ft ladder       1.00              14 ft ladder
# 136808              side shield       1.00              side shields
# 120624              rachael ray       1.00               rachael ray
# 204530                bird stop       1.00                bird stops
# 104722             101-1h crane       1.00          101-1h for crane
# 176724              bronz green       1.00              bronze green
# 83392         rubbermaid cooler       1.33         rubbermaid cooler
# 9508         hot water tank gas       1.00        hot water tank gas
# 92432               granit sand       1.00             granite  sand
# 97371      terra cotta clay pot       1.33     terra cotta clay pots
# 17236                ant killer       1.00                ant killer
# 142618           fireplac paint       1.00           fireplace paint
# 101448             inlin switch       1.00             inline switch
# 37816                 paint cup       1.00                paint cups
# 93622               grape plant       1.00               grape plant
# 85851               grape plant       1.00               grape plant
# 96532             copper faucet       1.00             copper faucet
# 45195           circular sander       1.00           circular Sander
# 45248                 free ship       1.00             free shipping
# 69064                   big ass       1.00                   big ass
# 188479       laura ashley light       1.33     laura ashley lighting
# 76169               round beech       1.00               round beech
# 157518       ourdoor patio tile       1.00        ourdoor patio tile
# 11984     wheelbarrow tire tube       1.33  wheelbarrow tire no tube
# 200148               swffer mop       1.00                swffer mop
# 198022               alpin larg       1.00              alpine large
# 171923     ridgid josi tile saw       1.00     ridgid josie tile saw
# 50034             solar blanket       1.33             solar blanket
# 51369              mosquito net       1.00              mosquito net
# 146217            coleman grill       1.33             coleman grill
# 188875    continent rod end cap       1.00  continental rod end caps
# 137108               strawberri       1.00              strawberries
# 108146      full spectrum light       1.33       full spectrum light
# 72456                   sticker       1.33                   sticker
# 143520                   shanko       1.00                    shanko
# 96946        speaker wall mount       1.00        speaker wall mount
# 139648             ground clear       1.00              Ground Clear
# 73919               socket ring       1.00               socket ring
# 201869                 bran gun       1.00                  bran gun
# 6907     cordless electr blower       1.00  cordless electric blower
# 108375          2.4 white board       1.00           2.4 white board
# 208607                roam wood       1.00                 roam wood
# 199586  batteryfor alarm system       1.00   batteryfor alarm system
# 134157            troffer light       1.33          troffer lighting
# 127467        tilt wash hardwar       1.00        tilt wash hardware
# 146582          tuscani classic       1.00           tuscany classic
# 742                   face mask       1.00                face masks
# 216595             great outdor       1.00             great outdors
# 90155                      next       1.00                      next
#
#                                        orig_product_title  \
# id
# 69679            Romano 4 ft. Boxwood Spiral Topiary Tree
# 156918  Werner 14 ft. Fiberglass Round Rung Straight L...
# 136808  Earthquake 212cc Tiller Rear Tine CRT with Sid...
# 120624                Rachael Ray 10 qt. Covered Stockpot
# 204530      Heath Bird Stop Blue Ceramic Wild Bird Feeder
# 104722                DANCO Low Lead 1A-3C Stem for Crane
# 176724  Green Matters 3-Light Mahogany Bronze Vanity F...
# 83392             Rubbermaid FastTrack Garage Cooler Hook
# 9508    Sure Comfort 40 Gal. Tall 3 Year 34,000 BTU Na...
# 92432   Mont Blanc Northbrook Drop-in Composite Granit...
# 97371    Norcal Pottery 6 in. Terra Cotta Clay Azalea Pot
# 17236   Ortho Home Defense Max 1.33 Gal. Perimeter and...
# 142618  Builder&#39;s Choice Richmond 4 ft. x 3-3/4 in...
# 101448  Warehouse of Tiffany 21 in. Jewel Off White/Br...
# 37816   BEHR Premium Plus Ultra #PPU6-16 Cup of Tea Paint
# 93622   Daylily Grape Magic Bare Root Dormant Plants (...
# 85851   Oakland Living 26 in. Metal Grape Table Plant ...
# 96532   BrassCraft 3/8 in. O.D. x 36 in. Copper Faucet...
# 45195   Lincoln Electric 1-1/2 in. Circular Coarse Wir...
# 45248   Globalrose Red Mini Carnations (160 Stems) Inc...
# 69064   Big Ass Fans 3600 144 in. Yellow and Silver Al...
# 188479  Laura Ashley Freya 3-Light Weathered Cognac Va...
# 76169   Zamma Beech Blocked 5/8 in. Thick x 3/4 in. Wi...
# 157518  Hampton Bay Pine Valley Tile Top Patio Side Table
# 11984   Tire Science 4 in. x 6 in. Wheelbarrow Tube wi...
# 200148                         Genuine Joe Dust Mop Frame
# 198022       Alpine 15 in. Large Red Bowl Plastic Planter
# 171923                              RIDGID Tile Saw Stand
# 50034   Thermo-Tex 12 ft. x 24 ft. 3-Year Rectangular ...
# 51369   5 ft. x 30 ft. Dalen Products Nylon Trellis Ne...
# 146217       Coleman RoadTrip Grill Wheeled Carrying Case
# 188875  The Artifactory 8 ft. Fixed Length 1 in. Dia. ...
# 137108         Viagrow Strawberry Planter Vertical Garden
# 108146  Daylight Naturalight 22-Watt Energy Saving Cir...
# 72456   Sticky Pix Removable and Repositionable Ultima...
# 143520  Shanko 2 ft. x 2 ft. Lay-in Suspended Grid Cei...
# 96946          Pyle Wall Mount Rotary Volume Control Knob
# 139648  Thermo-Tex 30 ft. 7-Year Round Clear Above Gro...
# 73919   Eaton 125-Amp Ring Type Underground Group Mete...
# 201869  Control Brand Visby 12-Light Gun Metal Black C...
# 6907    EGO 20 in. 56-Volt Lithium-ion Cordless Lawn M...
# 108375  SPEEDI-GRILLE 24 in. x 6 in. Base Board Return...
# 208607  Radionic Hi Tech Elsta Roma 3-Light Wood Patin...
# 199586  GE Choice Alert Wireless Alarm System with Ala...
# 134157        Lithonia Lighting LED Troffer Dimmer Switch
# 127467  Rustica Hardware 42 in. x 84 in. Mountain Mode...
# 146582  Tuscany Coast 2-Light Weathered Charcoal Outdo...
# 742        Sundstrom Safety Silicone Half Mask Respirator
# 216595  the great outdoors by Minka Lavery Kirkham 1-L...
# 90155   Intec FORCE/2 Next Generation Insulation Blowi...
#
#                                                     descr  \
# id
# 69679   enhanc home romano boxwood spiral topiari tree...
# 156918  7114-1 one-sect round rung 14 ft. straight lad...
# 136808  earthquak 6015v rear tine rototil deliv ultim ...
# 120624  whether boil pasta, make batch chili cook grai...
# 204530  bird stop blue ceram wild bird feeder featur b...
# 104722  repair leaki faucet easi inexpens altern repla...
# 176724  cornerston collect quality, incandesc vaniti e...
# 83392   part fasttrack system, cooler hook perfect sol...
# 9508    sure comfort 40 gal. natur gas tall water heat...
# 92432   durabl granit composit materi provid mont blan...
# 97371   6.75 in. terra cotta pot craft porous terra co...
# 17236   ortho home defens max 1.33 gal. ready-to-us pe...
# 142618  add sens timeless beauti fireplac home decor f...
# 101448  tiffani style 21 in. jewel 1 light white tabl ...
# 37816   behr premium plus ultra interior paint primer ...
# 93622   daylili vigor perenni requir littl care garden...
# 85851   oakland live 26 in. metal grape tabl plant sta...
# 96532   brasscraft 3/8 in. o.d. tube x 36 in. length c...
# 45195   lincoln electr 1-1/2 in. circular coars wire b...
# 45248   mini red carnat grown environment greenhouses,...
# 69064   want air movement without noise. got it. big a...
# 188479  found 1953, laura ashley becom quintessenti en...
# 76169   beech block quarter round use accent transit b...
# 157518  pine valley 20 in. squar patio side tabl ideal...
# 11984   infus leak-stopper, tire scienc 4 in. x 6 in. ...
# 200148  mop frame design use genuin joe 02310 dust mop...
# 198022  bowl planter perfect patio decks. avail variet...
# 171923  made specif ridgid r4030 r4040 tile saws, stan...
# 50034   thermo-tex solar blanket extend swim season sa...
# 51369   heavy-duti nylon trelli net ideal grow tomatoe...
# 146217  inner strap secur hold inner pocket accommod c...
# 188875  artifactori fix length draperi hardwar made di...
# 137108  viagrow strawberri planter allow grow strawber...
# 108146  naturalight 22w energi save circular tube. nat...
# 72456   sticki pix home decor think life verb captur j...
# 143520  authent tin ceil tile produc use origin sand-c...
# 96946   volum control design mount standard electr wal...
# 139648  thermo-tex clear solar blanket extend swim sea...
# 73919   group metering, also known multipl metering, u...
# 201869  visbi chandeli twelv gun metal rod radiat core...
# 6907    perform gas without noise, mess fumes; mow 2 m...
# 108375  bbrag (base board return grille) durabl steel ...
# 208607  elsta roma 59.5 in. 3-light wood patina billia...
# 199586  ge choic alert wireless alarm system alarm sir...
# 134157  0- 10-volt wall dimmer switch lithonia light 2...
# 127467  combin eleg natur materi craftsmanship artist,...
# 146582  tuscani coast 2-light exterior post lamp weath...
# 742     sr 100 half mask air purifi respir intend use ...
# 216595  great outdoor minka laveri wall-mount 1-light ...
# 90155   forc 2 insul blower want need larger, stronger...
#
#                                                orig_descr  \
# id
# 69679   Enhance your home with a Romano Boxwood Spiral...
# 156918  The 7114-1 one-section round rung 14 ft. Strai...
# 136808  The Earthquake 6015V rear tine rototiller deli...
# 120624  Whether you're boiling pasta, making a batch o...
# 204530  The Bird Stop Blue Ceramic Wild Bird Feeder fe...
# 104722  Repairing a leaky faucet is an easy and inexpe...
# 176724  The cornerstone of this collection is quality,...
# 83392   Part of the FastTrack system, the Cooler Hook ...
# 9508    The Sure Comfort 40 Gal. Natural Gas Tall Wate...
# 92432   Durable granite composite material provides th...
# 97371   The 6.75 in. Terra Cotta Pot is crafted with p...
# 17236   The Ortho Home Defense Max 1.33 Gal. Ready-to-...
# 142618  Add a sense of timeless beauty to your firepla...
# 101448  The Tiffany Style 21 in. Jewel 1 Light off Whi...
# 37816   BEHR Premium Plus Ultra Interior Paint and Pri...
# 93622   Daylilies are vigorous perennial that require ...
# 85851   The Oakland Living 26 in. Metal Grape Table Pl...
# 96532   BrassCraft 3/8 in. O.D. tube x 36 in. length c...
# 45195   The Lincoln Electric 1-1/2 in. Circular Coarse...
# 45248   Mini Red carnations are grown in environmental...
# 69064   Want air movement without noise. You've got it...
# 188479  Founded in 1953, Laura Ashley has become a qui...
# 76169   Beech Blocked Quarter Round is used to accent ...
# 157518  The Pine Valley 20 in. Square Patio Side Table...
# 11984   Infused with leak-stopper, this Tire Science 4...
# 200148  Mop frame is designed for use with Genuine Joe...
# 198022  These bowl planters are perfect for patios and...
# 171923  Made specifically for the RIDGID R4030 and R40...
# 50034   Thermo-Tex Solar blankets will extend your Swi...
# 51369   Our heavy-duty nylon trellis netting is ideal ...
# 146217  With inner straps for a secure hold and inner ...
# 188875  Artifactory Fixed Length Drapery Hardware made...
# 137108  The Viagrow Strawberry Planter allows you to g...
# 108146  Naturalight 22W energy saving circular tube. N...
# 72456   With Sticky Pix Home Decor you can think of li...
# 143520  These authentic tin ceiling tiles are produced...
# 96946   The volume control is designed to be mounted i...
# 139648  Thermo-Tex clear Solar blankets will extend yo...
# 73919   Group metering, also known as multiple meterin...
# 201869  The Visby chandelier has twelve gun metal rods...
# 6907    The performance of gas without the noise, mess...
# 108375  BBRAG (Base Board Return Grille) is out of a d...
# 208607  The Elsta Roma 59.5 in. 3-Light Wood Patina Bi...
# 199586  The GE Choice Alert Wireless Alarm System Alar...
# 134157  The 0- to 10-Volt Wall Dimmer Switch for the L...
# 127467  Combining the elegance of natural materials wi...
# 146582  Tuscany Coast 2-Light Exterior Post Lamp In We...
# 742     The SR 100 half mask Air Purifying Respirator ...
# 216595  The great outdoors by Minka Lavery Wall-Mount ...
# 90155   The Force 2 is the insulation blower you want ...
#
#         match_product_title  match_descr    ...     descr_ind  pred_diff  \
# id                                          ...
# 69679              1.000000     1.000000    ...      0.092593   1.627411
# 156918             0.666667     0.666667    ...      0.064516   1.482803
# 136808             1.000000     0.000000    ...      1.000000   1.477143
# 120624             1.000000     0.500000    ...      0.440367   1.448947
# 204530             1.000000     1.000000    ...      0.000000   1.393136
# 104722             0.500000     0.500000    ...      0.514286   1.375360
# 176724             1.000000     0.500000    ...      0.109756   1.370850
# 83392              1.000000     0.500000    ...      0.051724   1.369197
# 9508               0.500000     1.000000    ...      0.027778   1.366897
# 92432              1.000000     1.000000    ...      0.008130   1.365866
# 97371              1.000000     1.000000    ...      0.035088   1.332952
# 17236              0.500000     0.500000    ...      0.121951   1.330209
# 142618             0.500000     1.000000    ...      0.039604   1.323682
# 101448             1.000000     0.000000    ...      1.000000   1.322145
# 37816              1.000000     0.500000    ...      0.040323   1.315260
# 93622              1.000000     1.000000    ...      0.515625   1.307798
# 85851              1.000000     1.000000    ...      0.084746   1.306378
# 96532              1.000000     1.000000    ...      0.126582   1.285594
# 45195              0.500000     0.500000    ...      0.114286   1.273263
# 45248              1.000000     0.500000    ...      0.712871   1.266180
# 69064              1.000000     1.000000    ...      0.052632   1.264884
# 188479             1.000000     1.000000    ...      0.037037   1.263905
# 76169              1.000000     1.000000    ...      0.000000   1.262170
# 157518             0.666667     0.666667    ...      0.058824   1.259831
# 11984              1.000000     1.000000    ...      0.036364   1.255951
# 200148             0.500000     0.500000    ...      0.000000   1.251896
# 198022             1.000000     0.000000    ...      1.000000   1.247469
# 171923             0.750000     0.750000    ...      0.028571   1.235192
# 50034              1.000000     1.000000    ...      0.014286   1.235059
# 51369              0.500000     0.500000    ...      0.045455   1.230090
# 146217             1.000000     1.000000    ...      0.180000   1.227683
# 188875             0.750000     0.750000    ...      0.318841   1.220887
# 137108             1.000000     1.000000    ...      0.015385   1.219895
# 108146             0.333333     1.000000    ...      0.168421   1.218621
# 72456              1.000000     0.000000    ...      1.000000   1.218539
# 143520             1.000000     0.000000    ...      1.000000   1.217516
# 96946              0.666667     1.000000    ...      0.061224   1.216811
# 139648             1.000000     0.500000    ...      0.012346   1.216732
# 73919              1.000000     0.500000    ...      0.403509   1.213388
# 201869             0.500000     0.500000    ...      0.063830   1.212338
# 6907               0.333333     0.000000    ...      1.000000   1.204327
# 108375             0.666667     0.666667    ...      0.018868   1.203367
# 208607             0.500000     0.500000    ...      0.078125   1.201393
# 199586             0.666667     0.666667    ...      0.020513   1.200486
# 134157             1.000000     1.000000    ...      0.076923   1.200056
# 127467             0.666667     0.333333    ...      0.129870   1.194579
# 146582             0.500000     1.000000    ...      0.000000   1.194260
# 742                0.500000     1.000000    ...      0.026316   1.193370
# 216595             0.500000     0.500000    ...      0.000000   1.191889
# 90155              1.000000     0.000000    ...      1.000000   1.188711
#
#         words_std_title  words_std_descr  len_title  len_descr  \
# id
# 69679          0.250000        16.000000          7         54
# 156918         9.000000         2.250000         16         62
# 136808         0.250000         0.000000          8         47
# 120624         0.250000         0.000000          6        109
# 204530         0.250000         0.250000          8         50
# 104722         0.000000         0.000000          6         35
# 176724         4.000000         0.000000          7         82
# 83392          2.250000         0.000000          5         58
# 9508           0.250000       281.187500         13        180
# 92432         20.250000       256.000000         15        123
# 97371          2.187500       108.500000          9         57
# 17236          0.000000         0.000000         11         82
# 142618         0.000000       196.000000         12        101
# 101448         0.250000         0.000000         10         71
# 37816          1.000000         0.000000          8        124
# 93622          6.250000         6.250000          8         64
# 85851          1.000000         1.000000          9         59
# 96532          0.250000         1.000000         11         79
# 45195          0.000000         0.000000          8         35
# 45248          0.250000         0.000000          9        101
# 69064          0.250000         0.250000         12        133
# 188479         9.555556       112.666667          8         54
# 76169         56.250000         2.250000         18         83
# 157518         1.000000        49.000000          9         85
# 11984         12.666667        14.888889         10         55
# 200148         0.000000         0.000000          5         70
# 198022         2.250000         0.000000          8         33
# 171923         0.666667       314.000000          4         70
# 50034          1.000000         0.250000         13         70
# 51369          0.000000         0.000000         10         66
# 146217         1.000000         1.000000          6         50
# 188875         2.888889         9.555556         17         69
# 137108         0.000000         0.000000          5         65
# 108146         0.000000         0.666667          9         95
# 72456          0.000000         0.000000         11         52
# 143520         0.000000         0.000000         18         86
# 96946          0.250000        14.000000          7         49
# 139648         0.250000         0.000000         10         81
# 73919          6.250000         0.000000          8         57
# 201869         0.000000         0.000000          8         47
# 6907           0.000000         0.000000          8         85
# 108375        12.250000        49.000000         15        106
# 208607         0.000000         0.000000         11         64
# 199586         0.250000         0.250000          8        195
# 134157         1.000000        12.250000          6         78
# 127467        20.250000         0.000000         20         77
# 146582         0.000000        20.250000          8         29
# 742            0.000000       324.000000          6        114
# 216595         0.000000         0.000000         11         52
# 90155          0.000000         0.000000          7        185
#
#        last_word_title  last_word_descr   bad  bad_pred
# id
# 69679                1                1  True  0.064587
# 156918               1                1  True  0.189142
# 136808               1                0  True  0.103526
# 120624               1                0  True  0.088333
# 204530               1                1  True  0.183157
# 104722               1                1  True  0.063852
# 176724               1                0  True  0.165830
# 83392                1                1  True  0.184175
# 9508                 1                1  True  0.171904
# 92432                1                1  True  0.123621
# 97371                1                1  True  0.103490
# 17236                1                1  True  0.062361
# 142618               1                1  True  0.234840
# 101448               1                0  True  0.294587
# 37816                1                0  True  0.314901
# 93622                1                1  True  0.215977
# 85851                1                1  True  0.297951
# 96532                1                1  True  0.112051
# 45195                0                0  True  0.273819
# 45248                1                1  True  0.121718
# 69064                1                1  True  0.217440
# 188479               1                1  True  0.061171
# 76169                1                1  True  0.219598
# 157518               1                1  True  0.212885
# 11984                1                1  True  0.257461
# 200148               1                1  True  0.098964
# 198022               1                0  True  0.331033
# 171923               1                1  True  0.221551
# 50034                1                1  True  0.212399
# 51369                1                1  True  0.074628
# 146217               1                1  True  0.123894
# 188875               1                1  True  0.370448
# 137108               1                1  True  0.090717
# 108146               1                1  True  0.064751
# 72456                1                1  True  0.091803
# 143520               1                0  True  0.239551
# 96946                1                1  True  0.060595
# 139648               1                1  True  0.346244
# 73919                1                1  True  0.145289
# 201869               1                1  True  0.137057
# 6907                 0                0  True  0.122808
# 108375               1                1  True  0.521683
# 208607               1                1  True  0.052271
# 199586               1                1  True  0.098364
# 134157               1                1  True  0.073274
# 127467               1                1  True  0.088066
# 146582               0                1  True  0.144357
# 742                  1                1  True  0.114839
# 216595               0                0  True  0.104748
# 90155                1                0  True  0.367653
#
# [50 rows x 29 columns]

# %%
@np.vectorize
def word_match_count(search_term, text):
    count = 0
    search_term = search_term.split()
    text = text.split()
    if len(search_term) == 0:
        return 0
    for word in set(search_term):
        count += 1 if text.count(word) > 0 else 0
    return count / len(search_term)

# %%
train['match_orig_title'] = word_match_count(train['search_term'], train['orig_product_title'])
train['match_orig_descr'] = word_match_count(train['search_term'], train['orig_descr'])
test['match_orig_title'] = word_match_count(test['search_term'], test['orig_product_title'])
test['match_orig_descr'] = word_match_count(test['search_term'], test['orig_descr'])

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr', 'len_title', 'len_descr', 'last_word_title',
             'last_word_descr', 'match_orig_title', 'match_orig_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=20))]))
                    ]
            ))])
clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])
X_test = clf.transform(test[use_cols])

# %%
gbm_best.fit(X_train, y)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=0.5,
#        importance_type='split', learning_rate=0.03, max_depth=-1,
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=700, n_jobs=-1, num_leaves=80, objective=None,
#        random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = gbm_best.predict(X_test)
y_pred[y_pred>3.] = 3.
y_pred[y_pred<1.] = 1.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47370

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr', 'len_title', 'len_descr', 'last_word_title',
             'last_word_descr', 'match_orig_title', 'match_orig_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=20))]))
                    ],
                transformer_weights = {
                    'cst': 1.0,
                    'txt1': 0.5,
                    'txt2': 0.25,
                    'txt3': 0.01,
                    'txt4': 0.5
                    }
            ))])
clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])
X_test = clf.transform(test[use_cols])

# %%
gbm_best.fit(X_train, y)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=0.5,
#        importance_type='split', learning_rate=0.03, max_depth=-1,
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=700, n_jobs=-1, num_leaves=80, objective=None,
#        random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = gbm_best.predict(X_test)
y_pred[y_pred>3.] = 3.
y_pred[y_pred<1.] = 1.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %%
gbm_best.feature_importances_
# Out:
# array([317, 205, 191, 608, 280,  58, 196, 556, 409, 139, 220, 273, 281,
#         86,  67,  99,  93, 292, 268, 269, 220, 217, 229, 250, 246, 200,
#        229, 223, 217, 198, 218, 265, 221, 221, 212, 255, 239, 232, 216,
#        258, 224, 228, 281, 254, 220, 216, 212, 189, 255, 222, 245, 265,
#        203, 263, 245, 276, 267, 222, 222, 269, 266, 187, 209, 234, 253,
#        200, 208, 234, 185, 222, 282, 234, 275, 244, 235, 231, 244, 308,
#        231, 221, 351, 231, 278, 242, 271, 241, 285, 245, 243, 335, 277,
#        227, 320, 255, 274, 263, 303, 253, 202, 245, 232, 203, 194, 199,
#        254, 191, 181, 206, 206, 185, 168, 199, 160, 197, 201, 188, 222,
#        178, 177, 161, 166, 205, 224, 171, 218, 174, 196, 177, 207, 190,
#        161, 234, 229, 229, 239, 187, 188, 189, 181, 226, 211, 156, 203,
#        210, 193, 196, 209, 169, 199, 185, 191, 238, 202, 220, 316, 161,
#        218, 209, 234, 228, 227, 173, 211, 209, 239, 205, 198, 213, 261,
#        186, 235, 243, 221, 220, 214, 215, 198, 325, 204, 204, 213, 228,
#        181, 159, 233, 172, 195, 191, 196, 208, 220, 223, 193, 211, 199,
#        253, 195, 208, 175, 218, 199, 233, 230, 196, 204, 216, 202, 221,
#        214, 174, 230, 208, 228, 205, 196, 193, 226, 236, 186, 227, 222,
#        205, 200, 249, 193, 225, 191, 244, 226, 222, 285, 236, 200, 242,
#        227, 202, 225, 110, 111,  94, 219, 134, 135, 128,  99, 105, 130,
#        131, 112, 122, 135, 126, 118, 117, 120, 103, 125])

# %%
train.drop(columns=['pred_diff'], inplace=True)
train['pred_diff'] = (train['relevance'] - model.predict(X_train))
train.sort_values(['pred_diff'], ascending=False)[:50]
# Out:
#         product_uid                                      product_title  \
# id
# 207064       194599  home legend distress lennox hickori 3/8 in. th...
# 203914       192088  behr premium plus #600e-2 harbor mist zero voc...
# 194147       184559  lenmar nickel-met hydrid 1200mah/3.6-volt cord...
# 116307       138721   behr premium plus ultra #ecc-38-3 sea fern paint
# 78785        122860  american standard green tea ecosil 6 ft. x 42 ...
# 114403       137867          extech instrument carbon monoxid co meter
# 181669       175688  cap tread cross wood 94 in. long x 12-1/8 in. ...
# 201248       189965  bdk warner brother batman carpet floor mat (4-...
# 193001       183692  lichtenberg white no. 918 millenni ryan heathe...
# 72273        120449  scott handi green ii 1,000 sq. ft. handheld sp...
# 185380       178276  home decor collect assembl 30x15x24 in. wall d...
# 42809        110370                           pro-lab asbesto test kit
# 83558        124699             beapco drop-in fruit fli trap (6-pack)
# 14019        102456  custom build product versabond gray 50 lb. for...
# 185512       178376  behr premium plus ultra 1-gal. #p460-5 fiji se...
# 141074       151168  aspect squar mat 12 in. x 4 in. metal decor ti...
# 72911        120678  ekena millwork 1-1/4 in. x 80 in. x 5-1/2 in. ...
# 211452       198172  splashback tile cleveland bendem mini brick 10...
# 209900       196878  behr premium plus ultra 5-gal. #p520-5 boat ho...
# 211050       197843  bluworld water classic quarri larg nojoqui fal...
# 218645       204191  fan essenti 1 ft. x 1-1/2 ft. bois state unive...
# 128765       144833  certainte membrain 100 in. x 50 ft. air barrie...
# 205903       193675  south shore furnitur majest 6-drawer dresser p...
# 34178        107737  1/4 in. x 2 ft. x 2 ft. purebond hickori plywo...
# 209550       196604         john deer nitril coat ladi larg grip glove
# 113218       137331  halo 4 in. 2700k matt white recess retrofit ba...
# 116075       138620  fan essenti 1 ft. x 1-1/2 ft. arizona state un...
# 72011        120349  master flow flexright flexibl duct elbow - 4 i...
# 170606       168347  safavieh harlow flat cream birchwood bicast le...
# 186244       178892          home depot 24 in. x 100 ft. bubbl cushion
# 208561       195785  legend valv 1/4 turn frost free faucet soft to...
# 66669        118413     j-b weld 2 oz. j-b steelstik epoxi putti stick
# 182365       176170   qep 7-1/2 in. x 5-1/2 in. x 2 in. microfib spong
# 150259       156172  pittsburgh corn 24 in. x 24 in. lightwis icesc...
# 160756       162275  ortho weed-b-gon 32 oz. max plus crabgrass con...
# 92980        128509  zamma hand scrape canyon grenadillo 7/16 in. t...
# 209421       196497     halex 2 in. rigid thread aluminum conduit bodi
# 19910        103605      halex 2 in. rigid plastic insul bush (4-pack)
# 64013        117485     liberti garden heavi duti wall-mount hose rack
# 60771        116340  kidd intellig batteri oper combin smoke carbon...
# 178375       173435  lehigh 60 lb. x 3-3/8 in. x 9/16 in. brass rou...
# 62723        117020  lifesmart 50 squar foot filter cartridg lifesm...
# 200236       189169        viagrow 3 in. net pot nurseri pot (50-pack)
# 42078        110136  fiskar staysharp max 18 in. push reel lawn mow...
# 204918       192872  halo 5 in. 6 in. 3500k matt white recess retro...
# 64910        117795         fix-a-flat ultim 1-step tire repair inflat
# 82008        124107  cap tread glenwood oak 47 in. long x 12-1/8 in...
# 145318       153437  kidd worri free hardwir 120-volt interconnect ...
# 83205        124567    carlon 1/2 in. pvc type-t conduit bodi (case 8)
# 69564        119436              southern ag 8 oz. triple-act neem oil
#
#                           search_term  relevance  \
# id
# 207064                          ennox       3.00
# 203914                 locit 2 plus 1       3.00
# 194147           polish batteri metal       3.00
# 116307                            fen       3.00
# 78785               arctic air ast28r       3.00
# 114403                         carboy       3.00
# 181669           wood chip best cover       3.00
# 201248                            vdk       3.00
# 193001                        w g 918       3.00
# 72273                           grqss       3.00
# 185380                  30 light door       3.00
# 42809                            labo       3.00
# 83558                            gnat       3.00
# 14019                          canyon       3.00
# 185512                           fija       3.00
# 141074              decor metal sceen       3.00
# 72911                 1 1/4 pvcsch 80       3.00
# 211452      cleveland ohio mini excav       3.00
# 209900              blue boat chlorin       3.00
# 211050                 marbl etch kit       3.00
# 218645               metal garden cts       3.00
# 128765                          unsul       3.00
# 205903                         treser       3.00
# 34178                        surebond       3.00
# 209550           work hope glove pink       3.00
# 113218                         mmodel       2.67
# 116075                           gard       2.67
# 72011        4 inch back flow prenter       3.00
# 170606             frame nail hitschi       3.00
# 186244             home depot cambrig       3.00
# 208561  continent soft touch shut-off       3.00
# 66669            b&d .08 string spool       3.00
# 182365                         spaong       3.00
# 150259                       242x24x6       3.00
# 160756           b&d .08 string spool       3.00
# 92980                mold sku 237-752       3.00
# 209421              aluminum pipe 1x1       3.00
# 19910             2 1/2in conduit pvc       3.00
# 64013              garden hose hanger       3.00
# 60771              co2 detector kiddi       3.00
# 178375               quick snap punch       3.00
# 62723            cartridg filter fosl       3.00
# 200236                           clab       2.67
# 42078                          manual       3.00
# 204918                         mmodel       2.67
# 64910            fix flat tire sensor       3.00
# 82008         deep frezer glass cover       2.67
# 145318           batteri backup timer       3.00
# 83205             type hibiscus plant       3.00
# 69564                            flea       3.00
#
#                        orig_search_term  \
# id
# 207064                            ennox
# 203914                  locite 2 plus 1
# 194147           polisher battery metal
# 116307                              fen
# 78785                 arctic air ast28r
# 114403                           carboy
# 181669         wood chips best to cover
# 201248                              vdk
# 193001                          w g 918
# 72273                             grqss
# 185380                    30 light door
# 42809                              labo
# 83558                              gnat
# 14019                            canyon
# 185512                             fija
# 141074           decorative metal sceen
# 72911                   1 1/4 pvcsch 80
# 211452    cleveland ohio mini excavator
# 209900               blue boat chlorine
# 211050                  marble etch kit
# 218645                 metal garden cts
# 128765                       unsulation
# 205903                          tresers
# 34178                          surebond
# 209550        work for hope gloves pink
# 113218                           mmodel
# 116075                            garde
# 72011          4 inch back flow prenter
# 170606               frame nail hitschi
# 186244           home depot in cambrige
# 208561  continental soft touch shut-off
# 66669              b&d .08 string spool
# 182365                         spaonges
# 150259                         242x24x6
# 160756             b&d .08 string spool
# 92980               molding sku 237-752
# 209421                aluminum pipe 1x1
# 19910               2 1/2in conduit pvc
# 64013               garden hose hangers
# 60771               co2 detector kiddie
# 178375                 quick snap punch
# 62723            cartridge filter fosle
# 200236                             clab
# 42078                            manual
# 204918                           mmodel
# 64910       fix a flat for tire sensors
# 82008      deep frezer with glass cover
# 145318            battery backup timers
# 83205          types of hibiscus plants
# 69564                              flea
#
#                                        orig_product_title  \
# id
# 207064  Home Legend Distressed Lennox Hickory 3/8 in. ...
# 203914  BEHR Premium Plus #600E-2 Harbor Mist Zero VOC...
# 194147  Lenmar Nickel-Metal Hydride 1200mAh/3.6-Volt C...
# 116307   BEHR Premium Plus Ultra #ECC-38-3 Sea Fern Paint
# 78785   American Standard Green Tea EcoSilent 6 ft. x ...
# 114403        Extech Instruments Carbon Monoxide CO Meter
# 181669  Cap A Tread Cross Wood 94 in. Long x 12-1/8 in...
# 201248  BDK Warner Brothers Batman Carpet Floor Mats (...
# 193001  LICHTENBERG White No. 918 Millennial Ryan Heat...
# 72273   Scotts Handy Green II 1,000 sq. ft. Handheld S...
# 185380  Home Decorators Collection Assembled 30x15x24 ...
# 42809                           PRO-LAB Asbestos Test Kit
# 83558            BEAPCO Drop-Ins Fruit Fly Traps (6-Pack)
# 14019   Custom Building Products VersaBond Gray 50 lb....
# 185512  BEHR Premium Plus Ultra 1-gal. #P460-5 Fiji Se...
# 141074  Aspect Square Matted 12 in. x 4 in. Metal Deco...
# 72911   Ekena Millwork 1-1/4 in. x 80 in. x 5-1/2 in. ...
# 211452  Splashback Tile Cleveland Bendemeer Mini Brick...
# 209900  BEHR Premium Plus Ultra 5-gal. #P520-5 Boat Ho...
# 211050  Bluworld of Water Classic Quarry Large Nojoqui...
# 218645  Fan Essentials 1 ft. x 1-1/2 ft. Boise State U...
# 128765  CertainTeed MemBrain 100 in. x 50 ft. Air Barr...
# 205903  South Shore Furniture Majestic 6-Drawer Dresse...
# 34178   1/4 in. x 2 ft. x 2 ft. PureBond Hickory Plywo...
# 209550  John Deere Nitrile Coated Ladies Large Grip Gl...
# 113218  Halo 4 in. 2700K Matte White Recessed Retrofit...
# 116075  Fan Essentials 1 ft. x 1-1/2 ft. Arizona State...
# 72011   Master Flow FlexRIGHT Flexible Duct Elbow - 4 ...
# 170606  Safavieh Harlow Flat Cream Birchwood Bicast Le...
# 186244     The Home Depot 24 in. x 100 ft. Bubble Cushion
# 208561  LEGEND VALVE 1/4 Turn Frost Free Faucet with S...
# 66669      J-B Weld 2 oz. J-B SteelStik Epoxy Putty Stick
# 182365  QEP 7-1/2 in. x 5-1/2 in. x 2 in. Microfiber S...
# 150259  Pittsburgh Corning 24 in. x 24 in. LightWise I...
# 160756  Ortho Weed-B-Gon 32 oz. Max Plus Crabgrass Con...
# 92980   Zamma Hand Scraped Canyon Grenadillo 7/16 in. ...
# 209421   Halex 2 in. Rigid Threaded Aluminum Conduit Body
# 19910   Halex 2 in. Rigid Plastic Insulated Bushing (4...
# 64013    Liberty Garden Heavy Duty Wall-Mounted Hose Rack
# 60771   Kidde Intelligent Battery Operated Combination...
# 178375  Lehigh 60 lb. x 3-3/8 in. x 9/16 in. Brass Rou...
# 62723   Lifesmart 50 Square Foot Filter Cartridge for ...
# 200236        Viagrow 3 in. Net Pot Nursery Pot (50-Pack)
# 42078   Fiskars StaySharp Max 18 in. Push Reel Lawn Mo...
# 204918  Halo 5 in. and 6 in. 3500K Matte White Recesse...
# 64910   Fix-A-Flat Ultimate 1-Step Tire Repair and Inf...
# 82008   Cap A Tread Glenwood Oak 47 in. Long x 12-1/8 ...
# 145318  Kidde Worry Free Hardwired 120-Volt Interconne...
# 83205   Carlon 1/2 in. PVC Type-T Conduit Body (Case o...
# 69564            Southern Ag 8 oz. Triple-Action Neem Oil
#
#                                                     descr  \
# id
# 207064  78 in. length, hardwood veneer carpet reduc ov...
# 203914  behr premium plus zero voc, self-prim interior...
# 194147  power panasonic, american telecom, tele-phone,...
# 116307  behr premium plus ultra semi-gloss enamel inte...
# 78785   luxury, pure simple. modern acryl tub featur e...
# 114403  check co level easi push 1 button model c010, ...
# 181669  cap tread durabl vinyl pre-attach stair nosing...
# 201248  warner brother batman carpet floor mat enhanc ...
# 193001  no. 918 millenni ryan heather textur semi-sh c...
# 72273   scott handi green ii 1,000 sq. ft. handheld sp...
# 185380  strike grain weston light oak collect highligh...
# 42809   asbesto miner occur natur environ made long, t...
# 83558   beapco drop-in fruit fli trap give home owner ...
# 14019   custom build product versabond 50 lb. fortifi ...
# 185512  perfect pop color give home serious curb appea...
# 141074  get look high-end, design kitchen fraction cos...
# 72911   make plan design improv home office, one easie...
# 211452  ideal tile kitchen backsplash bathroom surface...
# 209900  add stun splash color home interior accent beh...
# 211050  make last impress bluworld new rock solid "cla...
# 218645  offici licens fan essenti ncaa 18 in. x 12.5 i...
# 128765  moistur wall unavoidable, manag easi membrain ...
# 205903  majest pure black 6-drawer dresser timeless lo...
# 34178   purebond plywood project panel conveni cost-ef...
# 209550  john deer micro-foam nitril coat grip glove se...
# 113218  halo rl4 seri consist retrofit led module-trim...
# 116075  offici licens fan essenti ncaa 18 in. x 12.5 i...
# 72011   kink flexibl duct caus restrict airflow excess...
# 170606  harlow ring chair made eleg add distinguish lo...
# 186244  protect fragil item move ship 3/16 in. x 24 in...
# 208561  anti-siphon frost-fre sillcock come patent sof...
# 66669   repair rebuild anyth made metal j-b weld co. 2...
# 182365  qep microfib polish spong ideal grout cleanup ...
# 150259  use lightwis pittsburgh corn aluminum-clad gla...
# 160756  ortho weed-b-gon max plus crabgrass control co...
# 92980   handscrap canyon grenadillo t-mold finish touc...
# 209421  halex 2 in. thread aluminum conduit bodi desig...
# 19910   halex 2 in. plastic insul bush (4-pack) design...
# 64013   liberti garden product heavi duti wall-mount h...
# 60771   intellig combin alarm offer famili protect fir...
# 178375  lehigh 60 lb. 3-3/8 in. x 9/16 in. brass round...
# 62723   make sure spa alway safe guests. 50 squar foot...
# 200236  use net pot allow root grow mesh better breath...
# 42078   former momentum reel mower, staysharp max reel...
# 204918  halo rl56 seri complet led baffle-trim modul 5...
# 64910   univers pistol holster great accessori keep ha...
# 82008   cap tread durabl lamin pre-attach stair nosing...
# 145318  new kidd 120 volt hardwired-interconnect 10 ye...
# 83205   carlon 1/2 in. non-metal type conduit bodi non...
# 69564   southern ag 8 oz. concentr triple-act neem oil...
#
#                                                orig_descr  \
# id
# 207064  78 in. length, hardwood veneer carpet reducer ...
# 203914  BEHR Premium Plus Zero VOC, Self-Priming Inter...
# 194147  Power your Panasonic, American Telecom, Tele-P...
# 116307  BEHR Premium Plus Ultra Semi-Gloss Enamel Inte...
# 78785   Luxury, pure and simple. This modern acrylic t...
# 114403  Checking co levels is as easy as pushing just ...
# 181669  Cap A Tread is a durable vinyl with pre-attach...
# 201248  Warner Brothers Batman carpet floor mats will ...
# 193001  No. 918 Millennial Ryan heathered texture semi...
# 72273   The Scotts Handy Green II 1,000 sq. ft. Handhe...
# 185380  The striking grain of the Weston Light Oak Col...
# 42809   Asbestos is a mineral that occurs naturally in...
# 83558   BEAPCO Drop-Ins Fruit Fly Traps give home owne...
# 14019   Custom Building Products VersaBond 50 lb. Fort...
# 185512  For a perfect pop of color that will give your...
# 141074  Get the look of a high-end, designer kitchen a...
# 72911   When making plans for design improvements to t...
# 211452  An ideal tile for a kitchen backsplash or bath...
# 209900  Add a stunning splash of color to your home's ...
# 211050  Make a lasting impression with Bluworld's new ...
# 218645  This officially licensed Fan Essentials NCAA 1...
# 128765  Moisture in walls is unavoidable, but managing...
# 205903  This Majestic Pure Black 6-Drawer Dresser has ...
# 34178   PureBond plywood project panels are a convenie...
# 209550  John Deere micro-foam nitrile coated grip glov...
# 113218  Halo RL4 Series consists of retrofit LED Modul...
# 116075  This officially licensed Fan Essentials NCAA 1...
# 72011   Kinked flexible ducts cause restricted airflow...
# 170606  The Harlow ring chair is made with elegancy an...
# 186244  Protect fragile items while moving and shippin...
# 208561  Anti-siphon frost-free sillcock comes with pat...
# 66669   Repair or rebuild anything made of metal with ...
# 182365  The QEP Microfiber Polishing Sponge is ideal f...
# 150259  Use the LightWise Pittsburgh Corning Aluminum-...
# 160756  Ortho Weed-B-Gon Max Plus Crabgrass Control Co...
# 92980   Handscraped Canyon Grenadillo T-Molding is the...
# 209421  The Halex 2 in. Threaded Aluminum Conduit Body...
# 19910   The Halex 2 in. Plastic Insulated Bushings (4-...
# 64013   The Liberty Garden Products Heavy Duty Wall-Mo...
# 60771   Intelligent combination alarm offers you and y...
# 178375  This Lehigh 60 lb. 3-3/8 in. x 9/16 in. Brass ...
# 62723   Make sure your spa is always safe for you and ...
# 200236  Using Net Pots allows the roots to grow throug...
# 42078   Formerly the Momentum Reel Mower, The StayShar...
# 204918  The Halo RL56 Series is a complete LED Baffle-...
# 64910   Universal pistol holsters are a great accessor...
# 82008   Cap A Tread is a durable laminate with pre-att...
# 145318  NEW Kidde 120 Volt Hardwired-Interconnected 10...
# 83205   The Carlon 1/2 in. Non-Metallic Type T Conduit...
# 69564   The Southern Ag 8 oz. Concentrated Triple-Acti...
#
#         match_product_title  match_descr    ...      words_std_descr  \
# id                                          ...
# 207064             0.000000     0.000000    ...                 0.00
# 203914             0.250000     0.500000    ...               529.00
# 194147             0.333333     0.333333    ...                 0.00
# 116307             0.000000     0.000000    ...                 0.00
# 78785              0.666667     0.333333    ...                 0.00
# 114403             0.000000     0.000000    ...                 0.00
# 181669             0.500000     0.000000    ...                 0.00
# 201248             0.000000     0.000000    ...                 0.00
# 193001             0.666667     0.333333    ...                 0.00
# 72273              0.000000     0.000000    ...                 0.00
# 185380             0.666667     0.666667    ...                30.25
# 42809              0.000000     0.000000    ...                 0.00
# 83558              0.000000     0.000000    ...                 0.00
# 14019              0.000000     0.000000    ...                 0.00
# 185512             0.000000     0.000000    ...                 0.00
# 141074             0.666667     0.333333    ...                 0.00
# 72911              0.250000     0.000000    ...                 0.00
# 211452             0.500000     0.500000    ...                 1.00
# 209900             0.333333     0.000000    ...                 0.00
# 211050             0.666667     0.000000    ...                 0.00
# 218645             0.666667     0.666667    ...               625.00
# 128765             0.000000     0.000000    ...                 0.00
# 205903             0.000000     0.000000    ...                 0.00
# 34178              0.000000     0.000000    ...                 0.00
# 209550             0.250000     0.250000    ...                 0.00
# 113218             0.000000     0.000000    ...                 0.00
# 116075             0.000000     0.000000    ...                 0.00
# 72011              0.400000     0.200000    ...                 0.00
# 170606             0.000000     0.333333    ...                 0.00
# 186244             0.666667     0.000000    ...                 0.00
# 208561             0.500000     0.000000    ...                 0.00
# 66669              0.000000     0.000000    ...                 0.00
# 182365             0.000000     0.000000    ...                 0.00
# 150259             0.000000     0.000000    ...                 0.00
# 160756             0.000000     0.000000    ...                 0.00
# 92980              0.000000     0.333333    ...                 0.00
# 209421             0.333333     0.333333    ...                 0.00
# 19910              0.250000     0.250000    ...                 0.00
# 64013              0.666667     0.666667    ...                 6.25
# 60771              0.000000     0.000000    ...                 0.00
# 178375             0.000000     0.333333    ...                 0.00
# 62723              0.666667     0.333333    ...                 0.00
# 200236             0.000000     0.000000    ...                 0.00
# 42078              0.000000     0.000000    ...                 0.00
# 204918             0.000000     0.000000    ...                 0.00
# 64910              0.250000     0.250000    ...                 0.00
# 82008              0.500000     0.000000    ...                 0.00
# 145318             0.666667     0.333333    ...                 0.00
# 83205              0.000000     0.333333    ...                 0.00
# 69564              0.000000     0.000000    ...                 0.00
#
#         len_title  len_descr  last_word_title  last_word_descr   bad  \
# id
# 207064         20         89                1                1  True
# 203914         10         93                0                1  True
# 194147          8         81                0                0  True
# 116307          8        111                0                0  True
# 78785          16         95                0                0  True
# 114403          6         76                0                0  True
# 181669         23         45                1                0  True
# 201248          8         81                0                0  True
# 193001         18         56                1                1  True
# 72273           9         64                0                0  True
# 185380         13        193                1                1  True
# 42809           4         63                0                0  True
# 83558           6        156                0                0  True
# 14019          10         84                0                0  True
# 185512         11        133                0                0  True
# 141074         15         71                0                0  True
# 72911          14        122                1                0  True
# 211452         20        169                0                0  True
# 209900         12        115                0                0  True
# 211050         15        155                1                1  True
# 218645         17         67                0                0  True
# 128765         12        140                0                0  True
# 205903          8         83                0                0  True
# 34178          13        111                0                0  True
# 209550          8         39                0                0  True
# 113218         14         99                0                0  True
# 116075         13         64                1                1  True
# 72011          15         60                0                0  True
# 170606         11         78                0                0  True
# 186244          9         83                0                0  True
# 208561         16         38                0                0  True
# 66669           9         58                0                0  True
# 182365         11         58                0                0  True
# 150259         14         40                0                0  True
# 160756          9         65                0                0  True
# 92980          18         89                0                0  True
# 209421          8         34                0                0  True
# 19910           8         35                0                0  True
# 64013           7         54                0                0  True
# 60771          11        132                0                0  True
# 178375         14         38                0                0  True
# 62723          15         42                0                0  True
# 200236          8         69                0                0  True
# 42078          10        171                0                0  True
# 204918         17        110                0                0  True
# 64910           6         46                0                0  True
# 82008          21         50                1                0  True
# 145318         14         55                0                0  True
# 83205           9         50                0                0  True
# 69564           7         73                0                0  True
#
#         bad_pred  match_orig_title  match_orig_descr  pred_diff
# id
# 207064  0.318959          0.000000          0.000000   1.242307
# 203914  0.051446          0.000000          0.250000   1.192145
# 194147  0.106693          0.000000          0.000000   1.144559
# 116307  0.232118          0.000000          0.000000   1.097668
# 78785   0.242641          0.000000          0.333333   1.091517
# 114403  0.245047          0.000000          0.000000   1.072386
# 181669  0.135103          0.000000          0.000000   1.072193
# 201248  0.080473          0.000000          0.000000   1.067600
# 193001  0.308694          0.333333          0.333333   1.063746
# 72273   0.085003          0.000000          0.000000   1.053112
# 185380  0.169871          0.000000          0.666667   1.025063
# 42809   0.075905          0.000000          0.000000   1.023328
# 83558   0.110914          0.000000          0.000000   1.013755
# 14019   0.170664          0.000000          0.000000   1.011150
# 185512  0.165072          0.000000          0.000000   1.004868
# 141074  0.485583          0.000000          0.333333   1.004104
# 72911   0.075405          0.250000          0.000000   0.997485
# 211452  0.392474          0.000000          0.000000   0.994232
# 209900  0.102414          0.000000          0.000000   0.992588
# 211050  0.103733          0.000000          0.000000   0.986977
# 218645  0.138681          0.000000          0.333333   0.981658
# 128765  0.085981          0.000000          0.000000   0.967639
# 205903  0.154209          0.000000          0.000000   0.956628
# 34178   0.392126          0.000000          0.000000   0.955642
# 209550  0.152315          0.000000          0.000000   0.950631
# 113218  0.069204          0.000000          0.000000   0.950501
# 116075  0.173399          0.000000          0.000000   0.949102
# 72011   0.086094          0.200000          0.200000   0.946595
# 170606  0.318438          0.000000          0.333333   0.945892
# 186244  0.149379          0.000000          0.000000   0.943949
# 208561  0.316375          0.000000          0.000000   0.943075
# 66669   0.208333          0.000000          0.000000   0.937853
# 182365  0.133403          0.000000          0.000000   0.928537
# 150259  0.219677          0.000000          0.000000   0.926496
# 160756  0.527794          0.000000          0.000000   0.920628
# 92980   0.200226          0.000000          0.000000   0.919263
# 209421  0.138701          0.000000          0.333333   0.917351
# 19910   0.409524          0.250000          0.250000   0.912827
# 64013   0.406017          0.000000          0.666667   0.910777
# 60771   0.104944          0.000000          0.000000   0.910657
# 178375  0.180783          0.000000          0.333333   0.910592
# 62723   0.185408          0.000000          0.333333   0.910027
# 200236  0.094328          0.000000          0.000000   0.909154
# 42078   0.079081          0.000000          0.000000   0.902364
# 204918  0.143049          0.000000          0.000000   0.901082
# 64910   0.154921          0.000000          0.250000   0.898265
# 82008   0.212267          0.000000          0.000000   0.894752
# 145318  0.065612          0.000000          0.000000   0.892741
# 83205   0.109385          0.000000          0.000000   0.892651
# 69564   0.072218          0.000000          0.000000   0.891845
#
# [50 rows x 31 columns]
