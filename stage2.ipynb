# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import re

encoding = "ISO-8859-1"
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /home/eugene/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eugene/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/eugene/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
stemmer = SnowballStemmer('english')
stop_words = set(stopwords.words('english'))


def replaces(s):
    if isinstance(s, str):
        s = s.lower()
        s = re.sub(r"(\w)\.([A-Z])", r"\1 \2", s) 

        s = re.sub(r"([0-9]+)( *)(inches|inch|in|')\.?", r"\1in. ", s)
    
        s = re.sub(r"([0-9]+)( *)(foot|feet|ft|'')\.?", r"\1ft. ", s)
    
        s = re.sub(r"([0-9]+)( *)(pounds|pound|lbs|lb)\.?", r"\1lb. ", s)
    
        s = s.replace(" x "," xby ")
        s = s.replace("*"," xby ")
        s = s.replace(" by "," xby")
        s = s.replace("x0"," xby 0")
        s = s.replace("x1"," xby 1")
        s = s.replace("x2"," xby 2")
        s = s.replace("x3"," xby 3")
        s = s.replace("x4"," xby 4")
        s = s.replace("x5"," xby 5")
        s = s.replace("x6"," xby 6")
        s = s.replace("x7"," xby 7")
        s = s.replace("x8"," xby 8")
        s = s.replace("x9"," xby 9")
        s = s.replace("0x","0 xby ")
        s = s.replace("1x","1 xby ")
        s = s.replace("2x","2 xby ")
        s = s.replace("3x","3 xby ")
        s = s.replace("4x","4 xby ")
        s = s.replace("5x","5 xby ")
        s = s.replace("6x","6 xby ")
        s = s.replace("7x","7 xby ")
        s = s.replace("8x","8 xby ")
        s = s.replace("9x","9 xby ")
        
        s = re.sub(r"([0-9])( *)\.( *)([0-9])", r"\1.\4", s)
        s = re.sub(r"([0-9]+)( *)(inches|inch|in|')\.?", r"\1in. ", s)
        s = re.sub(r"([0-9]+)( *)(foot|feet|ft|'')\.?", r"\1ft. ", s)
        s = re.sub(r"([0-9]+)( *)(pounds|pound|lbs|lb)\.?", r"\1lb. ", s)
        s = re.sub(r"([0-9]+)( *)(square|sq) ?\.?(feet|foot|ft)\.?", r"\1sq.ft. ", s)
        s = re.sub(r"([0-9]+)( *)(cubic|cu) ?\.?(feet|foot|ft)\.?", r"\1cu.ft. ", s)
        s = re.sub(r"([0-9]+)( *)(gallons|gallon|gal)\.?", r"\1gal. ", s)
        s = re.sub(r"([0-9]+)( *)(ounces|ounce|oz)\.?", r"\1oz. ", s)
        s = re.sub(r"([0-9]+)( *)(centimeters|cm)\.?", r"\1cm. ", s)
        s = re.sub(r"([0-9]+)( *)(milimeters|mm)\.?", r"\1mm. ", s)
        s = s.replace("°"," degrees ")
        s = re.sub(r"([0-9]+)( *)(degrees|degree)\.?", r"\1deg. ", s)
        s = s.replace(" v "," volts ")
        s = re.sub(r"([0-9]+)( *)(volts|volt)\.?", r"\1volt. ", s)
        s = re.sub(r"([0-9]+)( *)(watts|watt)\.?", r"\1watt. ", s)
        s = re.sub(r"([0-9]+)( *)(amperes|ampere|amps|amp)\.?", r"\1amp. ", s)
        
        s = s.replace("toliet","toilet")
        s = s.replace("airconditioner","air conditioner")
        s = s.replace("vinal","vinyl")
        s = s.replace("vynal","vinyl")
        s = s.replace("skill","skil")
        s = s.replace("snowbl","snow bl")
        s = s.replace("plexigla","plexi gla")
        s = s.replace("rustoleum","rust-oleum")
        s = s.replace("whirpool","whirlpool")
        s = s.replace("whirlpoolga", "whirlpool ga")
        s = s.replace("whirlpoolstainless","whirlpool stainless")

        s = s.replace("  "," ")
        
        s = s.replace("/", " ")
        s = s.replace("-", " ")
        return " ".join([re.sub('[^A-Za-z0-9-./]', ' ', word)
                         for word in s.split()])
    else:
        return "null"

def stem_sentence(s): 
    s = replaces(s)   
    return str(" ".join([stemmer.stem(word)
                         for word in s.split()
                         if word not in stop_words]))

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion

# %%
def word_match_count(search_term, text):
    count = 0
    search_term = search_term.split()
    text = text.split()
    if len(search_term) == 0:
        return 0
    for word in set(search_term):
        count += 1 if text.count(word) > 0 else 0
    return count / len(search_term)

# %%
def match_word_n_pos(text, search_term):
    text = nltk.pos_tag(replaces(text).split())
    search_pos = nltk.pos_tag(replaces(search_term).split())
    text = ["%s/%s" % (word[0].lower(), word[1]) for word in text]
    search_pos = ["%s/%s" % (word[0].lower(), word[1]) for word in search_pos]
    
    if len(search_pos) == 0:
        return 0
    matches = 0
    for word in set(text):
        if word in search_pos:
            matches += 1
    return matches / len(search_pos)

# %%
products = pd.read_csv('product_descriptions.csv', encoding=encoding, index_col=['product_uid'])
products['orig_descr'] = products['product_description']
products['descr'] = products['product_description'].apply(stem_sentence)
attrs = pd.read_csv('attributes.csv')
brand = attrs[attrs['name'] == 'MFG Brand Name']
brand.index = brand['product_uid']
brand = brand['value'].astype(str).apply(stem_sentence)

# %%
train = pd.read_csv('train.csv', encoding=encoding, index_col=['id'])
train['orig_search_term'] = train['search_term']
train['orig_product_title'] = train['product_title']
train['descr'] = train.product_uid.map(products['descr'])
train['orig_descr'] = train.product_uid.map(products['orig_descr'])
for col in ['product_title', 'search_term']:
    train[col] = train[col].apply(stem_sentence)

for col in ['product_title', 'descr']:
    train['match_' + col] = train.apply(lambda row: word_match_count(row['search_term'], row[col]), axis=1)

train['len_search_term_words'] = train['search_term'].apply(lambda x: len(x.split()))
train['len_search_term_letters'] = train['search_term'].str.len()
train['complete_match_title'] = \
    train.apply(lambda row:1 if row['product_title'].find(row['search_term']) >= 0 else 0, axis=1)   
train['complete_match_descr'] = \
    train.apply(lambda row:1 if row['descr'].find(row['search_term']) >= 0 else 0, axis=1)
train['match_pos_title'] = train.apply(
    lambda x: match_word_n_pos(x['orig_product_title'], x['orig_search_term']), axis=1)
train['match_pos_descr'] = train.apply(
    lambda x: match_word_n_pos(x['orig_descr'], x['orig_search_term']), axis=1)

train['brand'] = train['product_uid'].map(brand).astype(str)
train['search_term'] = train['search_term'].astype(str)
train['match_brand'] = train.apply(lambda row: word_match_count(row['brand'], row['search_term']), axis=1)
train.to_csv('train2.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4aae3acfc51e> in <module>()
# ----> 1 train = pd.read_csv('train.csv', encoding=encoding, index_col=['id'])
#       2 train['orig_search_term'] = train['search_term']
#       3 train['orig_product_title'] = train['product_title']
#       4 train['descr'] = train.product_uid.map(products['descr'])
#       5 train['orig_descr'] = train.product_uid.map(products['orig_descr'])
#
# NameError: name 'pd' is not defined

# %%
train = pd.read_csv('train_processed.csv', index_col=['id'])
train.head()
# Out:
#     product_uid                                      product_title  \
# id
# 2        100001                     simpson strong-ti 12-gaug angl
# 3        100001                     simpson strong-ti 12-gaug angl
# 9        100002  behr premium textur deckov 1-gal. #sc-141 tugb...
# 16       100005  delta vero 1-handl shower faucet trim kit chro...
# 17       100005  delta vero 1-handl shower faucet trim kit chro...
#
#          search_term  relevance    orig_search_term  \
# id
# 2       angl bracket       3.00       angle bracket
# 3          l bracket       2.50           l bracket
# 9               deck       3.00           deck over
# 16  rain shower head       2.33    rain shower head
# 17     shower faucet       2.67  shower only faucet
#
#                                    orig_product_title  \
# id
# 2                   Simpson Strong-Tie 12-Gauge Angle
# 3                   Simpson Strong-Tie 12-Gauge Angle
# 9   BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
#
#                                                 descr  \
# id
# 2   angl make joint stronger, also provid consiste...
# 3   angl make joint stronger, also provid consiste...
# 9   behr premium textur deckov innov solid color c...
# 16  updat bathroom delta vero single-handl shower ...
# 17  updat bathroom delta vero single-handl shower ...
#
#                                            orig_descr  match_product_title  \
# id
# 2   Not only do angles make joints stronger, they ...             0.500000
# 3   Not only do angles make joints stronger, they ...             0.000000
# 9   BEHR Premium Textured DECKOVER is an innovativ...             0.000000
# 16  Update your bathroom with the Delta Vero Singl...             0.333333
# 17  Update your bathroom with the Delta Vero Singl...             1.000000
#
#     match_descr  len_search_term_words  len_search_term_letters  \
# id
# 2      0.500000                      2                       12
# 3      0.000000                      2                        9
# 9      0.000000                      1                        4
# 16     0.333333                      3                       16
# 17     1.000000                      2                       13
#
#     complete_match_title  complete_match_descr  match_pos_title  \
# id
# 2                      0                     0         0.500000
# 3                      0                     0         0.000000
# 9                      1                     1         0.000000
# 16                     0                     0         0.333333
# 17                     1                     1         0.666667
#
#     match_pos_descr                       brand  match_brand
# id
# 2          0.000000           simpson strong-ti          0.0
# 3          0.000000           simpson strong-ti          0.0
# 9          0.500000  behr premium textur deckov          0.0
# 16         0.000000                       delta          0.0
# 17         0.333333                       delta          0.0

# %%
test = pd.read_csv('test.csv', encoding=encoding, index_col=['id'])
test['orig_search_term'] = test['search_term']
test['orig_product_title'] = test['product_title']
test['descr'] = test.product_uid.map(products['descr']).astype(str)
test['orig_descr'] = test.product_uid.map(products['orig_descr'])
test['search_term'] = test['search_term'].astype(str)
test['product_title'] = test['product_title'].astype(str)
for col in ['product_title', 'search_term']:
    test[col] = test[col].apply(stem_sentence)

for col in ['product_title', 'descr']:
    test['match_' + col] = test.apply(lambda row: word_match_count(row['search_term'], row[col]), axis=1)

test['len_search_term_words'] = test['search_term'].apply(lambda x: len(x.split()))
test['len_search_term_letters'] = test['search_term'].str.len()
test['complete_match_title'] = \
    test.apply(lambda row:1 if row['product_title'].find(row['search_term']) >= 0 else 0, axis=1)   
test['complete_match_descr'] = \
    test.apply(lambda row:1 if row['descr'].find(row['search_term']) >= 0 else 0, axis=1)
test['match_pos_title'] = test.apply(
    lambda x: match_word_n_pos(x['orig_product_title'], x['orig_search_term']), axis=1)
test['match_pos_descr'] = test.apply(
    lambda x: match_word_n_pos(x['orig_descr'], x['orig_search_term']), axis=1)

# %%
test['brand'] = test['product_uid'].map(brand).astype(str)
test['match_brand'] = test.apply(lambda row: word_match_count(row['brand'], row['search_term']), axis=1)
test.to_csv('test_processed.csv')

# %%
test = pd.read_csv('test_processed.csv', index_col=['id'])
test.head()
# Out:
#     product_uid                   product_title                search_term  \
# id
# 1        100001  simpson strong-ti 12-gaug angl           90 degre bracket
# 4        100001  simpson strong-ti 12-gaug angl            metal l bracket
# 5        100001  simpson strong-ti 12-gaug angl            simpson sku abl
# 6        100001  simpson strong-ti 12-gaug angl         simpson strong tie
# 7        100001  simpson strong-ti 12-gaug angl  simpson strong tie hcc668
#
#              orig_search_term                 orig_product_title  \
# id
# 1           90 degree bracket  Simpson Strong-Tie 12-Gauge Angle
# 4            metal l brackets  Simpson Strong-Tie 12-Gauge Angle
# 5            simpson sku able  Simpson Strong-Tie 12-Gauge Angle
# 6        simpson strong  ties  Simpson Strong-Tie 12-Gauge Angle
# 7   simpson strong tie hcc668  Simpson Strong-Tie 12-Gauge Angle
#
#                                                 descr  \
# id
# 1   angl make joint stronger, also provid consiste...
# 4   angl make joint stronger, also provid consiste...
# 5   angl make joint stronger, also provid consiste...
# 6   angl make joint stronger, also provid consiste...
# 7   angl make joint stronger, also provid consiste...
#
#                                            orig_descr  match_product_title  \
# id
# 1   Not only do angles make joints stronger, they ...             0.000000
# 4   Not only do angles make joints stronger, they ...             0.000000
# 5   Not only do angles make joints stronger, they ...             0.333333
# 6   Not only do angles make joints stronger, they ...             0.333333
# 7   Not only do angles make joints stronger, they ...             0.250000
#
#     match_descr  len_search_term_words  len_search_term_letters  \
# id
# 1      0.333333                      3                       16
# 4      0.000000                      3                       15
# 5      0.333333                      3                       15
# 6      0.333333                      3                       18
# 7      0.250000                      4                       25
#
#     complete_match_title  complete_match_descr  match_pos_title  \
# id
# 1                      0                     0         0.000000
# 4                      0                     0         0.000000
# 5                      0                     0         0.333333
# 6                      0                     0         0.666667
# 7                      0                     0         0.500000
#
#     match_pos_descr              brand  match_brand
# id
# 1          0.000000  simpson strong-ti     0.000000
# 4          0.000000  simpson strong-ti     0.000000
# 5          0.333333  simpson strong-ti     0.058824
# 6          1.000000  simpson strong-ti     0.058824
# 7          1.000000  simpson strong-ti     0.058824

# %%
cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
        'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr']
X = train[cols]
y = train['relevance']

# %%
br = BaggingRegressor(lgb.LGBMRegressor(), max_samples=0.1, n_estimators=40)
br.fit(X, y)

X_test = test[cols]
y_pred = br.predict(X_test)
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.48929

# %%
# Обвязка для FeatureUnion
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']



class cust_regression_vals(BaseEstimator, TransformerMixin):
    def fit(self, x, y=None):
        return self
    def transform(self, train):
        return train[tree_cols].values


class cust_txt_col(BaseEstimator, TransformerMixin):
    def __init__(self, col):
        self.col = col
    def fit(self, x, y=None):
        return self
    def transform(self, dataset):
        return dataset[self.col].apply(str)



tfidf = TfidfVectorizer(stop_words='english')
tsvd = TruncatedSVD(n_components=25)
gbm = lgb.LGBMRegressor()

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')), ('tfidf1', tfidf), ('tsvd1', tsvd)])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')), ('tfidf2', tfidf), ('tsvd2', tsvd)])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')), ('tfidf3', tfidf), ('tsvd3', tsvd)])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')), ('tfidf4', tfidf), ('tsvd4', tsvd)]))
                    ]
            )), 
    ('gbm', gbm)])

# %%
clf.fit(train[use_cols], y)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=None,
#        transformer_list=[('cst', cust_regression_vals()), ('txt1', Pipeline(memory=None,
#      steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float6....0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])

# %%
y_pred = clf.predict(test[use_cols][:])
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %%
clf.get_params()
# Out:
# {'memory': None, 'steps': [('union', FeatureUnion(n_jobs=None,
#           transformer_list=[('cst', cust_regression_vals()), ('txt1', Pipeline(memory=None,
#         steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lo...ncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))]))],
#           transformer_weights=None)),
#   ('gbm',
#    LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#           importance_type='split', learning_rate=0.1, max_depth=-1,
#           min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#           n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#           random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#           subsample=1.0, subsample_for_bin=200000, subsample_freq=0))], 'union': FeatureUnion(n_jobs=None,
#         transformer_list=[('cst', cust_regression_vals()), ('txt1', Pipeline(memory=None,
#       steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lo...ncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0))]))],
#         transformer_weights=None), 'gbm': LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0), 'union__n_jobs': None, 'union__transformer_list': [('cst',
#    cust_regression_vals()),
#   ('txt1', Pipeline(memory=None,
#         steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))])),
#   ('txt2', Pipeline(memory=None,
#         steps=[('s2', cust_txt_col(col='product_title')), ('tfidf2', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), no...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))])),
#   ('txt3', Pipeline(memory=None,
#         steps=[('s3', cust_txt_col(col='descr')), ('tfidf3', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm='l2',...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))])),
#   ('txt4', Pipeline(memory=None,
#         steps=[('s4', cust_txt_col(col='brand')), ('tfidf4', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm='l2',...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))]))], 'union__transformer_weights': None, 'union__cst': cust_regression_vals(), 'union__txt1': Pipeline(memory=None,
#       steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0))]), 'union__txt2': Pipeline(memory=None,
#       steps=[('s2', cust_txt_col(col='product_title')), ('tfidf2', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), no...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0))]), 'union__txt3': Pipeline(memory=None,
#       steps=[('s3', cust_txt_col(col='descr')), ('tfidf3', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm='l2',...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0))]), 'union__txt4': Pipeline(memory=None,
#       steps=[('s4', cust_txt_col(col='brand')), ('tfidf4', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm='l2',...TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0))]), 'union__txt1__memory': None, 'union__txt1__steps': [('s1',
#    cust_txt_col(col='search_term')),
#   ('tfidf1',
#    TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#            stop_words='english', strip_accents=None, sublinear_tf=False,
#            token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#            vocabulary=None)),
#   ('tsvd1', TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))], 'union__txt1__s1': cust_txt_col(col='search_term'), 'union__txt1__tfidf1': TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#          stop_words='english', strip_accents=None, sublinear_tf=False,
#          token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#          vocabulary=None), 'union__txt1__tsvd1': TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0), 'union__txt1__s1__col': 'search_term', 'union__txt1__tfidf1__analyzer': 'word', 'union__txt1__tfidf1__binary': False, 'union__txt1__tfidf1__decode_error': 'strict', 'union__txt1__tfidf1__dtype': numpy.float64, 'union__txt1__tfidf1__encoding': 'utf-8', 'union__txt1__tfidf1__input': 'content', 'union__txt1__tfidf1__lowercase': True, 'union__txt1__tfidf1__max_df': 1.0, 'union__txt1__tfidf1__max_features': None, 'union__txt1__tfidf1__min_df': 1, 'union__txt1__tfidf1__ngram_range': (1,
#   1), 'union__txt1__tfidf1__norm': 'l2', 'union__txt1__tfidf1__preprocessor': None, 'union__txt1__tfidf1__smooth_idf': True, 'union__txt1__tfidf1__stop_words': 'english', 'union__txt1__tfidf1__strip_accents': None, 'union__txt1__tfidf1__sublinear_tf': False, 'union__txt1__tfidf1__token_pattern': '(?u)\\b\\w\\w+\\b', 'union__txt1__tfidf1__tokenizer': None, 'union__txt1__tfidf1__use_idf': True, 'union__txt1__tfidf1__vocabulary': None, 'union__txt1__tsvd1__algorithm': 'randomized', 'union__txt1__tsvd1__n_components': 20, 'union__txt1__tsvd1__n_iter': 5, 'union__txt1__tsvd1__random_state': None, 'union__txt1__tsvd1__tol': 0.0, 'union__txt2__memory': None, 'union__txt2__steps': [('s2',
#    cust_txt_col(col='product_title')),
#   ('tfidf2',
#    TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#            stop_words='english', strip_accents=None, sublinear_tf=False,
#            token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#            vocabulary=None)),
#   ('tsvd2', TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))], 'union__txt2__s2': cust_txt_col(col='product_title'), 'union__txt2__tfidf2': TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#          stop_words='english', strip_accents=None, sublinear_tf=False,
#          token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#          vocabulary=None), 'union__txt2__tsvd2': TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0), 'union__txt2__s2__col': 'product_title', 'union__txt2__tfidf2__analyzer': 'word', 'union__txt2__tfidf2__binary': False, 'union__txt2__tfidf2__decode_error': 'strict', 'union__txt2__tfidf2__dtype': numpy.float64, 'union__txt2__tfidf2__encoding': 'utf-8', 'union__txt2__tfidf2__input': 'content', 'union__txt2__tfidf2__lowercase': True, 'union__txt2__tfidf2__max_df': 1.0, 'union__txt2__tfidf2__max_features': None, 'union__txt2__tfidf2__min_df': 1, 'union__txt2__tfidf2__ngram_range': (1,
#   1), 'union__txt2__tfidf2__norm': 'l2', 'union__txt2__tfidf2__preprocessor': None, 'union__txt2__tfidf2__smooth_idf': True, 'union__txt2__tfidf2__stop_words': 'english', 'union__txt2__tfidf2__strip_accents': None, 'union__txt2__tfidf2__sublinear_tf': False, 'union__txt2__tfidf2__token_pattern': '(?u)\\b\\w\\w+\\b', 'union__txt2__tfidf2__tokenizer': None, 'union__txt2__tfidf2__use_idf': True, 'union__txt2__tfidf2__vocabulary': None, 'union__txt2__tsvd2__algorithm': 'randomized', 'union__txt2__tsvd2__n_components': 20, 'union__txt2__tsvd2__n_iter': 5, 'union__txt2__tsvd2__random_state': None, 'union__txt2__tsvd2__tol': 0.0, 'union__txt3__memory': None, 'union__txt3__steps': [('s3',
#    cust_txt_col(col='descr')),
#   ('tfidf3',
#    TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#            stop_words='english', strip_accents=None, sublinear_tf=False,
#            token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#            vocabulary=None)),
#   ('tsvd3', TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))], 'union__txt3__s3': cust_txt_col(col='descr'), 'union__txt3__tfidf3': TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#          stop_words='english', strip_accents=None, sublinear_tf=False,
#          token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#          vocabulary=None), 'union__txt3__tsvd3': TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0), 'union__txt3__s3__col': 'descr', 'union__txt3__tfidf3__analyzer': 'word', 'union__txt3__tfidf3__binary': False, 'union__txt3__tfidf3__decode_error': 'strict', 'union__txt3__tfidf3__dtype': numpy.float64, 'union__txt3__tfidf3__encoding': 'utf-8', 'union__txt3__tfidf3__input': 'content', 'union__txt3__tfidf3__lowercase': True, 'union__txt3__tfidf3__max_df': 1.0, 'union__txt3__tfidf3__max_features': None, 'union__txt3__tfidf3__min_df': 1, 'union__txt3__tfidf3__ngram_range': (1,
#   1), 'union__txt3__tfidf3__norm': 'l2', 'union__txt3__tfidf3__preprocessor': None, 'union__txt3__tfidf3__smooth_idf': True, 'union__txt3__tfidf3__stop_words': 'english', 'union__txt3__tfidf3__strip_accents': None, 'union__txt3__tfidf3__sublinear_tf': False, 'union__txt3__tfidf3__token_pattern': '(?u)\\b\\w\\w+\\b', 'union__txt3__tfidf3__tokenizer': None, 'union__txt3__tfidf3__use_idf': True, 'union__txt3__tfidf3__vocabulary': None, 'union__txt3__tsvd3__algorithm': 'randomized', 'union__txt3__tsvd3__n_components': 20, 'union__txt3__tsvd3__n_iter': 5, 'union__txt3__tsvd3__random_state': None, 'union__txt3__tsvd3__tol': 0.0, 'union__txt4__memory': None, 'union__txt4__steps': [('s4',
#    cust_txt_col(col='brand')),
#   ('tfidf4',
#    TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#            stop_words='english', strip_accents=None, sublinear_tf=False,
#            token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#            vocabulary=None)),
#   ('tsvd4', TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#           random_state=None, tol=0.0))], 'union__txt4__s4': cust_txt_col(col='brand'), 'union__txt4__tfidf4': TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#          stop_words='english', strip_accents=None, sublinear_tf=False,
#          token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#          vocabulary=None), 'union__txt4__tsvd4': TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#         random_state=None, tol=0.0), 'union__txt4__s4__col': 'brand', 'union__txt4__tfidf4__analyzer': 'word', 'union__txt4__tfidf4__binary': False, 'union__txt4__tfidf4__decode_error': 'strict', 'union__txt4__tfidf4__dtype': numpy.float64, 'union__txt4__tfidf4__encoding': 'utf-8', 'union__txt4__tfidf4__input': 'content', 'union__txt4__tfidf4__lowercase': True, 'union__txt4__tfidf4__max_df': 1.0, 'union__txt4__tfidf4__max_features': None, 'union__txt4__tfidf4__min_df': 1, 'union__txt4__tfidf4__ngram_range': (1,
#   1), 'union__txt4__tfidf4__norm': 'l2', 'union__txt4__tfidf4__preprocessor': None, 'union__txt4__tfidf4__smooth_idf': True, 'union__txt4__tfidf4__stop_words': 'english', 'union__txt4__tfidf4__strip_accents': None, 'union__txt4__tfidf4__sublinear_tf': False, 'union__txt4__tfidf4__token_pattern': '(?u)\\b\\w\\w+\\b', 'union__txt4__tfidf4__tokenizer': None, 'union__txt4__tfidf4__use_idf': True, 'union__txt4__tfidf4__vocabulary': None, 'union__txt4__tsvd4__algorithm': 'randomized', 'union__txt4__tsvd4__n_components': 20, 'union__txt4__tsvd4__n_iter': 5, 'union__txt4__tsvd4__random_state': None, 'union__txt4__tsvd4__tol': 0.0, 'gbm__boosting_type': 'gbdt', 'gbm__class_weight': None, 'gbm__colsample_bytree': 1.0, 'gbm__importance_type': 'split', 'gbm__learning_rate': 0.1, 'gbm__max_depth': -1, 'gbm__min_child_samples': 20, 'gbm__min_child_weight': 0.001, 'gbm__min_split_gain': 0.0, 'gbm__n_estimators': 100, 'gbm__n_jobs': -1, 'gbm__num_leaves': 31, 'gbm__objective': None, 'gbm__random_state': None, 'gbm__reg_alpha': 0.0, 'gbm__reg_lambda': 0.0, 'gbm__silent': True, 'gbm__subsample': 1.0, 'gbm__subsample_for_bin': 200000, 'gbm__subsample_freq': 0}

# %%
params = {
    'gbm__learning_rate': [0.05, 0.1],
    'gbm__n_estimators': [200, 300, 400]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=None,
#        transformer_list=[('cst', cust_regression_vals()), ('txt1', Pipeline(memory=None,
#      steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float6....0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0))]),
#        fit_params=None, iid='warn', n_jobs=1,
#        param_grid={'gbm__learning_rate': [0.05, 0.1], 'gbm__n_estimators': [200, 300, 400]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring='neg_mean_squared_error', verbose=0)

# %%
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__learning_rate param_gbm__n_estimators  \
# 5        0.039619                      0.1                     400
# 4        0.062405                      0.1                     300
# 2        0.011238                     0.05                     400
# 3        0.009048                      0.1                     200
# 1        0.064630                     0.05                     300
#
#                                               params  split0_test_score  \
# 5  {'gbm__learning_rate': 0.1, 'gbm__n_estimators...          -0.224061
# 4  {'gbm__learning_rate': 0.1, 'gbm__n_estimators...          -0.223873
# 2  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.224448
# 3  {'gbm__learning_rate': 0.1, 'gbm__n_estimators...          -0.224385
# 1  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.225343
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 5          -0.213777          -0.241131        -0.226323        0.011281
# 4          -0.214883          -0.242731        -0.227162        0.011604
# 2          -0.215748          -0.241955        -0.227384        0.010899
# 3          -0.216939          -0.243309        -0.228211        0.011100
# 1          -0.217233          -0.242960        -0.228512        0.010739
#
#    rank_test_score
# 5                1
# 4                2
# 2                3
# 3                4
# 1                5

# %%
y_pred = model.predict(test[use_cols][:])
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.48111

# %%
params = {
    'gbm__learning_rate': [0.05, 0.07, 0.1],
    'gbm__n_estimators': [300, 400, 500],
    'union__txt1__tsvd1__n_components': [15],
    'union__txt2__tsvd2__n_components': [15],
    'union__txt3__tsvd3__n_components': [15],
    'union__txt4__tsvd4__n_components': [15]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols][:], y)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=None,
#        transformer_list=[('cst', cust_regression_vals()), ('txt1', Pipeline(memory=None,
#      steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float6....0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0))]),
#        fit_params=None, iid='warn', n_jobs=1,
#        param_grid={'gbm__learning_rate': [0.05, 0.07, 0.1], 'gbm__n_estimators': [300, 400, 500], 'union__txt1__tsvd1__n_components': [15], 'union__txt2__tsvd2__n_components': [15], 'union__txt3__tsvd3__n_components': [15], 'union__txt4__tsvd4__n_components': [15]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring='neg_mean_squared_error', verbose=0)

# %%
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__learning_rate param_gbm__n_estimators  \
# 4        0.011484                     0.07                     400
# 5        0.030416                     0.07                     500
# 8        0.024669                      0.1                     500
# 7        0.020821                      0.1                     400
# 2        0.017676                     0.05                     500
#
#   param_union__txt1__tsvd1__n_components  \
# 4                                     15
# 5                                     15
# 8                                     15
# 7                                     15
# 2                                     15
#
#   param_union__txt2__tsvd2__n_components  \
# 4                                     15
# 5                                     15
# 8                                     15
# 7                                     15
# 2                                     15
#
#   param_union__txt3__tsvd3__n_components  \
# 4                                     15
# 5                                     15
# 8                                     15
# 7                                     15
# 2                                     15
#
#   param_union__txt4__tsvd4__n_components  \
# 4                                     15
# 5                                     15
# 8                                     15
# 7                                     15
# 2                                     15
#
#                                               params  split0_test_score  \
# 4  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.224289
# 5  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.225120
# 8  {'gbm__learning_rate': 0.1, 'gbm__n_estimators...          -0.224752
# 7  {'gbm__learning_rate': 0.1, 'gbm__n_estimators...          -0.225535
# 2  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.225012
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 4          -0.215079          -0.240609        -0.226659        0.010556
# 5          -0.214967          -0.240220        -0.226769        0.010375
# 8          -0.215703          -0.241877        -0.227444        0.010854
# 7          -0.217081          -0.240346        -0.227654        0.009615
# 2          -0.216101          -0.242173        -0.227762        0.010820
#
#    rank_test_score
# 4                1
# 5                2
# 8                3
# 7                4
# 2                5

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.48232

# %%
params = {
    'gbm__learning_rate': [0.07],
    'gbm__n_estimators': [450, 500, 550],
    'union__txt1__tsvd1__n_components': [18],
    'union__txt2__tsvd2__n_components': [18],
    'union__txt3__tsvd3__n_components': [18],
    'union__txt4__tsvd4__n_components': [18]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols][:], y)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=None,
#        transformer_list=[('cst', cust_regression_vals()), ('txt1', Pipeline(memory=None,
#      steps=[('s1', cust_txt_col(col='search_term')), ('tfidf1', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float6....0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0))]),
#        fit_params=None, iid='warn', n_jobs=1,
#        param_grid={'gbm__learning_rate': [0.07], 'gbm__n_estimators': [450, 500, 550], 'union__txt1__tsvd1__n_components': [18], 'union__txt2__tsvd2__n_components': [18], 'union__txt3__tsvd3__n_components': [18], 'union__txt4__tsvd4__n_components': [18]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring='neg_mean_squared_error', verbose=0)

# %%
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__learning_rate param_gbm__n_estimators  \
# 1        0.040481                     0.07                     500
# 2        0.044157                     0.07                     550
# 0        0.049255                     0.07                     450
#
#   param_union__txt1__tsvd1__n_components  \
# 1                                     18
# 2                                     18
# 0                                     18
#
#   param_union__txt2__tsvd2__n_components  \
# 1                                     18
# 2                                     18
# 0                                     18
#
#   param_union__txt3__tsvd3__n_components  \
# 1                                     18
# 2                                     18
# 0                                     18
#
#   param_union__txt4__tsvd4__n_components  \
# 1                                     18
# 2                                     18
# 0                                     18
#
#                                               params  split0_test_score  \
# 1  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.222623
# 2  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.223949
# 0  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.223858
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 1          -0.214811          -0.239279        -0.225571        0.010204
# 2          -0.213966          -0.240192        -0.226035        0.010808
# 0          -0.214956          -0.240773        -0.226529        0.010708
#
#    rank_test_score
# 1                1
# 2                2
# 0                3

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.48015

# %%
def word_match_index(search_term, text):
    count = 0
    search_term = search_term.split()
    text = text.split()
    if len(search_term) == 0:
        return 0
    min_ind = len(text)
    for word in set(search_term):
        if word in text:
            min_ind = min(min_ind, text.index(word))
    return min_ind / len(text)

# %%
train['search_term'] = train['search_term'].apply(str)
train['prod_title_ind'] = train.apply(lambda x: word_match_index(x['search_term'], x['product_title']), axis=1)
train['descr_ind'] = train.apply(lambda x: word_match_index(x['search_term'], x['descr']), axis=1)
train.head()
# Out:
#     product_uid                                      product_title  \
# id
# 2        100001                     simpson strong-ti 12-gaug angl
# 3        100001                     simpson strong-ti 12-gaug angl
# 9        100002  behr premium textur deckov 1-gal. #sc-141 tugb...
# 16       100005  delta vero 1-handl shower faucet trim kit chro...
# 17       100005  delta vero 1-handl shower faucet trim kit chro...
#
#          search_term  relevance    orig_search_term  \
# id
# 2       angl bracket       3.00       angle bracket
# 3          l bracket       2.50           l bracket
# 9               deck       3.00           deck over
# 16  rain shower head       2.33    rain shower head
# 17     shower faucet       2.67  shower only faucet
#
#                                    orig_product_title  \
# id
# 2                   Simpson Strong-Tie 12-Gauge Angle
# 3                   Simpson Strong-Tie 12-Gauge Angle
# 9   BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
#
#                                                 descr  \
# id
# 2   angl make joint stronger, also provid consiste...
# 3   angl make joint stronger, also provid consiste...
# 9   behr premium textur deckov innov solid color c...
# 16  updat bathroom delta vero single-handl shower ...
# 17  updat bathroom delta vero single-handl shower ...
#
#                                            orig_descr  match_product_title  \
# id
# 2   Not only do angles make joints stronger, they ...             0.500000
# 3   Not only do angles make joints stronger, they ...             0.000000
# 9   BEHR Premium Textured DECKOVER is an innovativ...             0.000000
# 16  Update your bathroom with the Delta Vero Singl...             0.333333
# 17  Update your bathroom with the Delta Vero Singl...             1.000000
#
#     match_descr  len_search_term_words  len_search_term_letters  \
# id
# 2      0.500000                      2                       12
# 3      0.000000                      2                        9
# 9      0.000000                      1                        4
# 16     0.333333                      3                       16
# 17     1.000000                      2                       13
#
#     complete_match_title  complete_match_descr  match_pos_title  \
# id
# 2                      0                     0         0.500000
# 3                      0                     0         0.000000
# 9                      1                     1         0.000000
# 16                     0                     0         0.333333
# 17                     1                     1         0.666667
#
#     match_pos_descr                       brand  match_brand  prod_title_ind  \
# id
# 2          0.000000           simpson strong-ti          0.0            0.75
# 3          0.000000           simpson strong-ti          0.0            1.00
# 9          0.500000  behr premium textur deckov          0.0            1.00
# 16         0.000000                       delta          0.0            0.30
# 17         0.333333                       delta          0.0            0.30
#
#     descr_ind
# id
# 2    0.000000
# 3    1.000000
# 9    1.000000
# 16   0.075758
# 17   0.075758

# %%
# Обвязка для FeatureUnion
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr',
             'prod_title_ind', 'descr_ind']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']



class cust_regression_vals(BaseEstimator, TransformerMixin):
    def fit(self, x, y=None):
        return self
    def transform(self, train):
        return train[tree_cols].values


class cust_txt_col(BaseEstimator, TransformerMixin):
    def __init__(self, col):
        self.col = col
    def fit(self, x, y=None):
        return self
    def transform(self, dataset):
        return dataset[self.col].apply(str)



tfidf = TfidfVectorizer(stop_words='english')
tsvd = TruncatedSVD(n_components=18)
gbm = lgb.LGBMRegressor()

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')), ('tfidf1', tfidf), ('tsvd1', tsvd)])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')), ('tfidf2', tfidf), ('tsvd2', tsvd)])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')), ('tfidf3', tfidf), ('tsvd3', tsvd)])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')), ('tfidf4', tfidf), ('tsvd4', tsvd)]))
                    ]
            )), 
    ('gbm', gbm)])

# %%
params = {
    'gbm__learning_rate': [0.05, 0.07, 0.1],
    'gbm__n_estimators': [450, 500, 550]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__learning_rate param_gbm__n_estimators  \
# 2        0.053544                     0.05                     550
# 5        0.017776                     0.07                     550
# 1        0.011547                     0.05                     500
# 3        0.030457                     0.07                     450
# 4        0.018310                     0.07                     500
#
#                                               params  split0_test_score  \
# 2  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.220945
# 5  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.222060
# 1  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.222650
# 3  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.222487
# 4  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.222807
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2          -0.213883          -0.237682        -0.224170        0.009980
# 5          -0.214188          -0.238463        -0.224904        0.010112
# 1          -0.213925          -0.238743        -0.225106        0.010280
# 3          -0.213430          -0.239771        -0.225229        0.010927
# 4          -0.213934          -0.238969        -0.225237        0.010364
#
#    rank_test_score
# 2                1
# 5                2
# 1                3
# 3                4
# 4                5

# %%
test['search_term'] = test['search_term'].apply(str)
test['prod_title_ind'] = test.apply(lambda x: word_match_index(x['search_term'], x['product_title']), axis=1)
test['descr_ind'] = test.apply(lambda x: word_match_index(x['search_term'], x['descr']), axis=1)
test.head()
# Out:
#     product_uid                   product_title                search_term  \
# id
# 1        100001  simpson strong-ti 12-gaug angl           90 degre bracket
# 4        100001  simpson strong-ti 12-gaug angl            metal l bracket
# 5        100001  simpson strong-ti 12-gaug angl            simpson sku abl
# 6        100001  simpson strong-ti 12-gaug angl         simpson strong tie
# 7        100001  simpson strong-ti 12-gaug angl  simpson strong tie hcc668
#
#              orig_search_term                 orig_product_title  \
# id
# 1           90 degree bracket  Simpson Strong-Tie 12-Gauge Angle
# 4            metal l brackets  Simpson Strong-Tie 12-Gauge Angle
# 5            simpson sku able  Simpson Strong-Tie 12-Gauge Angle
# 6        simpson strong  ties  Simpson Strong-Tie 12-Gauge Angle
# 7   simpson strong tie hcc668  Simpson Strong-Tie 12-Gauge Angle
#
#                                                 descr  \
# id
# 1   angl make joint stronger, also provid consiste...
# 4   angl make joint stronger, also provid consiste...
# 5   angl make joint stronger, also provid consiste...
# 6   angl make joint stronger, also provid consiste...
# 7   angl make joint stronger, also provid consiste...
#
#                                            orig_descr  match_product_title  \
# id
# 1   Not only do angles make joints stronger, they ...             0.000000
# 4   Not only do angles make joints stronger, they ...             0.000000
# 5   Not only do angles make joints stronger, they ...             0.333333
# 6   Not only do angles make joints stronger, they ...             0.333333
# 7   Not only do angles make joints stronger, they ...             0.250000
#
#     match_descr  len_search_term_words  len_search_term_letters  \
# id
# 1      0.333333                      3                       16
# 4      0.000000                      3                       15
# 5      0.333333                      3                       15
# 6      0.333333                      3                       18
# 7      0.250000                      4                       25
#
#     complete_match_title  complete_match_descr  match_pos_title  \
# id
# 1                      0                     0         0.000000
# 4                      0                     0         0.000000
# 5                      0                     0         0.333333
# 6                      0                     0         0.666667
# 7                      0                     0         0.500000
#
#     match_pos_descr              brand  match_brand  prod_title_ind  descr_ind
# id
# 1          0.000000  simpson strong-ti     0.000000             1.0   0.558140
# 4          0.000000  simpson strong-ti     0.000000             1.0   1.000000
# 5          0.333333  simpson strong-ti     0.058824             0.0   0.104651
# 6          1.000000  simpson strong-ti     0.058824             0.0   0.104651
# 7          1.000000  simpson strong-ti     0.058824             0.0   0.104651

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47894

# %%
train['brand'] = train['brand'].apply(str)
train['match_brand'] = train.apply(lambda row: word_match_count(row['brand'], row['search_term']), axis=1)
params = {
    'gbm__learning_rate': [0.05, 0.07],
    'gbm__n_estimators': [500, 550]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__learning_rate param_gbm__n_estimators  \
# 3        0.083328                     0.07                     550
# 2        0.033788                     0.07                     500
# 1        0.016607                     0.05                     550
# 0        0.054620                     0.05                     500
#
#                                               params  split0_test_score  \
# 3  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.221026
# 2  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.222234
# 1  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.222216
# 0  {'gbm__learning_rate': 0.05, 'gbm__n_estimator...          -0.222154
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 3          -0.213931          -0.238266        -0.224408        0.010219
# 2          -0.213949          -0.237767        -0.224650        0.009873
# 1          -0.213646          -0.238101        -0.224654        0.010131
# 0          -0.214268          -0.240048        -0.225490        0.010786
#
#    rank_test_score
# 3                1
# 2                2
# 1                3
# 0                4

# %%
params = {
    'gbm__learning_rate': [0.06, 0.07, 0.08],
    'gbm__n_estimators': [500, 550, 600]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__learning_rate param_gbm__n_estimators  \
# 2        0.062972                     0.06                     600
# 7        0.031326                     0.08                     550
# 6        0.046469                     0.08                     500
# 1        0.064603                     0.06                     550
# 4        0.022276                     0.07                     550
#
#                                               params  split0_test_score  \
# 2  {'gbm__learning_rate': 0.06, 'gbm__n_estimator...          -0.222682
# 7  {'gbm__learning_rate': 0.08, 'gbm__n_estimator...          -0.221876
# 6  {'gbm__learning_rate': 0.08, 'gbm__n_estimator...          -0.222018
# 1  {'gbm__learning_rate': 0.06, 'gbm__n_estimator...          -0.221873
# 4  {'gbm__learning_rate': 0.07, 'gbm__n_estimator...          -0.221230
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2          -0.212750          -0.237397        -0.224277        0.010125
# 7          -0.213890          -0.237226        -0.224331        0.009683
# 6          -0.213549          -0.237538        -0.224368        0.009934
# 1          -0.213015          -0.238575        -0.224488        0.010597
# 4          -0.213778          -0.238482        -0.224497        0.010346
#
#    rank_test_score
# 2                1
# 7                2
# 6                3
# 1                4
# 4                5

# %%
test['brand'] = test['brand'].apply(str)
test['match_brand'] = test.apply(lambda row: word_match_count(row['brand'], row['search_term']), axis=1)
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47864

# %%
params = {
    'gbm__learning_rate': [0.06],
    'gbm__n_estimators': [600],
    'gbm__num_leaves': [31, 40, 50],
    'gbm__colsample_bytree': [0.8, 1.]
    
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 2        0.036648                         0.8                     0.06
# 4        0.062110                           1                     0.06
# 5        0.040513                           1                     0.06
# 1        0.040047                         0.8                     0.06
# 3        0.022388                           1                     0.06
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 2                     600                    50
# 4                     600                    40
# 5                     600                    50
# 1                     600                    40
# 3                     600                    31
#
#                                               params  split0_test_score  \
# 2  {'gbm__colsample_bytree': 0.8, 'gbm__learning_...          -0.220665
# 4  {'gbm__colsample_bytree': 1.0, 'gbm__learning_...          -0.222417
# 5  {'gbm__colsample_bytree': 1.0, 'gbm__learning_...          -0.221894
# 1  {'gbm__colsample_bytree': 0.8, 'gbm__learning_...          -0.221908
# 3  {'gbm__colsample_bytree': 1.0, 'gbm__learning_...          -0.222465
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2          -0.211912          -0.238434        -0.223670        0.011034
# 4          -0.212668          -0.238081        -0.224389        0.010468
# 5          -0.212823          -0.238660        -0.224459        0.010703
# 1          -0.213617          -0.238290        -0.224605        0.010252
# 3          -0.213042          -0.239621        -0.225042        0.011003
#
#    rank_test_score
# 2                1
# 4                2
# 5                3
# 1                4
# 3                5

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47843

# %%
params = {
    'gbm__learning_rate': [0.06],
    'gbm__n_estimators': [600],
    'gbm__boosting_type': ['rf'],
    'gbm__bagging_freq': [1],
    'gbm__bagging_fraction': [0.8],
    'gbm__feature_fraction' : [0.7]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__bagging_fraction param_gbm__bagging_freq  \
# 0        0.054577                         0.8                       1
#
#   param_gbm__boosting_type param_gbm__feature_fraction  \
# 0                       rf                         0.7
#
#   param_gbm__learning_rate param_gbm__n_estimators  \
# 0                     0.06                     600
#
#                                               params  split0_test_score  \
# 0  {'gbm__bagging_fraction': 0.8, 'gbm__bagging_f...          -0.237328
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0          -0.229481          -0.255629        -0.240813        0.010956
#
#    rank_test_score
# 0                1

# %%
params = {
    'gbm__learning_rate': [0.05, 0.07],
    'gbm__n_estimators': [500, 600],
    'gbm__boosting_type': ['rf'],
    'gbm__bagging_freq': [1, 2],
    'gbm__bagging_fraction': [0.8],
    'gbm__feature_fraction' : [0.8]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__bagging_fraction param_gbm__bagging_freq  \
# 4        0.082362                         0.8                       2
# 5        0.032558                         0.8                       2
# 3        0.017711                         0.8                       1
# 1        0.045032                         0.8                       1
# 7        0.050543                         0.8                       2
#
#   param_gbm__boosting_type param_gbm__feature_fraction  \
# 4                       rf                         0.8
# 5                       rf                         0.8
# 3                       rf                         0.8
# 1                       rf                         0.8
# 7                       rf                         0.8
#
#   param_gbm__learning_rate param_gbm__n_estimators  \
# 4                     0.05                     500
# 5                     0.05                     600
# 3                     0.07                     600
# 1                     0.05                     600
# 7                     0.07                     600
#
#                                               params  split0_test_score  \
# 4  {'gbm__bagging_fraction': 0.8, 'gbm__bagging_f...          -0.237202
# 5  {'gbm__bagging_fraction': 0.8, 'gbm__bagging_f...          -0.237652
# 3  {'gbm__bagging_fraction': 0.8, 'gbm__bagging_f...          -0.237260
# 1  {'gbm__bagging_fraction': 0.8, 'gbm__bagging_f...          -0.237244
# 7  {'gbm__bagging_fraction': 0.8, 'gbm__bagging_f...          -0.237451
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 4          -0.229403          -0.255029        -0.240545        0.010725
# 5          -0.229307          -0.254713        -0.240557        0.010574
# 3          -0.229452          -0.255271        -0.240661        0.010811
# 1          -0.229453          -0.255331        -0.240676        0.010840
# 7          -0.229266          -0.255386        -0.240701        0.010908
#
#    rank_test_score
# 4                1
# 5                2
# 3                3
# 1                4
# 7                5

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.48978

# %%
params = {
    'gbm__learning_rate': [0.04, 0.06],
    'gbm__n_estimators': [600],
    'gbm__num_leaves': [50, 60],
    'gbm__colsample_bytree': [0.7, 0.9]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 2        0.031582                         0.7                     0.06
# 3        0.023708                         0.7                     0.06
# 1        0.019798                         0.7                     0.04
# 6        0.022488                         0.9                     0.06
# 5        0.029220                         0.9                     0.04
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 2                     600                    50
# 3                     600                    60
# 1                     600                    60
# 6                     600                    50
# 5                     600                    60
#
#                                               params  split0_test_score  \
# 2  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.219796
# 3  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.220758
# 1  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.220070
# 6  {'gbm__colsample_bytree': 0.9, 'gbm__learning_...          -0.220494
# 5  {'gbm__colsample_bytree': 0.9, 'gbm__learning_...          -0.221223
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2          -0.212528          -0.236325        -0.222883        0.009957
# 3          -0.211899          -0.236235        -0.222964        0.010057
# 1          -0.211971          -0.237386        -0.223142        0.010601
# 6          -0.212264          -0.237102        -0.223287        0.010331
# 5          -0.211994          -0.236923        -0.223380        0.010291
#
#    rank_test_score
# 2                1
# 3                2
# 1                3
# 6                4
# 5                5

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47891

# %%
print(model.best_estimator_.named_steps['gbm'].feature_importances_)
print(use_cols)
# Out:
# [371 226 182 585  47  18 315  65 297 555 497 583 556 486 450 438 531 457
#  409 482 490 462 430 528 523 541 513 539 601 413 355 386 388 310 367 322
#  402 320 338 419 336 410 394 392 384 412 426 483 389 378 359 359 379 405
#  396 362 375 356 402 404 415 436 381 465 425 240 187 177 158 245 165 179
#  168 182 173 162 202 173 176 156 198 206 133]
# ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters', 'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind', 'search_term', 'product_title', 'descr', 'brand']

# %%
params = {
    'gbm__learning_rate': [0.05],
    'gbm__n_estimators': [600],
    'gbm__num_leaves': [50],
    'gbm__colsample_bytree': [0.7],
    'union__txt1__tsvd1__n_components': [30],
    'union__txt2__tsvd2__n_components': [30],
    'union__txt3__tsvd3__n_components': [30],
    'union__txt4__tsvd4__n_components': [30]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 0         0.03503                         0.7                     0.05
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 0                     600                    50
#
#   param_union__txt1__tsvd1__n_components  \
# 0                                     30
#
#   param_union__txt2__tsvd2__n_components  \
# 0                                     30
#
#   param_union__txt3__tsvd3__n_components  \
# 0                                     30
#
#   param_union__txt4__tsvd4__n_components  \
# 0                                     30
#
#                                               params  split0_test_score  \
# 0  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...           -0.21917
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0          -0.210504          -0.236751        -0.222142        0.010919
#
#    rank_test_score
# 0                1

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47741

# %%
print(model.best_estimator_.named_steps['gbm'].feature_importances_[:12],
      model.best_estimator_.named_steps['gbm'].feature_importances_[12:42],
      model.best_estimator_.named_steps['gbm'].feature_importances_[42:72],
      model.best_estimator_.named_steps['gbm'].feature_importances_[72:102],
      model.best_estimator_.named_steps['gbm'].feature_importances_[102:],
      sep='\n'
     )
print(use_cols)
# Out:
# [324 214 152 546  39  13 286  65 162 414 365 419]
# [410 305 277 309 273 306 279 299 314 291 319 288 332 366 277 304 289 260
#  336 284 296 260 361 358 298 356 349 269 358 277]
# [223 235 217 225 195 231 256 163 215 242 215 231 206 240 218 271 221 211
#  211 248 227 244 243 237 254 246 263 293 237 342]
# [260 269 236 278 208 222 245 228 212 200 209 209 221 223 207 244 249 273
#  269 275 298 250 249 260 249 233 289 255 254 163]
# [113 127  94 133  85 108  80 123  87 111  82  97  74  89  68  96 101  88
#   90 114 112  90  87  88  91  80 108  75 113]
# ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters', 'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind', 'search_term', 'product_title', 'descr', 'brand']

# %%
params = {
    'gbm__learning_rate': [0.05],
    'gbm__n_estimators': [600],
    'gbm__num_leaves': [50],
    'gbm__colsample_bytree': [0.7],
    'union__txt1__tsvd1__n_components': [50],
    'union__txt2__tsvd2__n_components': [50],
    'union__txt3__tsvd3__n_components': [40],
    'union__txt4__tsvd4__n_components': [35]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 0        0.047816                         0.7                     0.05
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 0                     600                    50
#
#   param_union__txt1__tsvd1__n_components  \
# 0                                     50
#
#   param_union__txt2__tsvd2__n_components  \
# 0                                     50
#
#   param_union__txt3__tsvd3__n_components  \
# 0                                     40
#
#   param_union__txt4__tsvd4__n_components  \
# 0                                     35
#
#                                               params  split0_test_score  \
# 0  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.217159
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            -0.2092          -0.236125        -0.220828        0.011294
#
#    rank_test_score
# 0                1

# %%
print(model.best_estimator_.named_steps['gbm'].feature_importances_[:12],
      model.best_estimator_.named_steps['gbm'].feature_importances_[12:62],
      model.best_estimator_.named_steps['gbm'].feature_importances_[62:102],
      model.best_estimator_.named_steps['gbm'].feature_importances_[102:142],
      model.best_estimator_.named_steps['gbm'].feature_importances_[142:],
      sep='\n'
     )
print(use_cols)
# Out:
# [289 185 140 407  42  11 208  40 145 352 250 291]
# [270 236 202 189 219 202 181 175 216 188 207 154 218 206 165 223 165 156
#  180 198 195 177 163 204 207 179 185 191 165 201 170 243 224 214 221 233
#  188 207 223 235 209 237 222 245 250 236 238 246 250 238]
# [174 143 154 148 152 137 152 126 138 156 139 157 154 170 134 135 167 172
#  139 146 151 159 142 155 133 119 165 142 154 180 159 140 194 183 151 158
#  154 157 179 166]
# [200 143 159 134 138 187 187 181 164 253 140 179 152 199 129 158 182 141
#  148 162 187 198 160 182 158 177 166 169 170 179 152 165 163 162 171 144
#  159 177 142 190]
# [142 145 176 169 192 162 161 170 164 121  82  52  64 105  62  54  76  69
#   52  56  69  68  50  58  54  61  68  53  68  90  57  68  61  76  68  54
#   77  63  58  78  97  50  69  64]
# ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters', 'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind', 'search_term', 'product_title', 'descr', 'brand']

# %%
params = {
    'gbm__learning_rate': [0.05],
    'gbm__n_estimators': [600],
    'gbm__num_leaves': [50],
    'gbm__colsample_bytree': [0.7],
    'union__txt1__tsvd1__n_components': [80],
    'union__txt2__tsvd2__n_components': [80],
    'union__txt3__tsvd3__n_components': [60],
    'union__txt4__tsvd4__n_components': [35]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 0        0.040601                         0.7                     0.05
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 0                     600                    50
#
#   param_union__txt1__tsvd1__n_components  \
# 0                                     80
#
#   param_union__txt2__tsvd2__n_components  \
# 0                                     80
#
#   param_union__txt3__tsvd3__n_components  \
# 0                                     60
#
#   param_union__txt4__tsvd4__n_components  \
# 0                                     35
#
#                                               params  split0_test_score  \
# 0  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.217119
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0          -0.208772          -0.234422        -0.220104        0.010682
#
#    rank_test_score
# 0                1

# %%
print(model.best_estimator_.named_steps['gbm'].feature_importances_[:12],
      model.best_estimator_.named_steps['gbm'].feature_importances_[12:92],
      model.best_estimator_.named_steps['gbm'].feature_importances_[92:172],
      model.best_estimator_.named_steps['gbm'].feature_importances_[172:232],
      model.best_estimator_.named_steps['gbm'].feature_importances_[232:],
      sep='\n'
     )
print(use_cols)
# Out:
# [238 138 125 323  35   5 186  33 113 294 222 241]
# [159 151 125 108 134 127 133 125 154 130 124  95 124 137 115 103 131 131
#  150 116 144 114  97  98 167 132 102 108 105 118 122 166 149 144 114 131
#  112 151 141 149 101 115 126 120 107 124 176 117 110 139 103 109 116 130
#  176 147 127 117 147 168 119 138 137 128 160 152 145 157 148 106 112 121
#  180 127 137 132 152 169 139 157]
# [ 94 118 108  85 133  78 126  89  87 141 106  79  87 120 109 108 107 108
#   83  85 103 101  88  86  79  71 103 117 113  85 106 108  99 111 115 118
#  110  96 101  95  94 104  98  86  85 112  90  92 103  91 116 103  90  84
#  127 127 155 110 138 115 106 117 112  93 113 115 117 133 142  89 122 124
#  115 110 128 112 114 123 111 188]
# [132 115  75 119 112 106 131 100  99 102 102 106 122 115 105 123 104 114
#  118  86 107 120 119  96 128  90 122 112 104  90  95 109 103  95 105 103
#   99 101 107  90 124 117 120 120 100 133 108 132 109 152  92 107 106 146
#  127 137 134 106 133 119]
# [44 45 66 84 36 58 45 44 41 46 73 41 54 41 47 48 33 48 44 44 54 44 37 53
#  48 30 59 50 38 58 49 54 41 60]
# ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters', 'complete_match_title', 'complete_match_descr', 'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind', 'search_term', 'product_title', 'descr', 'brand']

# %%
# Обвязка для FeatureUnion
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']


tfidf = TfidfVectorizer(stop_words='english')
tsvd80 = TruncatedSVD(n_components=80)
tsvd80_2 = TruncatedSVD(n_components=80)
tsvd60 = TruncatedSVD(n_components=60)
tsvd35 = TruncatedSVD(n_components=30)
gbm = lgb.LGBMRegressor()

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')), ('tfidf1', tfidf), ('tsvd1', tsvd80)])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')), ('tfidf2', tfidf), ('tsvd2', tsvd80_2)])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')), ('tfidf3', tfidf), ('tsvd3', tsvd60)])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')), ('tfidf4', tfidf), ('tsvd4', tsvd35)]))
                    ]
            )), 
    ('gbm', gbm)])

# %%
params = {
    'gbm__learning_rate': [0.05],
    'gbm__n_estimators': [600, 700],
    'gbm__num_leaves': [50, 60],
    'gbm__colsample_bytree': [0.7]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 3        0.022706                         0.7                     0.05
# 1        0.042269                         0.7                     0.05
# 2        0.030646                         0.7                     0.05
# 0        0.036436                         0.7                     0.05
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 3                     700                    60
# 1                     600                    60
# 2                     700                    50
# 0                     600                    50
#
#                                               params  split0_test_score  \
# 3  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.217018
# 1  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.216747
# 2  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.216710
# 0  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.216840
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 3          -0.206555          -0.234525        -0.219366        0.011539
# 1          -0.207510          -0.234539        -0.219599        0.011217
# 2          -0.208067          -0.235516        -0.220097        0.011459
# 0          -0.207697          -0.235915        -0.220151        0.011755
#
#    rank_test_score
# 3                1
# 1                2
# 2                3
# 0                4

# %%
print(model.best_estimator_.named_steps['gbm'].feature_importances_[:9],
      model.best_estimator_.named_steps['gbm'].feature_importances_[9:89],
      model.best_estimator_.named_steps['gbm'].feature_importances_[89:169],
      model.best_estimator_.named_steps['gbm'].feature_importances_[169:229],
      model.best_estimator_.named_steps['gbm'].feature_importances_[229:],
      sep='\n'
     )
print(use_cols)
# Out:
# [270 164 135 378 241  44 145 376 310]
# [280 246 220 164 169 166 155 155 158 191 145 164 147 183 208 125 144 155
#  167 162 171 141 135 166 147 200 159 156 146 207 175 167 199 160 165 164
#  183 184 166 168 164 149 168 165 177 172 164 181 169 170 148 160 197 171
#  205 210 193 176 166 220 184 204 169 180 210 196 182 244 178 195 210 182
#  192 191 178 206 217 221 202 231]
# [227 185 156 140 147 158 145 154 141 162 160 167 154 132 116 175 145 171
#  153 149 147 148 125 132 166 166 125 158 176 149 154 165 137 146 153 174
#  155 193 146 151 156 154 158 145 127 157 156 157 150 167 133 154 148 116
#  174 148 168 179 215 202 172 153 161 168 146 180 174 179 155 131 181 163
#  178 178 189 172 216 172 161 183]
# [263 173 171 154 158 148 135 175 142 149 146 137 182 143 165 168 163 146
#  191 139 147 167 178 186 152 172 142 145 183 141 167 144 145 150 143 167
#  146 155 183 153 154 143 225 143 199 188 189 202 186 137 159 174 194 163
#  178 180 154 167 174 214]
# [164  87  70  81 114  70  62  72  66  58  80  56  68  58  63  72  86  64
#   52  61  84  55  58  78  58  80  55  69  57  63]
# ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters', 'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind', 'search_term', 'product_title', 'descr', 'brand']

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47719

# %%
train['pred_diff'] = (train['relevance'] - model.predict(train[use_cols])).abs()
train.sort_values(['pred_diff'], ascending=False)
# Out:
#         product_uid                                      product_title  \
# id
# 69679        119478           romano 4 ft. boxwood spiral topiari tree
# 156918       160006  werner 14 ft. fiberglass round rung straight l...
# 120624       140844                  rachael ray 10 qt. cover stockpot
# 69064        119252  big ass fan 3600 144 in. yellow silver aluminu...
# 204530       192555        heath bird stop blue ceram wild bird feeder
# 136808       148897   earthquak 212cc tiller rear tine crt side shield
# 104722       133520                    danco low lead 1a-3c stem crane
# 176724       172318  green matter 3-light mahogani bronz vaniti fixtur
# 109498       135608  gilbert &amp; bennett 42 in. galvan steel toma...
# 17236        103041  ortho home defens max 1.33 gal. perimet indoor...
# 98819        130929  prime-lin slide door tandem roller assembly, 1...
# 93622        128763  daylili grape magic bare root dormant plant (8...
# 92432        128292  mont blanc northbrook drop-in composit granit ...
# 9508         101618  sure comfort 40 gal. tall 3 year 34,000 btu na...
# 199586       188671   ge choic alert wireless alarm system alarm siren
# 85851        125582   oakland live 26 in. metal grape tabl plant stand
# 83392        124633             rubbermaid fasttrack garag cooler hook
# 45248        111134  globalros red mini carnat (160 stems) includ f...
# 132180       146528           zuo nob hill tuft loveseat charcoal gray
# 29109        106225  showerdoordirect 36 in. frameless shower door ...
# 39795        109474  winchest 3 ton 13 seer sweat a/c system 21 in....
# 7470         101272  samsung 30 in. w 1.6 cu. ft. rang microwav sta...
# 58986        115722  lincoln electr wire feed .030 welder contact t...
# 176212       171977                           drive terrain cane bronz
# 198022       187480         alpin 15 in. larg red bowl plastic planter
# 96402        129949        zadro surround light 7x vaniti mirror acryl
# 51369        113189      5 ft. x 30 ft. dalen product nylon trelli net
# 139648       150400  thermo-tex 30 ft. 7-year round clear ground so...
# 80767        123619  entryway orang butterfli 18 in. x 30 in. hand ...
# 142618       152011  builder&#39; choic richmond 4 ft. x 3-3/4 in. ...
# ...             ...                                                ...
# 136208       148583      1/8 - 3/4 in. cast-iron mpt valv replac handl
# 141028       151147                    ryobi router bit set (15-piece)
# 62868        117073  ryobi 40-volt x lithium-ion cordless attach ca...
# 131553       146206  crown metalwork black tradit decor garag hardw...
# 32385        107189     henri 4.75 gal. 287 solar-flex white roof coat
# 186008       178727    sharkbit 3/4 in. brass pex barb coupl (10-pack)
# 130463       145646    sharkbit 1/2 in. brass pex barb coupl (10-pack)
# 26128        105317  apach mill weav brown 18 in. x 30 in. recycl r...
# 1724         100304  new york wire 5/16 in. x 48 in. white aluminum...
# 32827        107330  red head 1/2 in. x 3 in. steel hex-nut-head sl...
# 6019         101034  weathershield 2 in. x 6 in. x 12 ft. #2 prime ...
# 156454       159734  master lock 1-9/16 in. vinyl cover solid bodi ...
# 63878        117435  commerci electr 11 in. stainless steel tie (10...
# 105976       134043  st. paul 61 in. x 22 in. ab engin technolog do...
# 188115       180228           arien 9 in. 136 cc walk-behind gas edger
# 187815       180015   st. paul provid 20 in. w john wall cabinet white
# 181161       175320                          duck flexibl faucet cover
# 72410        120498  poulan pro pr625y22rkp 22 in. variabl speed fr...
# 219333       204799  york wallcov 60.75 sq. ft. ashford geometr hou...
# 191355       182517  york wallcov 60.75 sq. ft. ashford geometr hou...
# 218672       204213  whitehaus collect 3.5 in. garbag dispos trim a...
# 84812        125195  home decor collect niya 32 in. ir electr firep...
# 37034        108614             frost king 12 ft. water pipe heat cabl
# 170619       168356  3nled 3 ft. t8 14-watt cool white g13 frost le...
# 67417        118657  toro replac scraper hardwar kit power clear 18...
# 24607        104909  paslod 3 in. x 0.120 in. 21å¡ brite smooth nai...
# 89813        127196        ce tech 1-line wall jack wall plate - white
# 150341       156217  rust-oleum painter&#39; touch 32 oz. ultra cov...
# 160671       162226              everbilt bright brass solid door stop
# 134560       147763  gardensun 11,000 btu powder coat bronz tableto...
#
#                          search_term  relevance  \
# id
# 69679                   topiari tree       1.00
# 156918                  14 ft ladder       1.00
# 120624                   rachael ray       1.00
# 69064                        big ass       1.00
# 204530                     bird stop       1.00
# 136808                   side shield       1.00
# 104722                  101-1h crane       1.00
# 176724                   bronz green       1.00
# 109498                  tomato plant       1.00
# 17236                     ant killer       1.00
# 98819                    roller bear       1.00
# 93622                    grape plant       1.00
# 92432                    granit sand       1.00
# 9508              hot water tank gas       1.00
# 199586       batteryfor alarm system       1.00
# 85851                    grape plant       1.00
# 83392              rubbermaid cooler       1.33
# 45248                      free ship       1.00
# 132180                           nob       1.00
# 29109                 36 shower door       1.00
# 39795                 line condition       1.00
# 7470                        gas rang       1.00
# 58986                elrctric welder       1.00
# 176212               sawtrax terrain       1.00
# 198022                    alpin larg       1.00
# 96402                    stand light       1.00
# 51369                   mosquito net       1.00
# 139648                  ground clear       1.00
# 80767                  coconut fiber       1.33
# 142618                fireplac paint       1.00
# ...                              ...        ...
# 136208                  replac handl       2.67
# 141028             speacalti bit set       2.33
# 62868                lithium seedeat       2.33
# 131553        door handl deabolt kit       2.00
# 32385              flat seal 1097686       2.00
# 186008           outdoor brass coupl       2.33
# 130463           outdoor brass coupl       2.33
# 26128                 tread door mat       2.33
# 1724         34x34 window screen kit       2.00
# 32827                   sleev anchor       2.67
# 6019          round2x2 pressur treat       2.33
# 156454                      pad lock       2.33
# 63878                       cabl tie       2.67
# 105976           bathroom doubl sink       2.67
# 188115              hoinda gas edger       2.33
# 187815   white wall bathroon cabinet       2.67
# 181161            outdoor pump insul       2.00
# 72410    poulan pro lawn motor blade       2.00
# 219333               wallpap ashford       2.67
# 191355               wallpap ashford       2.67
# 218672           univers dispos trim       2.00
# 84812          white electr fireplac       2.67
# 37034                      heat tape       2.33
# 170619                cool tube lgts       2.33
# 67417               toro power clear       2.67
# 24607              paslod frame nail       2.67
# 89813   bronzw phone wall jack cover       2.33
# 150341             latex acryl paint       2.67
# 160671     bright brass door stopper       2.33
# 134560                 padtio heater       2.33
#
#                      orig_search_term  \
# id
# 69679                    topiary tree
# 156918                   14 ft ladder
# 120624                    rachael ray
# 69064                         big ass
# 204530                     bird stops
# 136808                   side shields
# 104722               101-1h for crane
# 176724                   bronze green
# 109498                  tomato plants
# 17236                      ant killer
# 98819                 roller bearings
# 93622                     grape plant
# 92432                   granite  sand
# 9508               hot water tank gas
# 199586        batteryfor alarm system
# 85851                     grape plant
# 83392               rubbermaid cooler
# 45248                   free shipping
# 132180                           nobs
# 29109                  36 shower door
# 39795                line conditioner
# 7470                        gas range
# 58986                elrctric welders
# 176212            sawtrax all terrain
# 198022                   alpine large
# 96402                  standing light
# 51369                    mosquito net
# 139648                   Ground Clear
# 80767                   coconut fiber
# 142618                fireplace paint
# ...                               ...
# 136208             replacement handle
# 141028              speacalty bit set
# 62868               lithium seedeater
# 131553        door handle deabolt kit
# 32385               flat seal 1097686
# 186008         outdoor brass coupling
# 130463         outdoor brass coupling
# 26128                  tread door mat
# 1724          34x34 window screen kit
# 32827                  sleeve anchors
# 6019        round2x2 pressure treated
# 156454                      pad locks
# 63878                       cable tie
# 105976           bathroom double sink
# 188115               hoinda gas edger
# 187815  white wall  bathroon cabinets
# 181161        outdoor pump insulation
# 72410    poulan pro lawn motor blades
# 219333              wallpaper ashford
# 191355              wallpaper ashford
# 218672        universal disposal trim
# 84812       white electric fireplaces
# 37034                    heating tape
# 170619                cool  tube lgts
# 67417                toro power clear
# 24607           paslode framing nails
# 89813    bronzw phone wall jack cover
# 150341           latex  acrylic paint
# 160671      bright brass door stopper
# 134560                  padtio heater
#
#                                        orig_product_title  \
# id
# 69679            Romano 4 ft. Boxwood Spiral Topiary Tree
# 156918  Werner 14 ft. Fiberglass Round Rung Straight L...
# 120624                Rachael Ray 10 qt. Covered Stockpot
# 69064   Big Ass Fans 3600 144 in. Yellow and Silver Al...
# 204530      Heath Bird Stop Blue Ceramic Wild Bird Feeder
# 136808  Earthquake 212cc Tiller Rear Tine CRT with Sid...
# 104722                DANCO Low Lead 1A-3C Stem for Crane
# 176724  Green Matters 3-Light Mahogany Bronze Vanity F...
# 109498  Gilbert &amp; Bennett 42 in. Galvanized Steel ...
# 17236   Ortho Home Defense Max 1.33 Gal. Perimeter and...
# 98819   Prime-Line Sliding Door Tandem Roller Assembly...
# 93622   Daylily Grape Magic Bare Root Dormant Plants (...
# 92432   Mont Blanc Northbrook Drop-in Composite Granit...
# 9508    Sure Comfort 40 Gal. Tall 3 Year 34,000 BTU Na...
# 199586  GE Choice Alert Wireless Alarm System with Ala...
# 85851   Oakland Living 26 in. Metal Grape Table Plant ...
# 83392             Rubbermaid FastTrack Garage Cooler Hook
# 45248   Globalrose Red Mini Carnations (160 Stems) Inc...
# 132180      ZUO Nob Hill Tufted Loveseat in Charcoal Gray
# 29109   Showerdoordirect 36 in. Frameless Shower Door ...
# 39795   Winchester 3 Ton 13 SEER Sweat A/C System with...
# 7470    Samsung 30 in. W 1.6 cu. ft. Over the Range Mi...
# 58986   Lincoln Electric Wire Feed .030 Welder Contact...
# 176212                   Drive All Terrain Cane in Bronze
# 198022       Alpine 15 in. Large Red Bowl Plastic Planter
# 96402    Zadro Surround Light 7X Vanity Mirror in Acrylic
# 51369   5 ft. x 30 ft. Dalen Products Nylon Trellis Ne...
# 139648  Thermo-Tex 30 ft. 7-Year Round Clear Above Gro...
# 80767   Entryways Orange Butterfly 18 in. x 30 in. Han...
# 142618  Builder&#39;s Choice Richmond 4 ft. x 3-3/4 in...
# ...                                                   ...
# 136208  1/8 - 3/4 in. Cast-Iron MPT Valve Replacement ...
# 141028                    Ryobi Router Bit Set (15-Piece)
# 62868   Ryobi 40-Volt X Lithium-Ion Cordless Attachmen...
# 131553  Crown MetalWorks Black Traditional Decorative ...
# 32385   Henry 4.75 Gal. 287 Solar-Flex White Roof Coating
# 186008  SharkBite 3/4 in. Brass PEX Barb Coupling (10-...
# 130463  SharkBite 1/2 in. Brass PEX Barb Coupling (10-...
# 26128   Apache Mills Weave Brown 18 in. x 30 in. Recyc...
# 1724    New York Wire 5/16 in. x 48 in. White Aluminum...
# 32827   Red Head 1/2 in. x 3 in. Steel Hex-Nut-Head Sl...
# 6019    WeatherShield 2 in. x 6 in. x 12 ft. #2 Prime ...
# 156454  Master Lock 1-9/16 in. Vinyl Covered Solid Bod...
# 63878   Commercial Electric 11 in. Stainless Steel Tie...
# 105976  St. Paul 61 in. x 22 in. AB Engineered Technol...
# 188115          Ariens 9 in. 136 cc Walk-Behind Gas Edger
# 187815  St. Paul Providence 20 in. W Over John Wall Ca...
# 181161                         Duck Flexible Faucet Cover
# 72410   Poulan PRO PR625Y22RKP 22 in. Variable Speed F...
# 219333  York Wallcoverings 60.75 sq. ft. Ashford Geome...
# 191355  York Wallcoverings 60.75 sq. ft. Ashford Geome...
# 218672  Whitehaus Collection 3.5 in. Garbage Disposal ...
# 84812   Home Decorators Collection Niya 32 in. IR Elec...
# 37034             Frost King 12 ft. Water Pipe Heat Cable
# 170619  3NLED 3 ft. T8 14-Watt Cool White G13 Frosted ...
# 67417   Toro Replacement Scraper and Hardware Kit for ...
# 24607   Paslode 3 in. x 0.120 in. 21å¡ Brite Smooth Na...
# 89813         CE TECH 1-Line Wall Jack Wall Plate - White
# 150341  Rust-Oleum Painter&#39;s Touch 32 oz. Ultra Co...
# 160671              Everbilt Bright Brass Solid Door Stop
# 134560  Gardensun 11,000 BTU Powder Coated Bronze Tabl...
#
#                                                     descr  \
# id
# 69679   enhanc home romano boxwood spiral topiari tree...
# 156918  7114-1 one-sect round rung 14 ft. straight lad...
# 120624  whether boil pasta, make batch chili cook grai...
# 69064   want air movement without noise. got it. big a...
# 204530  bird stop blue ceram wild bird feeder featur b...
# 136808  earthquak 6015v rear tine rototil deliv ultim ...
# 104722  repair leaki faucet easi inexpens altern repla...
# 176724  cornerston collect quality, incandesc vaniti e...
# 109498  help tomato plant grow lush tall 42 in. tomato...
# 17236   ortho home defens max 1.33 gal. ready-to-us pe...
# 98819   patio door roller construct steel tandem rolle...
# 93622   daylili vigor perenni requir littl care garden...
# 92432   durabl granit composit materi provid mont blan...
# 9508    sure comfort 40 gal. natur gas tall water heat...
# 199586  ge choic alert wireless alarm system alarm sir...
# 85851   oakland live 26 in. metal grape tabl plant sta...
# 83392   part fasttrack system, cooler hook perfect sol...
# 45248   mini red carnat grown environment greenhouses,...
# 132180  sturdi loveseat versatil appear rich color fin...
# 29109   seal use bottom door use seal side door. desig...
# 39795   singl phase 13 seer sweat air condit system de...
# 7470    samsung 1.6 cu. ft. rang microwav provid ampl ...
# 58986   lincoln electr wire feed welder contact tip (1...
# 176212  bronz terrain cane drive medic allow peopl red...
# 198022  bowl planter perfect patio decks. avail variet...
# 96402   surround light 7x acryl vaniti mirror offer sl...
# 51369   heavy-duti nylon trelli net ideal grow tomatoe...
# 139648  thermo-tex clear solar blanket extend swim sea...
# 80767   design artist, distinct mat work art add welco...
# 142618  add sens timeless beauti fireplac home decor f...
# ...                                                   ...
# 136208  mueller streamlin 1/8 - 3/4 in. cast-iron mpt ...
# 141028  ryobi introduc ryobi 15-piec router bit set. r...
# 62868   gas-lik power want, attach capabl need. ryobi ...
# 131553  tradit style decor garag door hardwar kit inst...
# 32385   henri 287 solar-flex white roof coat premium, ...
# 186008  sharkbit pex barb coupl (10-pack) easi install...
# 130463  sharkbit pex barb coupl (10-pack) easi install...
# 26128   apach mill weav brown 18 in. x 30 in. recycl r...
# 1724    5/16 in. x 48 in. aluminum screen frame kit in...
# 32827   red head 1/2 in. x 3 in. steel hex-nut-head sl...
# 6019    weathershield 2 in. x 6 in. x 12 ft. pressure-...
# 156454  no. 141 padlock featur 1-9/16 in. (40 mm) wide...
# 63878   stainless steel cabl tie design secur horses, ...
# 105976  featur timeless, classic style clean line desi...
# 188115  flexibility, edger arien can't beat. multipl a...
# 187815  clean line classic styling, st. john provid jo...
# 181161  home smart earth friendly, cover easi instal p...
# 72410   self-propel model premium poulan pro walk behi...
# 219333  pattern compos interlock band form varieti sha...
# 191355  pattern compos interlock band form varieti sha...
# 218672  whitehaus collect 3 1/2 in. garbag dispos trim...
# 84812   home decor electr fireplac provid supplement h...
# 37034   thermwel product co. inc. 12 ft. water pipe he...
# 170619  led linear tubes, replac tradit t5/t8/t10/t12 ...
# 67417   scraper hardwar kit help ensur optimum perform...
# 24607   new paslod 21 plastic collat frame nail best n...
# 89813   replac old wall jack instal new one wall jack ...
# 150341  painter touch 32 oz. general purpos brush pain...
# 160671  everbilt solid doorstop help prevent damag wal...
# 134560  stay warm winter season powder coat bronz tabl...
#
#                                                orig_descr  \
# id
# 69679   Enhance your home with a Romano Boxwood Spiral...
# 156918  The 7114-1 one-section round rung 14 ft. Strai...
# 120624  Whether you're boiling pasta, making a batch o...
# 69064   Want air movement without noise. You've got it...
# 204530  The Bird Stop Blue Ceramic Wild Bird Feeder fe...
# 136808  The Earthquake 6015V rear tine rototiller deli...
# 104722  Repairing a leaky faucet is an easy and inexpe...
# 176724  The cornerstone of this collection is quality,...
# 109498  Help your tomato plant grow lush and tall with...
# 17236   The Ortho Home Defense Max 1.33 Gal. Ready-to-...
# 98819   This patio door roller is constructed from ste...
# 93622   Daylilies are vigorous perennial that require ...
# 92432   Durable granite composite material provides th...
# 9508    The Sure Comfort 40 Gal. Natural Gas Tall Wate...
# 199586  The GE Choice Alert Wireless Alarm System Alar...
# 85851   The Oakland Living 26 in. Metal Grape Table Pl...
# 83392   Part of the FastTrack system, the Cooler Hook ...
# 45248   Mini Red carnations are grown in environmental...
# 132180  A sturdy loveseat with a versatile appearance ...
# 29109   The seal can be used for the bottom of the doo...
# 39795   This single phase 13 SEER sweat air conditioni...
# 7470    The Samsung 1.6 cu. ft. Over the Range Microwa...
# 58986   The Lincoln Electric Wire Feed Welder Contact ...
# 176212  The Bronze All Terrain Cane by Drive Medical a...
# 198022  These bowl planters are perfect for patios and...
# 96402   The Surround Light 7X Acrylic Vanity Mirror of...
# 51369   Our heavy-duty nylon trellis netting is ideal ...
# 139648  Thermo-Tex clear Solar blankets will extend yo...
# 80767   Designed by an artist, this distinctive mat is...
# 142618  Add a sense of timeless beauty to your firepla...
# ...                                                   ...
# 136208  The MUELLER STREAMLINE 1/8 - 3/4 in. Cast-Iron...
# 141028  Ryobi introduces the Ryobi 15-Piece Router Bit...
# 62868   Gas-like power you want, attachment capability...
# 131553  The Traditional Style Decorative Garage Door H...
# 32385   Henry 287 Solar-Flex White Roof Coating is a p...
# 186008  The SharkBite PEX Barb Coupling (10-Pack) is a...
# 130463  The SharkBite PEX Barb Coupling (10-Pack) is a...
# 26128   The Apache Mills Weave Brown 18 in. x 30 in. R...
# 1724    5/16 in. x 48 in. Aluminum Screen Frame Kit in...
# 32827   Red Head 1/2 in. x 3 in. Steel Hex-Nut-Head Sl...
# 6019    The WeatherShield 2 in. x 6 in. x 12 ft. Press...
# 156454  The No. 141 padlock features a 1-9/16 in. (40 ...
# 63878   A stainless steel cable tie is designed to sec...
# 105976  Featuring timeless, classic styling with a cle...
# 188115  For flexibility, this edger from Ariens can't ...
# 187815  With clean lines and classic styling, the St. ...
# 181161  Home smart and Earth friendly, this cover is e...
# 72410   This self-propelled model is the most premium ...
# 219333  This pattern is composed of interlocking bands...
# 191355  This pattern is composed of interlocking bands...
# 218672  Whitehaus Collection 3 1/2 in. garbage disposa...
# 84812   This Home Decorators electric fireplace provid...
# 37034   The Thermwell Products Co. Inc. 12 ft. Water P...
# 170619  LED linear Tubes, replacement for traditional ...
# 67417   This Scraper and Hardware kit helps ensure opt...
# 24607   New Paslode 21 Plastic Collated Framing Nails ...
# 89813   Replace an old wall jack or install a new one ...
# 150341  The Painter's Touch 32 oz. general purpose bru...
# 160671  The Everbilt Solid Doorstop helps prevent dama...
# 134560  Stay warm this winter season with this Powder ...
#
#         match_product_title  match_descr    ...      len_search_term_letters  \
# id                                          ...
# 69679              1.000000     1.000000    ...                           12
# 156918             0.666667     0.666667    ...                           12
# 120624             1.000000     0.500000    ...                           11
# 69064              1.000000     1.000000    ...                            7
# 204530             1.000000     1.000000    ...                            9
# 136808             1.000000     0.000000    ...                           11
# 104722             0.500000     0.500000    ...                           12
# 176724             1.000000     0.500000    ...                           11
# 109498             0.500000     1.000000    ...                           12
# 17236              0.500000     0.500000    ...                           10
# 98819              0.500000     1.000000    ...                           11
# 93622              1.000000     1.000000    ...                           11
# 92432              1.000000     1.000000    ...                           11
# 9508               0.500000     1.000000    ...                           18
# 199586             0.666667     0.666667    ...                           23
# 85851              1.000000     1.000000    ...                           11
# 83392              1.000000     0.500000    ...                           17
# 45248              1.000000     0.500000    ...                            9
# 132180             1.000000     1.000000    ...                            3
# 29109              1.000000     0.333333    ...                           14
# 39795              0.500000     0.500000    ...                           14
# 7470               0.500000     0.500000    ...                            8
# 58986              0.500000     0.500000    ...                           15
# 176212             0.500000     0.500000    ...                           15
# 198022             1.000000     0.000000    ...                           10
# 96402              0.500000     0.500000    ...                           11
# 51369              0.500000     0.500000    ...                           12
# 139648             1.000000     0.500000    ...                           12
# 80767              1.000000     0.000000    ...                           13
# 142618             0.500000     1.000000    ...                           14
# ...                     ...          ...    ...                          ...
# 136208             1.000000     1.000000    ...                           12
# 141028             0.666667     0.333333    ...                           17
# 62868              0.000000     0.000000    ...                           15
# 131553             0.250000     0.500000    ...                           22
# 32385              0.000000     0.000000    ...                           17
# 186008             0.666667     0.666667    ...                           19
# 130463             0.666667     0.666667    ...                           19
# 26128              0.666667     0.666667    ...                           14
# 1724               0.500000     0.500000    ...                           23
# 32827              1.000000     1.000000    ...                           12
# 6019               0.000000     0.000000    ...                           22
# 156454             0.500000     0.500000    ...                            8
# 63878              0.500000     1.000000    ...                            8
# 105976             0.333333     0.333333    ...                           19
# 188115             0.666667     0.333333    ...                           16
# 187815             0.750000     0.750000    ...                           27
# 181161             0.000000     0.333333    ...                           18
# 72410              0.400000     0.600000    ...                           27
# 219333             1.000000     0.500000    ...                           15
# 191355             1.000000     0.500000    ...                           15
# 218672             0.666667     0.333333    ...                           19
# 84812              0.666667     0.666667    ...                           21
# 37034              0.500000     0.500000    ...                            9
# 170619             0.666667     0.000000    ...                           14
# 67417              1.000000     1.000000    ...                           16
# 24607              0.666667     1.000000    ...                           17
# 89813              0.400000     0.400000    ...                           28
# 150341             1.000000     0.666667    ...                           17
# 160671             0.750000     0.500000    ...                           25
# 134560             0.500000     0.000000    ...                           13
#
#         complete_match_title  complete_match_descr  match_pos_title  \
# id
# 69679                      1                     1         1.000000
# 156918                     0                     0         1.000000
# 120624                     1                     0         1.000000
# 69064                      1                     1         1.000000
# 204530                     1                     1         1.000000
# 136808                     1                     0         1.000000
# 104722                     0                     0         0.500000
# 176724                     0                     0         0.500000
# 109498                     0                     1         0.500000
# 17236                      0                     0         0.500000
# 98819                      0                     0         0.500000
# 93622                      0                     0         0.500000
# 92432                      0                     0         1.000000
# 9508                       0                     0         0.500000
# 199586                     0                     0         1.000000
# 85851                      0                     0         1.000000
# 83392                      0                     0         1.000000
# 45248                      1                     0         1.000000
# 132180                     1                     1         0.000000
# 29109                      0                     0         0.666667
# 39795                      0                     0         0.500000
# 7470                       0                     0         0.500000
# 58986                      0                     0         0.000000
# 176212                     0                     0         0.333333
# 198022                     0                     0         1.000000
# 96402                      0                     0         0.000000
# 51369                      0                     0         0.000000
# 139648                     0                     0         1.000000
# 80767                      1                     0         1.000000
# 142618                     0                     0         0.500000
# ...                      ...                   ...              ...
# 136208                     1                     1         1.000000
# 141028                     0                     0         0.333333
# 62868                      0                     0         0.500000
# 131553                     0                     0         0.250000
# 32385                      0                     0         0.000000
# 186008                     0                     0         0.333333
# 130463                     0                     0         0.333333
# 26128                      0                     0         0.666667
# 1724                       0                     0         0.500000
# 32827                      1                     1         0.500000
# 6019                       0                     0         0.600000
# 156454                     0                     0         0.000000
# 63878                      0                     1         0.000000
# 105976                     0                     0         0.333333
# 188115                     0                     0         0.666667
# 187815                     0                     0         0.500000
# 181161                     0                     0         0.000000
# 72410                      0                     0         0.400000
# 219333                     0                     0         1.000000
# 191355                     0                     0         1.000000
# 218672                     0                     0         0.666667
# 84812                      0                     0         0.333333
# 37034                      0                     0         0.000000
# 170619                     0                     0         0.666667
# 67417                      0                     1         1.000000
# 24607                      0                     0         0.666667
# 89813                      0                     0         0.600000
# 150341                     0                     0         0.666667
# 160671                     0                     0         0.750000
# 134560                     0                     0         0.500000
#
#         match_pos_descr                     brand match_brand  prod_title_ind  \
# id
# 69679          3.000000                       NaN    0.000000        0.714286
# 156918         1.000000                       NaN    0.000000        0.062500
# 120624         0.500000                       NaN    0.000000        0.000000
# 69064          1.000000                       NaN    0.000000        0.000000
# 204530         1.000000                     heath    0.000000        0.125000
# 136808         0.000000                       NaN    0.000000        0.750000
# 104722         0.250000                       NaN    0.000000        0.833333
# 176724         1.000000              green matter    0.083333        0.000000
# 109498         1.000000         gilbert & bennett    0.000000        0.777778
# 17236          0.500000                     ortho    0.000000        0.818182
# 98819          1.000000                       NaN    0.000000        0.307692
# 93622          1.000000                       NaN    0.000000        0.125000
# 92432          1.000000                mont blanc    0.000000        0.333333
# 9508           5.000000              sure comfort    0.000000        0.769231
# 199586         6.000000                        ge    0.000000        0.500000
# 85851          1.000000                       NaN    0.000000        0.555556
# 83392          0.500000                       NaN    0.000000        0.000000
# 45248          0.500000                       NaN    0.000000        0.777778
# 132180         0.000000                       NaN    0.000000        0.142857
# 29109          0.333333          showerdoordirect    0.000000        0.083333
# 39795          3.500000                  winchest    0.000000        0.866667
# 7470           1.000000                   samsung    0.000000        0.636364
# 58986          1.000000            lincoln electr    0.000000        0.555556
# 176212         1.666667                     drive    0.000000        0.250000
# 198022         0.000000                     alpin    0.200000        0.000000
# 96402          0.500000                       NaN    0.000000        0.285714
# 51369          0.000000                   unbrand    0.000000        0.900000
# 139648         0.500000                       NaN    0.000000        0.500000
# 80767          0.000000                  entryway    0.000000        0.714286
# 142618         2.000000                       NaN    0.000000        0.666667
# ...                 ...                       ...         ...             ...
# 136208         1.000000                   unbrand    0.000000        0.777778
# 141028         0.333333                     ryobi    0.000000        0.400000
# 62868          0.500000                     ryobi    0.000000        1.000000
# 131553         1.000000           crown metalwork    0.000000        0.875000
# 32385          0.000000                     henri    0.000000        1.000000
# 186008         0.333333                  sharkbit    0.000000        0.375000
# 130463         0.333333                  sharkbit    0.000000        0.375000
# 26128          2.333333                apach mill    0.000000        0.846154
# 1724           1.166667             new york wire    0.000000        0.714286
# 32827          1.000000                  red head    0.000000        0.750000
# 6019           1.000000             weathershield    0.000000        1.000000
# 156454         0.500000               master lock    0.090909        0.100000
# 63878          1.000000                       NaN    0.000000        0.750000
# 105976         0.333333                  st. paul    0.000000        0.666667
# 188115         0.333333                     arien    0.000000        0.750000
# 187815         1.000000                  st. paul    0.000000        0.700000
# 181161         0.333333                      duck    0.000000        1.000000
# 72410          0.800000                poulan pro    0.200000        0.000000
# 219333         1.000000              york wallcov    0.000000        0.500000
# 191355         1.000000              york wallcov    0.000000        0.500000
# 218672         0.333333         whitehaus collect    0.000000        0.555556
# 84812          0.666667                       NaN    0.000000        0.636364
# 37034          0.000000                frost king    0.000000        0.750000
# 170619         0.000000                       NaN    0.000000        0.333333
# 67417          1.000000                       NaN    0.000000        0.000000
# 24607          1.666667                       NaN    0.000000        0.000000
# 89813          1.800000                   ce tech    0.000000        0.333333
# 150341         1.333333  rust-oleum painter touch    0.000000        0.533333
# 160671         0.500000                  everbilt    0.000000        0.166667
# 134560         0.000000                 gardensun    0.000000        0.900000
#
#         descr_ind  pred_diff
# id
# 69679    0.092593   1.625023
# 156918   0.064516   1.462272
# 120624   0.440367   1.448728
# 69064    0.052632   1.422245
# 204530   0.000000   1.411231
# 136808   1.000000   1.409618
# 104722   0.514286   1.395762
# 176724   0.109756   1.382297
# 109498   0.023810   1.363714
# 17236    0.121951   1.348652
# 98819    0.057143   1.348345
# 93622    0.515625   1.345182
# 92432    0.008130   1.343299
# 9508     0.027778   1.332122
# 199586   0.020513   1.324238
# 85851    0.084746   1.322158
# 83392    0.051724   1.321872
# 45248    0.712871   1.320059
# 132180   0.163934   1.315470
# 29109    0.090909   1.305274
# 39795    0.089385   1.292350
# 7470     0.028777   1.287858
# 58986    0.088889   1.280936
# 176212   0.011494   1.271254
# 198022   1.000000   1.263986
# 96402    0.018519   1.262827
# 51369    0.045455   1.260434
# 139648   0.012346   1.260215
# 80767    1.000000   1.258576
# 142618   0.039604   1.257123
# ...           ...        ...
# 136208   0.187500   0.000196
# 141028   0.094340   0.000192
# 62868    1.000000   0.000185
# 131553   0.095238   0.000183
# 32385    1.000000   0.000180
# 186008   0.030928   0.000178
# 130463   0.030928   0.000178
# 26128    0.115789   0.000177
# 1724     0.074074   0.000175
# 32827    0.157895   0.000171
# 6019     1.000000   0.000167
# 156454   0.932203   0.000160
# 63878    0.044444   0.000156
# 105976   0.132812   0.000139
# 188115   0.010753   0.000120
# 187815   0.073394   0.000118
# 181161   0.210526   0.000107
# 72410    0.020548   0.000103
# 219333   0.257143   0.000102
# 191355   0.257143   0.000102
# 218672   0.146341   0.000101
# 84812    0.031746   0.000098
# 37034    0.166667   0.000084
# 170619   1.000000   0.000080
# 67417    0.118644   0.000064
# 24607    0.017241   0.000063
# 89813    0.050000   0.000051
# 150341   0.086420   0.000025
# 160671   0.464286   0.000020
# 134560   1.000000   0.000019
#
# [74067 rows x 21 columns]

# %%
train['match_pos_title'] = train.apply(
    lambda x: match_word_n_pos(x['orig_product_title'], x['orig_search_term']), axis=1)
train['match_pos_descr'] = train.apply(
    lambda x: match_word_n_pos(x['orig_descr'], x['orig_search_term']), axis=1)
train['brand'].fillna('', inplace=True)

# %%
params = {
    'gbm__learning_rate': [0.05],
    'gbm__n_estimators': [700],
    'gbm__num_leaves': [60],
    'gbm__colsample_bytree': [0.7]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 0        0.031314                         0.7                     0.05
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 0                     700                    60
#
#                                               params  split0_test_score  \
# 0  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.216036
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0          -0.207662          -0.235604        -0.219767        0.011709
#
#    rank_test_score
# 0                1

# %%
test['match_pos_title'] = test.apply(
    lambda x: match_word_n_pos(x['orig_product_title'], x['orig_search_term']), axis=1)
test['match_pos_descr'] = test.apply(
    lambda x: match_word_n_pos(x['orig_descr'], x['orig_search_term']), axis=1)

# %%
test['brand'].fillna('', inplace=True)
train.to_csv('train_processed.csv')
test.to_csv('test_processed.csv')

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47696

# %%
def word_match_std(search_term, text):
    indexes = []
    search_term = search_term.split()
    text = text.split()    
    n = len(text)
    if len(search_term) == 0:
        return 0
    for word in set(search_term):
        if word in text:
            indexes.append(text.index(word))
    if len(indexes) > 0:
        return np.var(indexes)
    else:
        return 0

# %%
train['words_std_title'] = train.apply(
    lambda x: match_word_n_pos(x['search_term'], x['product_title']), axis=1)
train['words_std_descr'] = train.apply(
    lambda x: match_word_n_pos(x['search_term'], x['descr']), axis=1)

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']
clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')), ('tfidf1', tfidf), ('tsvd1', tsvd80)])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')), ('tfidf2', tfidf), ('tsvd2', tsvd80)])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')), ('tfidf3', tfidf), ('tsvd3', tsvd60)])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')), ('tfidf4', tfidf), ('tsvd4', tsvd35)]))
                    ]
            )), 
    ('gbm', gbm)])

params = {
    'gbm__learning_rate': [0.05],
    'gbm__n_estimators': [700],
    'gbm__num_leaves': [60],
    'gbm__colsample_bytree': [0.7]
}
model = GridSearchCV(clf, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False)
model.fit(train[use_cols], y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
#    std_score_time param_gbm__colsample_bytree param_gbm__learning_rate  \
# 0        0.022354                         0.7                     0.05
#
#   param_gbm__n_estimators param_gbm__num_leaves  \
# 0                     700                    60
#
#                                               params  split0_test_score  \
# 0  {'gbm__colsample_bytree': 0.7, 'gbm__learning_...          -0.215824
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0          -0.206791          -0.236066         -0.21956         0.01224
#
#    rank_test_score
# 0                1

# %%
print(model.best_estimator_.named_steps['gbm'].feature_importances_[:11],
      model.best_estimator_.named_steps['gbm'].feature_importances_[11:91],
      model.best_estimator_.named_steps['gbm'].feature_importances_[91:171],
      model.best_estimator_.named_steps['gbm'].feature_importances_[171:231],
      model.best_estimator_.named_steps['gbm'].feature_importances_[231:],
      sep='\n'
     )
print(use_cols)
# Out:
# [246 170 129 367 197  34 148 364 277 293 203]
# [268 214 182 145 143 150 160 177 147 204 184 176 156 175 206 168 137 151
#  173 164 177 159 176 161 139 181 165 157 154 179 154 176 158 204 172 152
#  160 182 194 154 161 158 187 157 190 174 189 169 190 152 206 178 191 174
#  189 227 190 179 187 197 180 232 217 202 188 214 160 180 163 198 208 187
#  178 196 223 206 172 215 212 215]
# [215 168 155 140 135 144 121 163 130 138 153 132 128 138 165 188 125 160
#  145 136 156 152 121 148 138 132 147 167 146 131 171 147 165 131 174 152
#  161 158 138 152 140 134 135 149 141 155 157 158 137 166 132 134 142 141
#  131 137 138 165 197 161 214 167 179 175 136 155 169 175 166 151 160 164
#  190 185 167 196 206 141 171 155]
# [276 151 175 122 139 140 139 185 137 154 147 154 163 155 165 136 145 157
#  159 179 139 158 172 155 190 162 152 149 152 181 160 170 149 168 138 182
#  147 158 133 150 164 117 157 155 178 156 214 198 156 177 186 160 176 175
#  193 135 187 198 204 188]
# [ 81  63  78 127  86  80  74  78  76  68  83  66  77  66  67  85  76  94
#   74  94  59  95  63  59  75  62  61  69  69  87]
# ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters', 'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind', 'words_std_title', 'words_std_descr', 'search_term', 'product_title', 'descr', 'brand']

# %%
test['words_std_title'] = test.apply(
    lambda x: match_word_n_pos(x['search_term'], x['product_title']), axis=1)
test['words_std_descr'] = test.apply(
    lambda x: match_word_n_pos(x['search_term'], x['descr']), axis=1)
train.to_csv('train_processed.csv')
test.to_csv('test_processed.csv')

# %%
y_pred = model.predict(test[use_cols])
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47588

# %% [markdown]
# It was a mistake to fit the TfIDf and SVD every time

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'words_std_title', 'words_std_descr']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=30))]))
                    ]
            ))])

clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])

# %%
gbm = lgb.LGBMRegressor(learning_rate=0.05, n_estimators=600, num_leaves=60, colsample_bytree=0.7)
gbm.fit(X_train, y)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=0.7,
#        importance_type='split', learning_rate=0.05, max_depth=-1,
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=600, n_jobs=-1, num_leaves=60, objective=None,
#        random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
X_test = clf.transform(test[use_cols])

# %%
y_pred = gbm.predict(X_test)
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47543

# %%
params = {
    'learning_rate': [0.04, 0.05],
    'n_estimators': [600, 700],
    'num_leaves': [60, 70]
}
model = GridSearchCV(gbm, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] learning_rate=0.04, n_estimators=600, num_leaves=60 .............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.04, n_estimators=600, num_leaves=60, total=  13.4s
# [CV] learning_rate=0.04, n_estimators=600, num_leaves=60 .............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.4s remaining:    0.0s
# [CV]  learning_rate=0.04, n_estimators=600, num_leaves=60, total=  13.4s
# [CV] learning_rate=0.04, n_estimators=600, num_leaves=60 .............
# [CV]  learning_rate=0.04, n_estimators=600, num_leaves=60, total=  13.2s
# [CV] learning_rate=0.04, n_estimators=600, num_leaves=70 .............
# [CV]  learning_rate=0.04, n_estimators=600, num_leaves=70, total=  15.3s
# [CV] learning_rate=0.04, n_estimators=600, num_leaves=70 .............
# [CV]  learning_rate=0.04, n_estimators=600, num_leaves=70, total=  15.0s
# [CV] learning_rate=0.04, n_estimators=600, num_leaves=70 .............
# [CV]  learning_rate=0.04, n_estimators=600, num_leaves=70, total=  14.9s
# [CV] learning_rate=0.04, n_estimators=700, num_leaves=60 .............
# [CV]  learning_rate=0.04, n_estimators=700, num_leaves=60, total=  15.3s
# [CV] learning_rate=0.04, n_estimators=700, num_leaves=60 .............
# [CV]  learning_rate=0.04, n_estimators=700, num_leaves=60, total=  15.4s
# [CV] learning_rate=0.04, n_estimators=700, num_leaves=60 .............
# [CV]  learning_rate=0.04, n_estimators=700, num_leaves=60, total=  14.9s
# [CV] learning_rate=0.04, n_estimators=700, num_leaves=70 .............
# [CV]  learning_rate=0.04, n_estimators=700, num_leaves=70, total=  17.3s
# [CV] learning_rate=0.04, n_estimators=700, num_leaves=70 .............
# [CV]  learning_rate=0.04, n_estimators=700, num_leaves=70, total=  17.1s
# [CV] learning_rate=0.04, n_estimators=700, num_leaves=70 .............
# [CV]  learning_rate=0.04, n_estimators=700, num_leaves=70, total=  16.9s
# [CV] learning_rate=0.05, n_estimators=600, num_leaves=60 .............
# [CV]  learning_rate=0.05, n_estimators=600, num_leaves=60, total=  13.0s
# [CV] learning_rate=0.05, n_estimators=600, num_leaves=60 .............
# [CV]  learning_rate=0.05, n_estimators=600, num_leaves=60, total=  13.1s
# [CV] learning_rate=0.05, n_estimators=600, num_leaves=60 .............
# [CV]  learning_rate=0.05, n_estimators=600, num_leaves=60, total=  12.9s
# [CV] learning_rate=0.05, n_estimators=600, num_leaves=70 .............
# [CV]  learning_rate=0.05, n_estimators=600, num_leaves=70, total=  14.8s
# [CV] learning_rate=0.05, n_estimators=600, num_leaves=70 .............
# [CV]  learning_rate=0.05, n_estimators=600, num_leaves=70, total=  14.5s
# [CV] learning_rate=0.05, n_estimators=600, num_leaves=70 .............
# [CV]  learning_rate=0.05, n_estimators=600, num_leaves=70, total=  14.4s
# [CV] learning_rate=0.05, n_estimators=700, num_leaves=60 .............
# [CV]  learning_rate=0.05, n_estimators=700, num_leaves=60, total=  14.8s
# [CV] learning_rate=0.05, n_estimators=700, num_leaves=60 .............
# [CV]  learning_rate=0.05, n_estimators=700, num_leaves=60, total=  14.9s
# [CV] learning_rate=0.05, n_estimators=700, num_leaves=60 .............
# [CV]  learning_rate=0.05, n_estimators=700, num_leaves=60, total=  14.6s
# [CV] learning_rate=0.05, n_estimators=700, num_leaves=70 .............
# [CV]  learning_rate=0.05, n_estimators=700, num_leaves=70, total=  16.6s
# [CV] learning_rate=0.05, n_estimators=700, num_leaves=70 .............
# [CV]  learning_rate=0.05, n_estimators=700, num_leaves=70, total=  16.6s
# [CV] learning_rate=0.05, n_estimators=700, num_leaves=70 .............
# [CV]  learning_rate=0.05, n_estimators=700, num_leaves=70, total=  16.3s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  6.0min finished
#    std_score_time param_learning_rate param_n_estimators param_num_leaves  \
# 2        0.001156                0.04                700               60
# 3        0.000475                0.04                700               70
# 7        0.002203                0.05                700               70
# 6        0.001235                0.05                700               60
# 0        0.001697                0.04                600               60
#
#                                               params  split0_test_score  \
# 2  {'learning_rate': 0.04, 'n_estimators': 700, '...          -0.213699
# 3  {'learning_rate': 0.04, 'n_estimators': 700, '...          -0.213289
# 7  {'learning_rate': 0.05, 'n_estimators': 700, '...          -0.214312
# 6  {'learning_rate': 0.05, 'n_estimators': 700, '...          -0.214166
# 0  {'learning_rate': 0.04, 'n_estimators': 600, '...          -0.213928
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2          -0.204396          -0.232376        -0.216823        0.011634
# 3          -0.204236          -0.233006        -0.216844        0.012011
# 7          -0.205031          -0.232094        -0.217146        0.011228
# 6          -0.204745          -0.232549        -0.217154        0.011546
# 0          -0.204712          -0.232919        -0.217186        0.011744
#
#    rank_test_score
# 2                1
# 3                2
# 7                3
# 6                4
# 0                5

# %%
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %% [markdown]
# 0.47476

# %%
train['pred_diff'] = (train['relevance'] - model.predict(X_train)).abs()
train.sort_values(['pred_diff'], ascending=False)
# Out:
#         product_uid                                      product_title  \
# id
# 120624       140844                  rachael ray 10 qt. cover stockpot
# 156918       160006  werner 14 ft. fiberglass round rung straight l...
# 69679        119478           romano 4 ft. boxwood spiral topiari tree
# 136808       148897   earthquak 212cc tiller rear tine crt side shield
# 9508         101618  sure comfort 40 gal. tall 3 year 34,000 btu na...
# 85851        125582   oakland live 26 in. metal grape tabl plant stand
# 104722       133520                    danco low lead 1a-3c stem crane
# 176724       172318  green matter 3-light mahogani bronz vaniti fixtur
# 17236        103041  ortho home defens max 1.33 gal. perimet indoor...
# 198022       187480         alpin 15 in. larg red bowl plastic planter
# 211891       198538     ce tech 6 ft. 8-outlet usb rj45 surg protector
# 93622        128763  daylili grape magic bare root dormant plant (8...
# 146582       154163  tuscani coast 2-light weather charcoal outdoor...
# 45248        111134  globalros red mini carnat (160 stems) includ f...
# 215764       201760  electrolux iq touch 4.6 cu. ft. electr rang fr...
# 188479       180470  laura ashley freya 3-light weather cognac vani...
# 742          100129          sundstrom safeti silicon half mask respir
# 137108       149071           viagrow strawberri planter vertic garden
# 31303        106875  amana 5.0 cu. ft. gas rang self-clean oven sta...
# 198125       187565  home decor collect garden 45.5 in. h blue bar ...
# 3909         100682    19/32 in. x 24 in. x 4 ft. osb attic deck board
# 134157       147541           lithonia light led troffer dimmer switch
# 143520       152517  shanko 2 ft. x 2 ft. lay-in suspend grid ceil ...
# 108146       135002  daylight naturalight 22-watt energi save circu...
# 69064        119252  big ass fan 3600 144 in. yellow silver aluminu...
# 181466       175543             ginger surfac towel ring polish chrome
# 108375       135102  speedi-grill 24 in. x 6 in. base board return ...
# 159057       161288  sharkbit 1/2 in. brass pex barb x femal thread...
# 76474        121983  philip 50-watt halogen mr16 12-volt landscap l...
# 58046        115431  sharkbit 1/2 in. chrome-pl brass push-to-conne...
# ...             ...                                                ...
# 155170       159008            ge 7.5 cu. ft. electr dryer steam white
# 80130        123384  impact plus bevel edg mirror solid core chrome...
# 104919       133617  rheem ecosens 6.4 gpm natur gas mid effici out...
# 80381        123473  veranda 4 ft. x 8 ft. cedar grove redwood viny...
# 174147       170613                            economi putti knife set
# 158951       161228       behr marque #icc-57 dri thyme exterior paint
# 16751        102954  marazzi montagna saddl 6 in. x 24 glaze porcel...
# 182795       176467  air king quiet zone 36 in. convert rang hood w...
# 212380       198938  dreamlin eleg 49-1/4 51-1/4 in. x 72 in. semi-...
# 44437        110888  marazzi montagna wood vintag chic 6 in. x 24 i...
# 82006        124105  sharpi assort color fine point oil-bas paint m...
# 198200       187615       folkart 2-oz. black cherri acryl craft paint
# 24846        104975  everbilt 3/8 in. -16 tpi x 4 in. stainless ste...
# 204090       192228  closetmaid impress 25 in. chocol delux hutch c...
# 25449        105141  legrand adorn 1-gang 1 modul wall plate - mirr...
# 175499       171519          supco 12 in. x 9 in. replac ice maker kit
# 184498       177658  creativ accent singl pictur frame green 38 in....
# 158089       160708  rev-a-shelf 18 in. h x 18 in. w x 25 in. doubl...
# 25928        105267  ropp fawn 4 in. x 120 ft. x 0.080 in. vinyl wa...
# 43227        110497  dewalt 20-volt max lithium-ion cordless combo ...
# 188869       180758  flow mediterranean bronz ceil fan replac glass...
# 66372        118319  vigoro 4.2 lb. evergreen holli fertil spike (1...
# 127455       144167   rion grand garden clear 8 ft. x 12 ft. greenhous
# 168864       167262               barton kramer slide glass door handl
# 135629       148285  starlit garden crater white die cast aluminum ...
# 152473       157477  prime-lin die cast slide door cylind lock adap...
# 188456       180455  milwauke larg black m12 lithium-ion cordless r...
# 183894       177236      ryobi 12-volt 3/8 in. cordless drill/driv kit
# 127602       144256        field control power vent 4 in. outsid mount
# 189014       180857  american standard cadet slow close everclean r...
#
#                                    search_term  relevance  \
# id
# 120624                             rachael ray       1.00
# 156918                            14 ft ladder       1.00
# 69679                             topiari tree       1.00
# 136808                             side shield       1.00
# 9508                        hot water tank gas       1.00
# 85851                              grape plant       1.00
# 104722                            101-1h crane       1.00
# 176724                             bronz green       1.00
# 17236                               ant killer       1.00
# 198022                              alpin larg       1.00
# 211891                            ce tech ipad       1.00
# 93622                              grape plant       1.00
# 146582                         tuscani classic       1.00
# 45248                                free ship       1.00
# 215764                    electrolux rang weed       1.00
# 188479                      laura ashley light       1.33
# 742                                  face mask       1.00
# 137108                              strawberri       1.00
# 31303                          gas stove lunch       1.00
# 198125                 bar stool height extend       1.00
# 3909                              attic ladder       1.00
# 134157                           troffer light       1.33
# 143520                                  shanko       1.00
# 108146                     full spectrum light       1.33
# 69064                                  big ass       1.00
# 181466                          surfac gringer       1.00
# 108375                         2.4 white board       1.00
# 159057                      13/16 thread adapt       1.00
# 76474                                12v light       1.00
# 58046                             3/8 compress       1.33
# ...                                        ...        ...
# 155170                   ge dryer knob we1m856       2.00
# 80130                  slide closet door 60x72       2.33
# 104919          tankl water heater gas outdoor       2.67
# 80381                         veranda 4ft fenc       2.67
# 174147                      paint scraper heat       2.00
# 158951                                   thyme       2.33
# 16751                  join compound wall tile       2.33
# 182795                 36 inch white rang hood       2.67
# 212380                                 1/4 1in       2.00
# 44437                towel ring look like wood       2.00
# 82006              paint marker burgondi color       2.33
# 198200                    black cherri stainer       2.00
# 24846   3/8 in.-16 tpi x 6 in. stainless steel       2.67
# 204090                        closet door ogan       2.33
# 25449                                    adron       1.67
# 175499                    ice marker water kit       2.33
# 184498                   creativ accent 9as101       2.00
# 158089                        wood mount shelf       2.00
# 25928                          vinyl base cove       2.67
# 43227                   dedwalt cordless drill       2.67
# 188869                  ranger fan light cover       1.67
# 66372                          holli evergreen       2.67
# 127455                               greenhous       2.67
# 168864                         garg door handl       2.33
# 135629                            garden torch       2.67
# 152473                             door cylind       2.67
# 188456        milwake m12 cordless heat jacket       2.33
# 183894                          rayobi batteri       2.33
# 127602                             outsid vent       2.67
# 189014                      buikid toilet seat       2.33
#
#                               orig_search_term  \
# id
# 120624                             rachael ray
# 156918                            14 ft ladder
# 69679                             topiary tree
# 136808                            side shields
# 9508                        hot water tank gas
# 85851                              grape plant
# 104722                        101-1h for crane
# 176724                            bronze green
# 17236                               ant killer
# 198022                            alpine large
# 211891                            ce tech ipad
# 93622                              grape plant
# 146582                         tuscany classic
# 45248                            free shipping
# 215764                   electrolux range weed
# 188479                   laura ashley lighting
# 742                                 face masks
# 137108                            strawberries
# 31303                          gas stove lunch
# 198125              bar stool height extenders
# 3909                              attic ladder
# 134157                        troffer lighting
# 143520                                  shanko
# 108146                     full spectrum light
# 69064                                  big ass
# 181466                         surface gringer
# 108375                         2.4 white board
# 159057                  13/16 threaded adapter
# 76474                             12v lighting
# 58046                          3/8 compression
# ...                                        ...
# 155170                   ge dryer knob we1m856
# 80130               sliding closet doors 60x72
# 104919        tankles water heater gas outdoor
# 80381                        veranda 4ft fence
# 174147                    paint scraper heated
# 158951                                   thyme
# 16751                  join compound wall tile
# 182795               36 inch white  range hood
# 212380                              1/4 to 1in
# 44437          towel rings that look like wood
# 82006             paint markers burgondy color
# 198200                    black cherry stainer
# 24846   3/8 in.-16 tpi x 6 in. stainless steel
# 204090                  closet doors oganizers
# 25449                                   adrone
# 175499                   ice marker water kits
# 184498                 creative accents 9as101
# 158089                        wood mount shelf
# 25928                          vinyl base cove
# 43227                   dedwalt cordless drill
# 188869                  ranger fan light cover
# 66372                          holly evergreen
# 127455                             greenhouses
# 168864                       garge door handle
# 135629                            garden torch
# 152473                           door cylinder
# 188456     milwakee m12 cordless heated jacket
# 183894                        rayoby batteries
# 127602                           outside vents
# 189014                     buikids toilet seat
#
#                                        orig_product_title  \
# id
# 120624                Rachael Ray 10 qt. Covered Stockpot
# 156918  Werner 14 ft. Fiberglass Round Rung Straight L...
# 69679            Romano 4 ft. Boxwood Spiral Topiary Tree
# 136808  Earthquake 212cc Tiller Rear Tine CRT with Sid...
# 9508    Sure Comfort 40 Gal. Tall 3 Year 34,000 BTU Na...
# 85851   Oakland Living 26 in. Metal Grape Table Plant ...
# 104722                DANCO Low Lead 1A-3C Stem for Crane
# 176724  Green Matters 3-Light Mahogany Bronze Vanity F...
# 17236   Ortho Home Defense Max 1.33 Gal. Perimeter and...
# 198022       Alpine 15 in. Large Red Bowl Plastic Planter
# 211891    CE TECH 6 ft. 8-Outlet USB RJ45 Surge Protector
# 93622   Daylily Grape Magic Bare Root Dormant Plants (...
# 146582  Tuscany Coast 2-Light Weathered Charcoal Outdo...
# 45248   Globalrose Red Mini Carnations (160 Stems) Inc...
# 215764  Electrolux IQ Touch 4.6 cu. ft. Electric Range...
# 188479  Laura Ashley Freya 3-Light Weathered Cognac Va...
# 742        Sundstrom Safety Silicone Half Mask Respirator
# 137108         Viagrow Strawberry Planter Vertical Garden
# 31303   Amana 5.0 cu. ft. Gas Range with Self-Cleaning...
# 198125  Home Decorators Collection Garden 45.5 in. H B...
# 3909    19/32 in. x 24 in. x 4 ft. OSB Attic Decking B...
# 134157        Lithonia Lighting LED Troffer Dimmer Switch
# 143520  Shanko 2 ft. x 2 ft. Lay-in Suspended Grid Cei...
# 108146  Daylight Naturalight 22-Watt Energy Saving Cir...
# 69064   Big Ass Fans 3600 144 in. Yellow and Silver Al...
# 181466       Ginger Surface Towel Ring in Polished Chrome
# 108375  SPEEDI-GRILLE 24 in. x 6 in. Base Board Return...
# 159057  SharkBite 1/2 in. Brass PEX Barb x Female Thre...
# 76474   Philips 50-Watt Halogen MR16 12-Volt Landscape...
# 58046   SharkBite 1/2 in. Chrome-Plated Brass Push-to-...
# ...                                                   ...
# 155170  GE 7.5 cu. ft. Electric Dryer with Steam in White
# 80130   Impact Plus Beveled Edge Mirror Solid Core Chr...
# 104919  Rheem EcoSense 6.4 GPM Natural Gas Mid Efficie...
# 80381   Veranda 4 ft. x 8 ft. Cedar Grove Redwood Viny...
# 174147                            Economy Putty Knife Set
# 158951    BEHR MARQUEE #ICC-57 Dried Thyme Exterior Paint
# 16751   MARAZZI Montagna Saddle 6 in. x 24 in Glazed P...
# 182795  Air King Quiet Zone 36 in. Convertible Range H...
# 212380  DreamLine Elegance 49-1/4 to 51-1/4 in. x 72 i...
# 44437   MARAZZI Montagna Wood Vintage Chic 6 in. x 24 ...
# 82006   Sharpie Assorted Colors Fine Point Oil-Based P...
# 198200     FolkArt 2-oz. Black Cherry Acrylic Craft Paint
# 24846   Everbilt 3/8 in. -16 tpi x 4 in. Stainless Ste...
# 204090  ClosetMaid Impressions 25 in. Chocolate Deluxe...
# 25449   Legrand adorne 1-Gang 1 Module Wall Plate - Mi...
# 175499     SUPCO 12 in. x 9 in. Replacement Ice Maker Kit
# 184498  Creative Accents Single Picture Frame Green 38...
# 158089  Rev-A-Shelf 18 in. H x 18 in. W x 25 in. D Dou...
# 25928   ROPPE Fawn 4 in. x 120 ft. x 0.080 in. Vinyl W...
# 43227   DEWALT 20-Volt Max Lithium-Ion Cordless Combo ...
# 188869  Flowe Mediterranean Bronze Ceiling Fan Replace...
# 66372   Vigoro 4.2 lb. Evergreen and Holly Fertilizer ...
# 127455  Rion Grand Gardener Clear 8 ft. x 12 ft. Green...
# 168864            Barton Kramer Sliding Glass Door Handle
# 135629  Starlite Garden Crater White Die Cast Aluminum...
# 152473  Prime-Line Die Cast Sliding Door Cylinder Lock...
# 188456  Milwaukee Large Black M12 Lithium-Ion Cordless...
# 183894    Ryobi 12-Volt 3/8 in. Cordless Drill/Driver Kit
# 127602    Field Controls Power Vent 4 in. Outside Mounted
# 189014  American Standard Cadet Slow Close EverClean R...
#
#                                                     descr  \
# id
# 120624  whether boil pasta, make batch chili cook grai...
# 156918  7114-1 one-sect round rung 14 ft. straight lad...
# 69679   enhanc home romano boxwood spiral topiari tree...
# 136808  earthquak 6015v rear tine rototil deliv ultim ...
# 9508    sure comfort 40 gal. natur gas tall water heat...
# 85851   oakland live 26 in. metal grape tabl plant sta...
# 104722  repair leaki faucet easi inexpens altern repla...
# 176724  cornerston collect quality, incandesc vaniti e...
# 17236   ortho home defens max 1.33 gal. ready-to-us pe...
# 198022  bowl planter perfect patio decks. avail variet...
# 211891  ce tech hdc806nuwh surg protector ideal home/o...
# 93622   daylili vigor perenni requir littl care garden...
# 146582  tuscani coast 2-light exterior post lamp weath...
# 45248   mini red carnat grown environment greenhouses,...
# 215764  electrolux iq touch freestand electr rang new ...
# 188479  found 1953, laura ashley becom quintessenti en...
# 742     sr 100 half mask air purifi respir intend use ...
# 137108  viagrow strawberri planter allow grow strawber...
# 31303   larg famili dinner snack time solutions, 5.0 c...
# 198125  garden bar stool add uniqu style bar home whet...
# 3909    osb attic deck 24 in. x 48 in. attic deck 8 sq...
# 134157  0- 10-volt wall dimmer switch lithonia light 2...
# 143520  authent tin ceil tile produc use origin sand-c...
# 108146  naturalight 22w energi save circular tube. nat...
# 69064   want air movement without noise. got it. big a...
# 181466  sophist serene, surfac embodi best modern desi...
# 108375  bbrag (base board return grille) durabl steel ...
# 159057  sharkbit pex barb x femal npt adapt easi insta...
# 76474   philip 50-watt mr16 landscap indoor flood dimm...
# 58046   sharkbit 1/2 in. push-fit x 3/8 in. o.d. compr...
# ...                                                   ...
# 155170  7.5 cu. ft. electr dryer steam white featur nu...
# 80130   welcom best mirror slider door money buy. bi-f...
# 104919  rheem ecosens eco150xln3 outdoor natur gas tan...
# 80381   cedar grain never look good. fence, buy stain ...
# 174147  economi putti knife set includ 2 in., 4 in. 6 ...
# 158951  behr marque exterior satin enamel stain-block ...
# 16751   montagna saddl hand scrape wood plank porcelai...
# 182795  quiet zone seri cabinet rang hood featur low p...
# 212380  eleg pivot shower door combin modern frameless...
# 44437   montagna vintag chic marazzi 6 in. x 24 in. po...
# 82006   sharpi oil-bas paint marker featur fine point ...
# 198200  folkart acryl paint choic decor painter two de...
# 24846   carriag bolt featur smooth, round head appeara...
# 204090  closetmaid impress closet kit featur premium, ...
# 25449   re-model look like million bucks. deserv bette...
# 175499  lukewarm lemonad longer part life. rim469 icem...
# 184498  natur harvest coir fiber hand woven tradit loo...
# 158089  keep kitchen trash contain sight, easili acces...
# 25928   low cost good look highlight ropp type tv ther...
# 43227   premium 5-tool dewalt combo kit pack valu vers...
# 188869  sandston glass bowl replac part flow 52 in. me...
# 66372   use vigoro tree spike lush foliage, brilliant ...
# 127455  grand garden clear featur 2 kind virtual unbre...
# 168864  barton kramer slide glass door handl design fi...
# 135629  classic tabletop patio torch great way enjoy u...
# 152473  slide patio door cylind lock adapt construct d...
# 188456  milwauke m12 heat ripstop vest: power m12 redl...
# 183894  ryobi 12-volt 3/8 in. cordless drill/driv kit ...
# 127602  patent swg combo-v power venter etl cetl list ...
# 189014  cadet round univers seat featur slow close hin...
#
#                                                orig_descr  \
# id
# 120624  Whether you're boiling pasta, making a batch o...
# 156918  The 7114-1 one-section round rung 14 ft. Strai...
# 69679   Enhance your home with a Romano Boxwood Spiral...
# 136808  The Earthquake 6015V rear tine rototiller deli...
# 9508    The Sure Comfort 40 Gal. Natural Gas Tall Wate...
# 85851   The Oakland Living 26 in. Metal Grape Table Pl...
# 104722  Repairing a leaky faucet is an easy and inexpe...
# 176724  The cornerstone of this collection is quality,...
# 17236   The Ortho Home Defense Max 1.33 Gal. Ready-to-...
# 198022  These bowl planters are perfect for patios and...
# 211891  The CE TECH HDC806NUWH Surge Protector is idea...
# 93622   Daylilies are vigorous perennial that require ...
# 146582  Tuscany Coast 2-Light Exterior Post Lamp In We...
# 45248   Mini Red carnations are grown in environmental...
# 215764  The Electrolux IQ Touch Freestanding Electric ...
# 188479  Founded in 1953, Laura Ashley has become a qui...
# 742     The SR 100 half mask Air Purifying Respirator ...
# 137108  The Viagrow Strawberry Planter allows you to g...
# 31303   From large family dinners to snack time soluti...
# 198125  Our Garden Bar Stool adds unique style to any ...
# 3909    The OSB Attic Decking 24 in. x 48 in. Attic De...
# 134157  The 0- to 10-Volt Wall Dimmer Switch for the L...
# 143520  These authentic tin ceiling tiles are produced...
# 108146  Naturalight 22W energy saving circular tube. N...
# 69064   Want air movement without noise. You've got it...
# 181466  Sophisticated and serene, Surface embodies the...
# 108375  BBRAG (Base Board Return Grille) is out of a d...
# 159057  The SharkBite PEX Barb x Female NPT Adapter is...
# 76474   Philips 50-Watt MR16 Landscape and Indoor Floo...
# 58046   The SharkBite 1/2 in. Push-Fit x 3/8 in. O.D. ...
# ...                                                   ...
# 155170  This 7.5 cu. ft. Electric Dryer with Steam in ...
# 80130   Welcome to the best mirror slider doors money ...
# 104919  The Rheem EcoSense ECO150XLN3 Outdoor Natural ...
# 80381   Cedar grain never looked so good. With our fen...
# 174147  The Economy Putty Knife Set includes 2 in., 4 ...
# 158951  BEHR MARQUEE Exterior Satin Enamel is a stain-...
# 16751   Montagna Saddle is a hand scraped wood plank o...
# 182795  The Quiet Zone Series Under Cabinet Range Hood...
# 212380  The Elegance pivot shower door combines a mode...
# 44437   Montagna Vintage Chic by MARAZZI is a 6 in. x ...
# 82006   Sharpie's Oil-Based Paint Marker features a fi...
# 198200  FolkArt acrylic paints have been the choice of...
# 24846   The Carriage Bolt features a smooth, rounded h...
# 204090  The ClosetMaid Impressions Closet Kit features...
# 25449   Your re-model looks like a million bucks. It d...
# 175499  Lukewarm lemonade is no longer a part of your ...
# 184498  Naturally harvested coir fibers are hand woven...
# 158089  Keep your kitchen trash containers out of sigh...
# 25928   Low cost and good looks highlights ROPPE's Typ...
# 43227   This premium 5-tool DEWALT Combo Kit is packed...
# 188869  This sandstone glass bowl is a replacement par...
# 66372   Use VIGORO tree spikes for lush foliage, brill...
# 127455  The Grand Gardener Clear features 2 kinds of v...
# 168864  The Barton Kramer Sliding Glass Door Handle is...
# 135629  Our classic tabletop patio torches are a great...
# 152473  This sliding patio door cylinder lock adapter ...
# 188456  Milwaukee M12 Heated Ripstop Vest: Powered by ...
# 183894  Ryobi's 12-Volt 3/8 in. Cordless Drill/Driver ...
# 127602  Patented SWG or Combo-Vent Power Venter's are ...
# 189014  The Cadet round universal seat features a slow...
#
#         match_product_title  match_descr       ...         \
# id                                             ...
# 120624             1.000000     0.500000       ...
# 156918             0.666667     0.666667       ...
# 69679              1.000000     1.000000       ...
# 136808             1.000000     0.000000       ...
# 9508               0.500000     1.000000       ...
# 85851              1.000000     1.000000       ...
# 104722             0.500000     0.500000       ...
# 176724             1.000000     0.500000       ...
# 17236              0.500000     0.500000       ...
# 198022             1.000000     0.000000       ...
# 211891             0.666667     0.666667       ...
# 93622              1.000000     1.000000       ...
# 146582             0.500000     1.000000       ...
# 45248              1.000000     0.500000       ...
# 215764             0.666667     0.666667       ...
# 188479             1.000000     1.000000       ...
# 742                0.500000     1.000000       ...
# 137108             1.000000     1.000000       ...
# 31303              0.333333     0.333333       ...
# 198125             0.750000     0.500000       ...
# 3909               0.500000     0.500000       ...
# 134157             1.000000     1.000000       ...
# 143520             1.000000     0.000000       ...
# 108146             0.333333     1.000000       ...
# 69064              1.000000     1.000000       ...
# 181466             0.500000     0.500000       ...
# 108375             0.666667     0.666667       ...
# 159057             0.666667     0.333333       ...
# 76474              0.500000     1.000000       ...
# 58046              1.000000     1.000000       ...
# ...                     ...          ...       ...
# 155170             0.500000     0.250000       ...
# 80130              0.500000     0.750000       ...
# 104919             0.800000     0.800000       ...
# 80381              0.666667     0.000000       ...
# 174147             0.000000     0.000000       ...
# 158951             1.000000     0.000000       ...
# 16751              0.500000     0.500000       ...
# 182795             0.800000     0.400000       ...
# 212380             0.000000     0.000000       ...
# 44437              0.200000     0.400000       ...
# 82006              0.750000     0.500000       ...
# 198200             0.666667     0.000000       ...
# 24846              0.750000     0.500000       ...
# 204090             0.333333     0.333333       ...
# 25449              0.000000     0.000000       ...
# 175499             0.500000     0.500000       ...
# 184498             0.666667     0.000000       ...
# 158089             0.666667     0.666667       ...
# 25928              1.000000     0.666667       ...
# 43227              0.333333     0.666667       ...
# 188869             0.250000     0.250000       ...
# 66372              1.000000     1.000000       ...
# 127455             1.000000     0.000000       ...
# 168864             0.666667     0.666667       ...
# 135629             1.000000     1.000000       ...
# 152473             1.000000     1.000000       ...
# 188456             0.600000     0.800000       ...
# 183894             0.000000     0.500000       ...
# 127602             1.000000     1.000000       ...
# 189014             0.666667     0.333333       ...
#
#         complete_match_descr  match_pos_title  match_pos_descr  \
# id
# 120624                     0         1.000000         0.500000
# 156918                     0         1.000000         1.000000
# 69679                      1         1.000000         1.000000
# 136808                     0         1.000000         0.000000
# 9508                       0         0.500000         1.000000
# 85851                      0         1.000000         1.000000
# 104722                     0         0.500000         0.250000
# 176724                     0         0.500000         0.500000
# 17236                      0         0.500000         0.500000
# 198022                     0         1.000000         0.000000
# 211891                     0         0.333333         0.666667
# 93622                      0         0.500000         1.000000
# 146582                     0         0.500000         1.000000
# 45248                      0         1.000000         0.500000
# 215764                     0         0.666667         0.666667
# 188479                     0         0.666667         0.666667
# 742                        0         0.000000         0.500000
# 137108                     1         0.000000         1.000000
# 31303                      0         0.333333         0.333333
# 198125                     0         0.500000         0.500000
# 3909                       0         0.500000         0.500000
# 134157                     0         1.000000         1.000000
# 143520                     0         1.000000         0.000000
# 108146                     1         0.666667         1.000000
# 69064                      1         1.000000         1.000000
# 181466                     0         0.500000         0.500000
# 108375                     0         0.666667         0.666667
# 159057                     0         0.500000         0.250000
# 76474                      0         0.500000         1.000000
# 58046                      0         0.666667         0.666667
# ...                      ...              ...              ...
# 155170                     0         0.500000         0.250000
# 80130                      0         0.166667         0.500000
# 104919                     0         0.800000         0.600000
# 80381                      0         1.000000         0.333333
# 174147                     0         0.000000         0.000000
# 158951                     0         1.000000         0.000000
# 16751                      0         0.500000         0.500000
# 182795                     0         1.000000         0.250000
# 212380                     0         0.750000         1.000000
# 44437                      0         0.166667         0.333333
# 82006                      0         0.250000         0.250000
# 198200                     0         0.666667         0.000000
# 24846                      0         0.875000         0.500000
# 204090                     0         0.333333         0.333333
# 25449                      0         0.000000         0.000000
# 175499                     0         0.250000         0.500000
# 184498                     0         0.666667         0.000000
# 158089                     0         1.000000         1.000000
# 25928                      0         0.333333         0.333333
# 43227                      0         0.333333         0.666667
# 188869                     0         0.250000         0.250000
# 66372                      0         1.000000         0.500000
# 127455                     0         0.000000         0.000000
# 168864                     0         0.666667         0.666667
# 135629                     0         1.000000         1.000000
# 152473                     1         1.000000         1.000000
# 188456                     0         0.600000         0.800000
# 183894                     0         0.000000         0.000000
# 127602                     0         0.000000         0.500000
# 189014                     0         0.666667         0.333333
#
#                      brand  match_brand  prod_title_ind descr_ind  pred_diff  \
# id
# 120624                         0.000000        0.000000  0.440367   1.491619
# 156918                         0.000000        0.062500  0.064516   1.456519
# 69679                          0.000000        0.714286  0.092593   1.451396
# 136808                         0.000000        0.750000  1.000000   1.434772
# 9508          sure comfort     0.000000        0.769231  0.027778   1.400278
# 85851                          0.000000        0.555556  0.084746   1.395766
# 104722                         0.000000        0.833333  0.514286   1.355375
# 176724        green matter     0.083333        0.000000  0.109756   1.338270
# 17236                ortho     0.000000        0.818182  0.121951   1.320465
# 198022               alpin     0.200000        0.000000  1.000000   1.297985
# 211891                         0.000000        0.000000  0.000000   1.282397
# 93622                          0.000000        0.125000  0.515625   1.280023
# 146582                         0.000000        0.000000  0.000000   1.276214
# 45248                          0.000000        0.777778  0.712871   1.270660
# 215764          electrolux     0.100000        0.000000  0.000000   1.260593
# 188479        laura ashley     0.166667        0.000000  0.037037   1.260444
# 742       sundstrom safeti     0.000000        0.666667  0.026316   1.237926
# 137108                         0.000000        0.200000  0.015385   1.234521
# 31303                amana     0.000000        0.400000  0.050228   1.227410
# 198125  home decor collect     0.000000        0.727273  0.021739   1.224365
# 3909               unbrand     0.000000        0.750000  0.014925   1.222115
# 134157                         0.000000        0.166667  0.076923   1.221476
# 143520                         0.000000        0.000000  1.000000   1.220084
# 108146                         0.000000        0.777778  0.168421   1.217794
# 69064                          0.000000        0.000000  0.052632   1.216439
# 181466              ginger     0.000000        0.166667  0.050000   1.216342
# 108375                         0.000000        0.466667  0.018868   1.206617
# 159057            sharkbit     0.000000        0.800000  0.063830   1.203533
# 76474               philip     0.000000        0.500000  0.067961   1.203272
# 58046             sharkbit     0.000000        0.466667  0.031646   1.201439
# ...                    ...          ...             ...       ...        ...
# 155170                  ge     0.500000        0.000000  0.020101   0.000153
# 80130          impact plus     0.000000        0.833333  0.018868   0.000150
# 104919       rheem ecosens     0.000000        0.384615  0.017442   0.000145
# 80381                          0.000000        0.000000  1.000000   0.000141
# 174147             economi     0.000000        1.000000  1.000000   0.000140
# 158951                         0.000000        0.571429  1.000000   0.000139
# 16751              marazzi     0.000000        0.588235  0.276471   0.000139
# 182795            air king     0.000000        0.400000  0.072727   0.000139
# 212380            dreamlin     0.000000        1.000000  1.000000   0.000138
# 44437              marazzi     0.000000        0.105263  0.067358   0.000136
# 82006               sharpi     0.000000        0.222222  0.047619   0.000133
# 198200             folkart     0.000000        0.285714  1.000000   0.000121
# 24846                          0.000000        0.071429  0.729167   0.000105
# 204090          closetmaid     0.000000        0.777778  0.021277   0.000105
# 25449        legrand adorn     0.000000        1.000000  1.000000   0.000088
# 175499                         0.000000        0.700000  0.762887   0.000084
# 184498      creativ accent     0.142857        0.000000  1.000000   0.000082
# 158089         rev-a-shelf     0.000000        0.600000  0.114583   0.000081
# 25928                 ropp     0.000000        0.666667  0.134328   0.000079
# 43227               dewalt     0.000000        0.500000  0.146739   0.000076
# 188869             unbrand     0.000000        0.500000  0.196429   0.000067
# 66372               vigoro     0.000000        0.375000  0.377049   0.000064
# 127455                         0.000000        0.900000  1.000000   0.000051
# 168864       barton kramer     0.000000        0.666667  0.078431   0.000048
# 135629                         0.000000        0.111111  0.032609   0.000047
# 152473                         0.000000        0.444444  0.050000   0.000037
# 188456            milwauke     0.000000        0.272727  0.009901   0.000028
# 183894               ryobi     0.000000        1.000000  0.396226   0.000027
# 127602                         0.000000        0.375000  0.303030   0.000026
# 189014   american standard     0.000000        0.750000  0.053571   0.000024
#
#         words_std_title  words_std_descr
# id
# 120624         0.333333         0.000000
# 156918         0.071429         0.030303
# 69679          0.000000         0.037037
# 136808         0.250000         0.000000
# 9508           0.153846         0.021978
# 85851          0.250000         0.034483
# 104722         0.142857         0.027027
# 176724         0.000000         0.009259
# 17236          0.100000         0.011628
# 198022         0.000000         0.000000
# 211891         0.111111         0.017699
# 93622          0.222222         0.030769
# 146582         0.111111         0.064516
# 45248          0.222222         0.009804
# 215764         0.058824         0.004132
# 188479         0.333333         0.037736
# 742            0.166667         0.017094
# 137108         0.200000         0.014925
# 31303          0.090909         0.004348
# 198125         0.200000         0.045455
# 3909           0.100000         0.015152
# 134157         0.333333         0.024096
# 143520         0.062500         0.000000
# 108146         0.181818         0.027778
# 69064          0.181818         0.014706
# 181466         0.166667         0.025641
# 108375         0.142857         0.017699
# 159057         0.200000         0.010204
# 76474          0.071429         0.017857
# 58046          0.052632         0.011494
# ...                 ...              ...
# 155170         0.250000         0.004673
# 80130          0.166667         0.009302
# 104919         0.307692         0.022222
# 80381          0.272727         0.000000
# 174147         0.000000         0.000000
# 158951         0.125000         0.000000
# 16751          0.133333         0.011628
# 182795         0.333333         0.018519
# 212380         0.125000         0.020979
# 44437          0.062500         0.010204
# 82006          0.272727         0.044444
# 198200         0.250000         0.000000
# 24846          0.538462         0.080000
# 204090         0.125000         0.010753
# 25449          0.000000         0.000000
# 175499         0.250000         0.030000
# 184498         0.166667         0.000000
# 158089         0.125000         0.027273
# 25928          0.083333         0.015152
# 43227          0.090909         0.010363
# 188869         0.125000         0.018868
# 66372          0.125000         0.008333
# 127455         0.125000         0.000000
# 168864         0.333333         0.036364
# 135629         0.222222         0.021978
# 152473         0.181818         0.047619
# 188456         0.250000         0.036697
# 183894         0.000000         0.008333
# 127602         0.285714         0.028169
# 189014         0.166667         0.000000
#
# [74067 rows x 23 columns]

# %%
model.best_estimator_.feature_importances_
# Out:
# array([317, 176, 158, 429, 248,  42, 178, 488, 316, 320, 221, 294, 242,
#        225, 224, 199, 215, 198, 214, 179, 235, 207, 189, 184, 233, 230,
#        206, 173, 169, 190, 206, 172, 198, 185, 199, 177, 212, 187, 167,
#        170, 203, 181, 178, 242, 219, 200, 167, 196, 200, 229, 205, 190,
#        197, 190, 212, 214, 194, 209, 179, 196, 226, 210, 188, 202, 235,
#        230, 254, 217, 181, 230, 233, 233, 229, 186, 212, 238, 207, 219,
#        194, 208, 252, 223, 257, 220, 246, 258, 235, 254, 205, 229, 232,
#        231, 185, 202, 187, 161, 171, 171, 201, 141, 152, 193, 145, 183,
#        130, 178, 174, 166, 163, 179, 148, 171, 179, 160, 178, 179, 169,
#        139, 184, 191, 158, 180, 163, 184, 156, 195, 172, 178, 192, 162,
#        190, 194, 174, 193, 174, 163, 162, 171, 205, 172, 185, 177, 165,
#        162, 172, 165, 170, 203, 192, 261, 187, 177, 224, 188, 168, 203,
#        174, 193, 249, 195, 192, 209, 186, 215, 212, 206, 195, 203, 205,
#        208, 221, 293, 166, 211, 167, 187, 182, 173, 214, 175, 158, 153,
#        195, 181, 191, 206, 190, 187, 184, 194, 194, 166, 186, 186, 188,
#        231, 211, 173, 191, 203, 173, 204, 172, 165, 177, 164, 172, 169,
#        189, 164, 211, 185, 219, 189, 179, 209, 160, 175, 199, 225, 172,
#        182, 212, 232, 212, 212, 195, 197, 185, 197, 232, 123,  82,  79,
#        185,  71,  60,  73,  66,  74,  74,  85,  83,  61,  79,  58,  68,
#         75,  76,  93, 129,  90,  98,  96,  67,  75,  73,  83,  76,  73,
#         84])

# %%
@np.vectorize
def word_match_diff(search_term, text):
    indexes = []
    search_term = search_term.split()
    text = text.split()
    if len(search_term) == 0:
        return 0
    for word in set(search_term):
        if word in text:
            indexes.append(text.index(word))
    if len(indexes) >= 2:
        return max(indexes) - min(indexes)
    elif len(indexes) == 1:
        return 1
    else:
        return 0

# %%
train = pd.read_csv('train_processed.csv', index_col=['id'])
train['search_term'] = train['search_term'].apply(str)
train['match_diff_title'] = word_match_diff(train['search_term'], train['product_title'])
train['match_diff_descr'] = word_match_diff(train['search_term'], train['descr'])

# %%
test = pd.read_csv('test_processed.csv', index_col=['id'])
test['search_term'] = test['search_term'].apply(str)
test['match_diff_title'] = word_match_diff(test['search_term'], test['product_title'])
test['match_diff_descr'] = word_match_diff(test['search_term'], test['descr'])

# %%
@np.vectorize
def word_match_count(search_term, text):
    count = 0
    search_term = search_term.split()
    text = text.split()
    if len(search_term) == 0:
        return 0
    for word in set(search_term):
        count += 1 if text.count(word) > 0 else 0
    return count / len(search_term)

# %%
train['match_product_title_orig'] = word_match_count(train['orig_search_term'].str.lower(),
                                                     train['orig_product_title'].str.lower())
train['match_descr_orig'] = word_match_count(train['orig_search_term'].str.lower(),
                                             train['orig_descr'].str.lower())

# %%
tree_cols = ['match_product_title', 'match_descr', 'len_search_term_words', 'len_search_term_letters',
             'match_pos_title', 'match_brand', 'match_pos_descr', 'prod_title_ind', 'descr_ind',
             'match_diff_title', 'match_diff_descr', 'match_product_title_orig', 'match_descr_orig']

use_cols = tree_cols + ['search_term', 'product_title', 'descr', 'brand']

clf = Pipeline([
    ('union', FeatureUnion(
                transformer_list = [
                    ('cst',  cust_regression_vals()),  
                    ('txt1', Pipeline([('s1', cust_txt_col(col='search_term')),
                                       ('tfidf1', TfidfVectorizer(stop_words='english')),
                                       ('tsvd1', TruncatedSVD(n_components=80))])),
                    ('txt2', Pipeline([('s2', cust_txt_col(col='product_title')),
                                       ('tfidf2', TfidfVectorizer(stop_words='english')),
                                       ('tsvd2', TruncatedSVD(n_components=80))])),
                    ('txt3', Pipeline([('s3', cust_txt_col(col='descr')),
                                       ('tfidf3', TfidfVectorizer(stop_words='english')),
                                       ('tsvd3', TruncatedSVD(n_components=60))])),
                    ('txt4', Pipeline([('s4', cust_txt_col(col='brand')),
                                       ('tfidf4', TfidfVectorizer(stop_words='english')),
                                       ('tsvd4', TruncatedSVD(n_components=30))]))
                    ]
            ))])

clf.fit(train[use_cols])
X_train = clf.transform(train[use_cols])

# %%
gbm = lgb.LGBMRegressor(learning_rate=0.05, n_estimators=700, num_leaves=60, colsample_bytree=0.7)
params = {
    'n_estimators': [700]
}
model = GridSearchCV(gbm, params,
                     cv=3,
                     n_jobs=1,
                     scoring='neg_mean_squared_error',
                     return_train_score=False,
                     verbose=2)
model.fit(X_train, y)
grid_df = pd.DataFrame(model.cv_results_)
grid_df.drop(columns=grid_df.columns[:3], inplace=True)
grid_df.sort_values(['rank_test_score'], inplace=True)
grid_df.head()
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] n_estimators=700 ................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................. n_estimators=700, total=  15.2s
# [CV] n_estimators=700 ................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.2s remaining:    0.0s
# [CV] ................................. n_estimators=700, total=  14.9s
# [CV] n_estimators=700 ................................................
# [CV] ................................. n_estimators=700, total=  14.7s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   44.8s finished
#    std_score_time param_n_estimators                 params  \
# 0        0.000891                700  {'n_estimators': 700}
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0          -0.214023          -0.204974          -0.233179        -0.217392
#
#    std_test_score  rank_test_score
# 0        0.011759                1

# %%
model.best_estimator_.feature_importances_
# Out:
# array([267, 126, 127, 385, 213,  46, 142, 349, 288,  63, 140, 151, 128,
#        293, 202, 193, 152, 151, 167, 159, 131, 156, 195, 186, 176, 164,
#        182, 179, 126, 160, 146, 179, 140, 155, 159, 188, 155, 149, 202,
#        191, 157, 155, 166, 144, 153, 196, 178, 176, 160, 183, 188, 201,
#        149, 154, 169, 149, 192, 154, 152, 189, 164, 162, 164, 172, 165,
#        127, 186, 171, 175, 176, 208, 181, 199, 162, 189, 214, 178, 180,
#        153, 168, 200, 188, 200, 190, 194, 202, 241, 208, 192, 207, 182,
#        177, 187, 222, 189, 168, 123, 166, 153, 146, 179, 133, 133, 190,
#        128, 139, 108, 126, 153, 126, 154, 158, 154, 157, 156, 147, 170,
#        159, 163, 127, 186, 166, 134, 183, 151, 153, 141, 157, 164, 143,
#        155, 159, 133, 172, 138, 148, 169, 165, 180, 164, 122, 147, 170,
#        136, 157, 174, 177, 155, 152, 172, 147, 159, 158, 168, 201, 214,
#        149, 182, 221, 154, 190, 156, 165, 198, 192, 158, 184, 156, 151,
#        178, 146, 183, 172, 256, 128, 133, 159, 162, 157, 162, 148, 116,
#        131, 133, 169, 151, 153, 171, 176, 152, 164, 163, 193, 143, 159,
#        164, 162, 174, 155, 166, 151, 150, 162, 175, 159, 137, 157, 177,
#        175, 136, 165, 154, 167, 160, 150, 159, 158, 147, 188, 166, 176,
#        153, 179, 177, 191, 182, 208, 149, 186, 152, 142, 168, 192, 125,
#         78,  65,  79, 103,  61,  82,  63,  59,  71,  77,  75,  70,  78,
#         74,  70,  72,  53,  75,  82,  93,  57,  69, 102,  55,  63,  59,
#         58,  78,  86])

# %%
test['match_product_title_orig'] = word_match_count(test['orig_search_term'].str.lower(),
                                                    test['orig_product_title'].str.lower())
test['match_descr_orig'] = word_match_count(test['orig_search_term'].str.lower(),
                                            test['orig_descr'].str.lower())
X_test = clf.transform(test[use_cols])

# %%
y_pred = model.predict(X_test)
y_pred[y_pred>3.] = 3.
y_pred[y_pred<1.] = 1.
results = pd.DataFrame({'id':test.index.values, 'relevance':y_pred})
results.to_csv('lgbm3.csv', header=True, index=False)

# %%
train['pred_diff'] = (train['relevance'] - model.predict(X_train)).abs()
train.sort_values(['pred_diff'], ascending=False)
# Out:
#         product_uid                                      product_title  \
# id
# 156918       160006  werner 14 ft. fiberglass round rung straight l...
# 69679        119478           romano 4 ft. boxwood spiral topiari tree
# 83392        124633             rubbermaid fasttrack garag cooler hook
# 136808       148897   earthquak 212cc tiller rear tine crt side shield
# 176724       172318  green matter 3-light mahogani bronz vaniti fixtur
# 120624       140844                  rachael ray 10 qt. cover stockpot
# 98819        130929  prime-lin slide door tandem roller assembly, 1...
# 17236        103041  ortho home defens max 1.33 gal. perimet indoor...
# 9508         101618  sure comfort 40 gal. tall 3 year 34,000 btu na...
# 188479       180470  laura ashley freya 3-light weather cognac vani...
# 198022       187480         alpin 15 in. larg red bowl plastic planter
# 211891       198538     ce tech 6 ft. 8-outlet usb rj45 surg protector
# 124807       142835  dewalt men&#39; x-larg camo 20-volt/12-volt ma...
# 199586       188671   ge choic alert wireless alarm system alarm siren
# 204530       192555        heath bird stop blue ceram wild bird feeder
# 207064       194599  home legend distress lennox hickori 3/8 in. th...
# 97371        130326   norcal potteri 6 in. terra cotta clay azalea pot
# 188875       180762  artifactori 8 ft. fix length 1 in. dia. metal ...
# 85851        125582   oakland live 26 in. metal grape tabl plant stand
# 108375       135102  speedi-grill 24 in. x 6 in. base board return ...
# 93622        128763  daylili grape magic bare root dormant plant (8...
# 137108       149071           viagrow strawberri planter vertic garden
# 82256        124201              klein tool powerlin util knife holder
# 11984        102095  tire scienc 4 in. x 6 in. wheelbarrow tube sea...
# 34765        107893                     graco suction tube mainten kit
# 69064        119252  big ass fan 3600 144 in. yellow silver aluminu...
# 72456        120519  sticki pix remov reposition ultim wall sticker...
# 45248        111134  globalros red mini carnat (160 stems) includ f...
# 90155        127352       intec force/2 next generat insul blow machin
# 101979       132288  #2 southern yellow pine pressure-tr timber (co...
# ...             ...                                                ...
# 79848        123280  hampton bay san marino 36 in. brush steel ceil...
# 210753       197598  artist weaver anderson beig 7 ft. 3 in. x 7 ft...
# 48889        112334  pergo xp kingston cherri 10 mm thick x 4-7/8 i...
# 135134       148049  eleg home fashion wilshir 20 in. w wall cabine...
# 132346       146612      auburn 5 ft. cherri distress cap-shelf mantel
# 68828        119178  uniqu home design 36 in. x 80 in. ultim white ...
# 7057         101202                 hdx nailer kit canva bag (3-piece)
# 2062         100370  master mark lifetim profession 40 ft. recycl p...
# 214643       200824        black+deck wire wheel starter kit (4-piece)
# 97021        130173  hampton bay black tropic blossom tuft outdoor ...
# 151256       156766  1-3/4 in. x 11-7/8 in. x 20 ft. southern pine ...
# 185007       178012  stanley-n hardwar 6 in. satin brass heavi barr...
# 55898        114691      hampton bay 2-light oil rub bronz flush mount
# 25477        105150   weber porcelain enamel steel flavor bar (5-pack)
# 194611       184913  ralph lauren 13 in. x 19 in. #rr130 chalk rive...
# 50877        113034  hampton bay georgian 1 duplex outlet plate - a...
# 144400       152968  cooper wire devic commerci grade 15 amp 3-way ...
# 188312       180355  henri 356 4 gal. multi-purpos sheet vinyl carp...
# 149800       155918         cramik enterpris 3/8 in. galvan ceil plate
# 70608        119832  fasad 24 in. x 18 in. ring pvc decor backsplas...
# 102074       132328  wen 9.6-volt variabl speed cordless rotari too...
# 63141        117159  home decor collect 7 in. x 48 in. hand scrape ...
# 4663         100805  lithonia light 4 ft. white led flushmount wrap...
# 115943       138567  hous fara 7/8 in. x 4-1/8 in. x 8 ft. prime wh...
# 201289       190001  bel air light cabernet collect 1-light outdoor...
# 111271       136423  american standard trevi delux adjust bodi / si...
# 118810       139953  ideal steel tree stand artifici tree 6 ft. 8 f...
# 57847        115358  firex 120-volt hardwir inter connect smoke ala...
# 113936       137643  wiremold wmfb seri 1/2 in. 15 amp rectangular ...
# 146490       154109  pass &amp; seymour 15-amp 125-volt industrial-...
#
#                          search_term  relevance  \
# id
# 156918                  14 ft ladder       1.00
# 69679                   topiari tree       1.00
# 83392              rubbermaid cooler       1.33
# 136808                   side shield       1.00
# 176724                   bronz green       1.00
# 120624                   rachael ray       1.00
# 98819                    roller bear       1.00
# 17236                     ant killer       1.00
# 9508              hot water tank gas       1.00
# 188479            laura ashley light       1.33
# 198022                    alpin larg       1.00
# 211891                  ce tech ipad       1.00
# 124807           batteri charger kit       1.00
# 199586       batteryfor alarm system       1.00
# 204530                     bird stop       1.00
# 207064                         ennox       3.00
# 97371           terra cotta clay pot       1.33
# 188875         continent rod end cap       1.00
# 85851                    grape plant       1.00
# 108375               2.4 white board       1.00
# 93622                    grape plant       1.00
# 137108                    strawberri       1.00
# 82256                      util belt       1.00
# 11984          wheelbarrow tire tube       1.33
# 34765                  mainten paint       1.00
# 69064                        big ass       1.00
# 72456                        sticker       1.33
# 45248                      free ship       1.00
# 90155                           next       1.00
# 101979              4x4 lumber treat       1.00
# ...                              ...        ...
# 79848         hampton bay ashland 36       2.33
# 210753  indoor * outdoor rug 21 x 15       2.33
# 48889             pergo floor pl1669       2.33
# 135134            white bath cabinet       2.67
# 132346             fire place mantel       2.33
# 68828           riverera screen door       2.33
# 7057                   hdx 16ga nail       2.33
# 2062                  garden barrier       2.00
# 214643                    brush dril       2.00
# 97021          outdoor bench cushion       2.67
# 151256                         lamin       2.67
# 185007            stanley powermax 6       2.00
# 55898                            nan       1.33
# 25477             gas grill accesori       2.00
# 194611                    faun paint       2.00
# 50877       hampton bay outlet cover       2.67
# 144400            3 way toggl switch       2.67
# 188312       clear adhes vinyl sheet       2.33
# 149800                    ceil plate       2.67
# 70608              copper backsplash       2.67
# 102074                     9.6 bvolt       2.33
# 63141                    plank floor       2.67
# 4663                 led strip light       2.67
# 115943                     white mdf       2.67
# 201289                     light swu       2.00
# 111271                    side spray       2.67
# 118810      christma tree stand spin       2.33
# 57847                  alarm batteri       2.67
# 113936               floor box cover       2.67
# 146490                          pasc       2.00
#
#                        orig_search_term  \
# id
# 156918                     14 ft ladder
# 69679                      topiary tree
# 83392                 rubbermaid cooler
# 136808                     side shields
# 176724                     bronze green
# 120624                      rachael ray
# 98819                   roller bearings
# 17236                        ant killer
# 9508                 hot water tank gas
# 188479            laura ashley lighting
# 198022                     alpine large
# 211891                     ce tech ipad
# 124807        batterys and charger kits
# 199586          batteryfor alarm system
# 204530                       bird stops
# 207064                            ennox
# 97371             terra cotta clay pots
# 188875         continental rod end caps
# 85851                       grape plant
# 108375                  2.4 white board
# 93622                       grape plant
# 137108                     strawberries
# 82256                      utility belt
# 11984          wheelbarrow tire no tube
# 34765                 maintenance paint
# 69064                           big ass
# 72456                           sticker
# 45248                     free shipping
# 90155                              next
# 101979           4x4 lumber not treated
# ...                                 ...
# 79848            hampton bay ashland 36
# 210753   indoor * outdoor rug 21' x 15'
# 48889             pergo flooring pl1669
# 135134              white baths cabinet
# 132346                fire place mantel
# 68828             riverera screen doors
# 7057                     hdx 16ga nails
# 2062                     garden barrier
# 214643                    brushes drils
# 97021           outdoor  bench cushions
# 151256                        laminated
# 185007               stanley powermax 6
# 55898                                or
# 25477              gas grill accesories
# 194611                       faun paint
# 50877        hampton bays outlet covers
# 144400              3 WAY TOGGLE SWITCH
# 188312      clear adhesive vinyl sheets
# 149800                   ceiling plates
# 70608                 copper backsplash
# 102074                        9.6 bvolt
# 63141                    plank flooring
# 4663                   led strip lights
# 115943                        white MDF
# 201289                        light swu
# 111271                       side spray
# 118810  christmas tree stand that spins
# 57847                     alarm battery
# 113936                  floor box cover
# 146490                             pasc
#
#                                        orig_product_title  \
# id
# 156918  Werner 14 ft. Fiberglass Round Rung Straight L...
# 69679            Romano 4 ft. Boxwood Spiral Topiary Tree
# 83392             Rubbermaid FastTrack Garage Cooler Hook
# 136808  Earthquake 212cc Tiller Rear Tine CRT with Sid...
# 176724  Green Matters 3-Light Mahogany Bronze Vanity F...
# 120624                Rachael Ray 10 qt. Covered Stockpot
# 98819   Prime-Line Sliding Door Tandem Roller Assembly...
# 17236   Ortho Home Defense Max 1.33 Gal. Perimeter and...
# 9508    Sure Comfort 40 Gal. Tall 3 Year 34,000 BTU Na...
# 188479  Laura Ashley Freya 3-Light Weathered Cognac Va...
# 198022       Alpine 15 in. Large Red Bowl Plastic Planter
# 211891    CE TECH 6 ft. 8-Outlet USB RJ45 Surge Protector
# 124807  DEWALT Men&#39;s X-Large Camo 20-Volt/12-Volt ...
# 199586  GE Choice Alert Wireless Alarm System with Ala...
# 204530      Heath Bird Stop Blue Ceramic Wild Bird Feeder
# 207064  Home Legend Distressed Lennox Hickory 3/8 in. ...
# 97371    Norcal Pottery 6 in. Terra Cotta Clay Azalea Pot
# 188875  The Artifactory 8 ft. Fixed Length 1 in. Dia. ...
# 85851   Oakland Living 26 in. Metal Grape Table Plant ...
# 108375  SPEEDI-GRILLE 24 in. x 6 in. Base Board Return...
# 93622   Daylily Grape Magic Bare Root Dormant Plants (...
# 137108         Viagrow Strawberry Planter Vertical Garden
# 82256          Klein Tools PowerLine Utility Knife Holder
# 11984   Tire Science 4 in. x 6 in. Wheelbarrow Tube wi...
# 34765                  Graco Suction Tube Maintenance Kit
# 69064   Big Ass Fans 3600 144 in. Yellow and Silver Al...
# 72456   Sticky Pix Removable and Repositionable Ultima...
# 45248   Globalrose Red Mini Carnations (160 Stems) Inc...
# 90155   Intec FORCE/2 Next Generation Insulation Blowi...
# 101979  #2 Southern Yellow Pine Pressure-Treated Timbe...
# ...                                                   ...
# 79848   Hampton Bay San Marino 36 in. Brushed Steel Ce...
# 210753  Artistic Weavers Anderson Beige 7 ft. 3 in. x ...
# 48889   Pergo XP Kingston Cherry 10 mm Thick x 4-7/8 i...
# 135134  Elegant Home Fashions Wilshire 20 in. W Wall C...
# 132346  The Auburn 5 ft. Cherry Distressed Cap-Shelf M...
# 68828   Unique Home Designs 36 in. x 80 in. Ultimate W...
# 7057             HDX Nailer Kit with Canvas Bag (3-Piece)
# 2062    Master Mark Lifetime Professional 40 ft. Recyc...
# 214643      BLACK+DECKER Wire Wheel Starter Kit (4-Piece)
# 97021   Hampton Bay Black Tropical Blossom Tufted Outd...
# 151256  1-3/4 in. x 11-7/8 in. x 20 ft. Southern Pine ...
# 185007  Stanley-National Hardware 6 in. Satin Brass He...
# 55898   Hampton Bay 2-Light Oil Rubbed Bronze Flush Mount
# 25477   Weber Porcelain Enameled Steel Flavorizer Bars...
# 194611  Ralph Lauren 13 in. x 19 in. #RR130 Chalk Rive...
# 50877   Hampton Bay Georgian 1 Duplex Outlet Plate - A...
# 144400  Cooper Wiring Devices Commercial Grade 15 Amp ...
# 188312  Henry 356 4 Gal. Multi-Purpose Sheet Vinyl and...
# 149800  Cramik Enterprises 3/8 in. Galvanized Ceiling ...
# 70608   Fasade 24 in. x 18 in. Rings PVC Decorative Ba...
# 102074  WEN 9.6-Volt Variable Speed Cordless Rotary To...
# 63141   Home Decorators Collection 7 in. x 48 in. Hand...
# 4663    Lithonia Lighting 4 ft. White LED Flushmount W...
# 115943  House of Fara 7/8 in. x 4-1/8 in. x 8 ft. Prim...
# 201289  Bel Air Lighting Cabernet Collection 1-Light O...
# 111271  American Standard Trevi Deluxe Adjustable Body...
# 118810  Ideal Steel Tree Stand for Artificial Trees 6 ...
# 57847   FireX 120-Volt Hardwired Inter Connectable Smo...
# 113936  Wiremold WMFB Series 1/2 in. 15 Amp Rectangula...
# 146490  Pass &amp; Seymour 15-Amp 125-Volt Industrial-...
#
#                                                     descr  \
# id
# 156918  7114-1 one-sect round rung 14 ft. straight lad...
# 69679   enhanc home romano boxwood spiral topiari tree...
# 83392   part fasttrack system, cooler hook perfect sol...
# 136808  earthquak 6015v rear tine rototil deliv ultim ...
# 176724  cornerston collect quality, incandesc vaniti e...
# 120624  whether boil pasta, make batch chili cook grai...
# 98819   patio door roller construct steel tandem rolle...
# 17236   ortho home defens max 1.33 gal. ready-to-us pe...
# 9508    sure comfort 40 gal. natur gas tall water heat...
# 188479  found 1953, laura ashley becom quintessenti en...
# 198022  bowl planter perfect patio decks. avail variet...
# 211891  ce tech hdc806nuwh surg protector ideal home/o...
# 124807  dewalt x-larg true timber htc camo heat jacket...
# 199586  ge choic alert wireless alarm system alarm sir...
# 204530  bird stop blue ceram wild bird feeder featur b...
# 207064  78 in. length, hardwood veneer carpet reduc ov...
# 97371   6.75 in. terra cotta pot craft porous terra co...
# 188875  artifactori fix length draperi hardwar made di...
# 85851   oakland live 26 in. metal grape tabl plant sta...
# 108375  bbrag (base board return grille) durabl steel ...
# 93622   daylili vigor perenni requir littl care garden...
# 137108  viagrow strawberri planter allow grow strawber...
# 82256   store util knive small tool klein tool powerli...
# 11984   infus leak-stopper, tire scienc 4 in. x 6 in. ...
# 34765   heavy-duti suction tube set replac kit suction...
# 69064   want air movement without noise. got it. big a...
# 72456   sticki pix home decor think life verb captur j...
# 45248   mini red carnat grown environment greenhouses,...
# 90155   forc 2 insul blower want need larger, stronger...
# 101979  next project realli matters, choos right lumbe...
# ...                                                   ...
# 79848   hampton bay san marino 36 in. brush steel ceil...
# 210753  achiev sens timeless trend suit indoor outdoor...
# 48889   pergo xp kingston cherri offer ultra realist w...
# 135134  combin style storag bathroom wilshir wall cabi...
# 132346  first piec furnitur home. there noth warm welc...
# 68828   ultim metal slide patio screen door includ con...
# 7057    hdx 3-piec finish nailer kit allow flexibl com...
# 2062    made 100% recycl qualiti post consum hdpe plas...
# 214643  black+deck 4-piec wire wheel starter kit use r...
# 97021   give bench, loveseat sette invit refresh look ...
# 151256  bois lamin veneer lumber (lvl) product use mul...
# 185007  stanley-n hardwar lead manufactur hardwar cent...
# 55898   add classic style den, live room interior spac...
# 25477   marinades, glazes, sauc juic go wast ooz grill...
# 194611  ralph lauren specialti finish cornerston ralph...
# 50877   25 years, hampton bay deliv home decor essenti...
# 144400  cooper wire devic csb315stv-sp commerci grade ...
# 188312  henri 356 4 gal. multi-purpos sheet vinyl carp...
# 149800  cramik enterpris 3/8 in. galvan ceil plate mak...
# 70608   transform ordinari kitchen bathroom stylish sp...
# 102074  wen 9.6-volt cordless rotari tool set, a??ll p...
# 63141   hand scrape rustic hickori vinyl planks, 7 in....
# 4663    4 ft. integr led wraparound lithonia light mou...
# 115943  use hous fara 7/8 in. x 4-1/8 in. x 8 ft. prim...
# 201289  cornerston cabernet collect elegance, 1-light ...
# 111271  american standard - style work better. durable...
# 118810  fold tree stand artifici tree 6.5 ft. 8.5 ft. ...
# 57847   walter kidd hardwir smoke alarm (4-pack) alert...
# 113936  wiremold wmfb1drb rectangular in-floor mount o...
# 146490  pass & seymour/legrand 15-amp 125-volt industr...
#
#                                                orig_descr  \
# id
# 156918  The 7114-1 one-section round rung 14 ft. Strai...
# 69679   Enhance your home with a Romano Boxwood Spiral...
# 83392   Part of the FastTrack system, the Cooler Hook ...
# 136808  The Earthquake 6015V rear tine rototiller deli...
# 176724  The cornerstone of this collection is quality,...
# 120624  Whether you're boiling pasta, making a batch o...
# 98819   This patio door roller is constructed from ste...
# 17236   The Ortho Home Defense Max 1.33 Gal. Ready-to-...
# 9508    The Sure Comfort 40 Gal. Natural Gas Tall Wate...
# 188479  Founded in 1953, Laura Ashley has become a qui...
# 198022  These bowl planters are perfect for patios and...
# 211891  The CE TECH HDC806NUWH Surge Protector is idea...
# 124807  The DEWALT X-Large True Timber HTC Camo Heated...
# 199586  The GE Choice Alert Wireless Alarm System Alar...
# 204530  The Bird Stop Blue Ceramic Wild Bird Feeder fe...
# 207064  78 in. length, hardwood veneer carpet reducer ...
# 97371   The 6.75 in. Terra Cotta Pot is crafted with p...
# 188875  Artifactory Fixed Length Drapery Hardware made...
# 85851   The Oakland Living 26 in. Metal Grape Table Pl...
# 108375  BBRAG (Base Board Return Grille) is out of a d...
# 93622   Daylilies are vigorous perennial that require ...
# 137108  The Viagrow Strawberry Planter allows you to g...
# 82256   Store your utility knives or other small tools...
# 11984   Infused with leak-stopper, this Tire Science 4...
# 34765   The Heavy-Duty Suction Tube Set is a replaceme...
# 69064   Want air movement without noise. You've got it...
# 72456   With Sticky Pix Home Decor you can think of li...
# 45248   Mini Red carnations are grown in environmental...
# 90155   The Force 2 is the insulation blower you want ...
# 101979  When your next project really matters, choose ...
# ...                                                   ...
# 79848   The Hampton Bay San Marino 36 in. Brushed Stee...
# 210753  Achieving a sense of timeless trend that will ...
# 48889   Pergo XP Kingston Cherry offers an ultra reali...
# 135134  Combine style and storage in your bathroom wit...
# 132346  It's the first piece of furniture in any home....
# 68828   The Ultimate Metal sliding patio screen door i...
# 7057    The HDX 3-Piece Finish Nailer Kit allows you t...
# 2062    Made from 100% recycled quality post consumer ...
# 214643  The BLACK+DECKER 4-Piece Wire Wheel Starter Ki...
# 97021   Give your bench, loveseat or settee an invitin...
# 151256  Boises Laminated veneer lumber (LVL) is a prod...
# 185007  Stanley-National Hardware has been a leading m...
# 55898   Add classic style to your den, living room or ...
# 25477   Marinades, glazes, sauces and juices won't go ...
# 194611  Ralph Lauren Specialty Finishes are the corner...
# 50877   For over 25 years, Hampton Bay has delivered h...
# 144400  The Cooper Wiring Devices CSB315STV-SP Commerc...
# 188312  Henry 356 4 Gal. Multi-Purpose Sheet Vinyl and...
# 149800  The CRAMIK ENTERPRISES 3/8 in. Galvanized Ceil...
# 70608   Transform an ordinary kitchen or bathroom into...
# 102074  WEN 9.6-Volt Cordless Rotary Tool Set, you a??...
# 63141   Hand Scraped Rustic Hickory Vinyl Planks, 7 in...
# 4663    The 4 ft. Integrated LED Wraparound from Litho...
# 115943  Use the House of Fara 7/8 in. x 4-1/8 in. x 8 ...
# 201289  The cornerstone of the Cabernet Collection is ...
# 111271  American Standard - Style That Works Better. D...
# 118810  Folding tree stand for artificial trees 6.5 ft...
# 57847   The Walter Kidde Hardwire Smoke Alarms (4-Pack...
# 113936  The Wiremold WMFB1DRB is a rectangular in-floo...
# 146490  The Pass & Seymour/Legrand 15-Amp 125-Volt Ind...
#
#         match_product_title  match_descr        ...         match_pos_descr  \
# id                                              ...
# 156918             0.666667     0.666667        ...                1.000000
# 69679              1.000000     1.000000        ...                1.000000
# 83392              1.000000     0.500000        ...                0.500000
# 136808             1.000000     0.000000        ...                0.000000
# 176724             1.000000     0.500000        ...                0.500000
# 120624             1.000000     0.500000        ...                0.500000
# 98819              0.500000     1.000000        ...                0.500000
# 17236              0.500000     0.500000        ...                0.500000
# 9508               0.500000     1.000000        ...                1.000000
# 188479             1.000000     1.000000        ...                0.666667
# 198022             1.000000     0.000000        ...                0.000000
# 211891             0.666667     0.666667        ...                0.666667
# 124807             1.000000     0.333333        ...                0.250000
# 199586             0.666667     0.666667        ...                0.666667
# 204530             1.000000     1.000000        ...                0.500000
# 207064             0.000000     0.000000        ...                0.000000
# 97371              1.000000     1.000000        ...                0.500000
# 188875             0.750000     0.750000        ...                0.000000
# 85851              1.000000     1.000000        ...                1.000000
# 108375             0.666667     0.666667        ...                0.666667
# 93622              1.000000     1.000000        ...                1.000000
# 137108             1.000000     1.000000        ...                1.000000
# 82256              0.500000     1.000000        ...                1.000000
# 11984              1.000000     1.000000        ...                0.750000
# 34765              0.500000     0.500000        ...                0.500000
# 69064              1.000000     1.000000        ...                1.000000
# 72456              1.000000     0.000000        ...                0.000000
# 45248              1.000000     0.500000        ...                0.500000
# 90155              1.000000     0.000000        ...                0.000000
# 101979             0.000000     0.333333        ...                0.166667
# ...                     ...          ...        ...                     ...
# 79848              0.750000     0.750000        ...                0.500000
# 210753             0.285714     0.428571        ...                0.000000
# 48889              0.666667     0.666667        ...                0.666667
# 135134             0.666667     0.666667        ...                0.666667
# 132346             0.333333     0.333333        ...                0.333333
# 68828              0.666667     0.666667        ...                0.333333
# 7057               0.333333     0.666667        ...                0.333333
# 2062               0.000000     0.000000        ...                0.000000
# 214643             0.000000     0.500000        ...                0.000000
# 97021              1.000000     1.000000        ...                0.666667
# 151256             1.000000     1.000000        ...                0.000000
# 185007             0.333333     0.000000        ...                0.000000
# 55898              0.000000     0.000000        ...                1.000000
# 25477              0.000000     0.666667        ...                0.666667
# 194611             0.500000     0.000000        ...                0.000000
# 50877              0.750000     0.750000        ...                0.250000
# 144400             0.500000     0.500000        ...                1.000000
# 188312             0.750000     0.750000        ...                0.500000
# 149800             1.000000     1.000000        ...                0.500000
# 70608              1.000000     0.500000        ...                0.500000
# 102074             0.000000     0.000000        ...                0.500000
# 63141              1.000000     0.500000        ...                0.000000
# 4663               0.666667     0.666667        ...                0.333333
# 115943             1.000000     1.000000        ...                1.000000
# 201289             0.500000     0.000000        ...                0.000000
# 111271             1.000000     0.000000        ...                0.000000
# 118810             0.500000     0.500000        ...                0.000000
# 57847              1.000000     1.000000        ...                1.000000
# 113936             1.000000     0.666667        ...                0.666667
# 146490             0.000000     0.000000        ...                0.000000
#
#                      brand  match_brand  prod_title_ind  descr_ind  pred_diff  \
# id
# 156918                 NaN     0.000000        0.062500   0.064516   1.469848
# 69679                  NaN     0.000000        0.714286   0.092593   1.374321
# 83392                  NaN     0.000000        0.000000   0.051724   1.348056
# 136808                 NaN     0.000000        0.750000   1.000000   1.343553
# 176724        green matter     0.083333        0.000000   0.109756   1.318144
# 120624                 NaN     0.000000        0.000000   0.440367   1.297241
# 98819                  NaN     0.000000        0.307692   0.057143   1.294766
# 17236                ortho     0.000000        0.818182   0.121951   1.287250
# 9508          sure comfort     0.000000        0.769231   0.027778   1.282277
# 188479        laura ashley     0.166667        0.000000   0.037037   1.276491
# 198022               alpin     0.200000        0.000000   1.000000   1.242072
# 211891                 NaN     0.000000        0.000000   0.000000   1.231245
# 124807                 NaN     0.000000        0.571429   0.447368   1.209588
# 199586                  ge     0.000000        0.500000   0.020513   1.207556
# 204530               heath     0.000000        0.125000   0.000000   1.203687
# 207064         home legend     0.000000        1.000000   1.000000   1.198227
# 97371                  NaN     0.000000        0.444444   0.035088   1.196727
# 188875         artifactori     0.000000        0.588235   0.318841   1.190889
# 85851                  NaN     0.000000        0.555556   0.084746   1.189934
# 108375                 NaN     0.000000        0.466667   0.018868   1.189083
# 93622                  NaN     0.000000        0.125000   0.515625   1.188548
# 137108                 NaN     0.000000        0.200000   0.015385   1.185286
# 82256           klein tool     0.000000        0.500000   0.019231   1.184849
# 11984          tire scienc     0.090909        0.000000   0.036364   1.184223
# 34765                  NaN     0.000000        0.600000   0.534483   1.179036
# 69064                  NaN     0.000000        0.000000   0.052632   1.178909
# 72456                  NaN     0.000000        0.545455   1.000000   1.170816
# 45248                  NaN     0.000000        0.777778   0.712871   1.169641
# 90155                  NaN     0.000000        0.285714   1.000000   1.169383
# 101979             unbrand     0.000000        1.000000   0.115385   1.167939
# ...                    ...          ...             ...        ...        ...
# 79848          hampton bay     0.181818        0.000000   0.000000   0.000182
# 210753                 NaN     0.000000        0.470588   0.043103   0.000178
# 48889                pergo     0.200000        0.000000   0.000000   0.000178
# 135134   eleg home fashion     0.000000        0.800000   0.051724   0.000165
# 132346                 NaN     0.000000        0.857143   0.047120   0.000159
# 68828    uniqu home design     0.000000        0.866667   0.048193   0.000154
# 7057                   hdx     0.333333        0.000000   0.000000   0.000142
# 2062           master mark     0.000000        1.000000   1.000000   0.000132
# 214643          black+deck     0.000000        1.000000   0.543478   0.000122
# 97021          hampton bay     0.000000        0.666667   0.122222   0.000118
# 151256             unbrand     0.000000        0.769231   0.012500   0.000117
# 185007   stanley-n hardwar     0.000000        0.200000   1.000000   0.000113
# 55898          hampton bay     0.000000        1.000000   1.000000   0.000106
# 25477                weber     0.000000        1.000000   0.106061   0.000101
# 194611        ralph lauren     0.000000        0.800000   1.000000   0.000095
# 50877          hampton bay     0.181818        0.000000   0.054054   0.000093
# 144400                 NaN     0.000000        0.533333   0.069565   0.000084
# 188312               henri     0.000000        0.555556   0.062500   0.000061
# 149800    cramik enterpris     0.000000        0.714286   0.131579   0.000055
# 70608                  NaN     0.000000        0.692308   0.046243   0.000051
# 102074                 NaN     0.000000        1.000000   1.000000   0.000038
# 63141   home decor collect     0.000000        0.650000   0.224490   0.000038
# 4663        lithonia light     0.071429        0.111111   0.069767   0.000030
# 115943                 NaN     0.000000        0.733333   0.230769   0.000029
# 201289       bel air light     0.076923        0.142857   1.000000   0.000022
# 111271                 NaN     0.000000        0.636364   1.000000   0.000021
# 118810               ideal     0.000000        0.181818   0.027027   0.000018
# 57847                firex     0.000000        0.600000   0.041237   0.000017
# 113936            wiremold     0.000000        0.500000   0.462963   0.000015
# 146490      pass & seymour     0.000000        1.000000   1.000000   0.000006
#
#        match_diff_title  match_diff_descr  match_product_title_orig  \
# id
# 156918                6                 3                  0.666667
# 69679                 1                 8                  1.000000
# 83392                 3                 1                  1.000000
# 136808                1                 0                  1.000000
# 176724                4                 1                  1.000000
# 120624                1                 1                  1.000000
# 98819                 1                24                  0.500000
# 17236                 1                 1                  0.500000
# 9508                  1                42                  0.500000
# 188479                7                23                  0.666667
# 198022                3                 0                  1.000000
# 211891                1                 1                  0.666667
# 124807                5                 1                  0.500000
# 199586                1                 1                  0.666667
# 204530                1                 1                  0.500000
# 207064                0                 0                  0.000000
# 97371                 4                25                  0.750000
# 188875                4                 7                  0.750000
# 85851                 2                 2                  1.000000
# 108375                7                14                  0.666667
# 93622                 5                 5                  0.500000
# 137108                1                 1                  0.000000
# 82256                 1                23                  0.500000
# 11984                 8                 9                  0.750000
# 34765                 1                 1                  0.500000
# 69064                 1                 1                  1.000000
# 72456                 1                 0                  1.000000
# 45248                 1                 1                  1.000000
# 90155                 1                 0                  1.000000
# 101979                0                 1                  0.000000
# ...                 ...               ...                       ...
# 79848                 4                 4                  0.750000
# 210753                8                31                  0.285714
# 48889                16                89                  0.666667
# 135134                1                 1                  0.666667
# 132346                1                 1                  0.333333
# 68828                 1                 1                  0.333333
# 7057                  1               125                  0.333333
# 2062                  0                 0                  0.000000
# 214643                0                 1                  0.000000
# 97021                 2                 2                  0.666667
# 151256                1                 1                  1.000000
# 185007                1                 0                  0.333333
# 55898                 0                 0                  0.000000
# 25477                 0                57                  0.000000
# 194611                1                 0                  0.500000
# 50877                 5                12                  0.500000
# 144400                1                 1                  0.500000
# 188312                3                 3                  0.500000
# 149800                1                 1                  0.500000
# 70608                 3                 1                  1.000000
# 102074                0                 0                  0.000000
# 63141                 1                 1                  1.000000
# 4663                  4                 3                  0.333333
# 115943                1                 1                  1.000000
# 201289                1                 0                  0.000000
# 111271                1                 0                  1.000000
# 118810                1                 1                  0.400000
# 57847                 1                19                  1.000000
# 113936                5                 5                  1.000000
# 146490                0                 0                  0.000000
#
#         match_descr_orig
# id
# 156918          0.666667
# 69679           1.000000
# 83392           0.500000
# 136808          0.000000
# 176724          0.500000
# 120624          0.000000
# 98819           0.500000
# 17236           0.500000
# 9508            1.000000
# 188479          0.666667
# 198022          0.000000
# 211891          0.666667
# 124807          0.250000
# 199586          0.666667
# 204530          0.500000
# 207064          0.000000
# 97371           0.750000
# 188875          0.500000
# 85851           1.000000
# 108375          0.666667
# 93622           1.000000
# 137108          1.000000
# 82256           1.000000
# 11984           0.750000
# 34765           0.500000
# 69064           1.000000
# 72456           0.000000
# 45248           0.500000
# 90155           0.000000
# 101979          0.250000
# ...                  ...
# 79848           0.750000
# 210753          0.428571
# 48889           0.666667
# 135134          0.666667
# 132346          0.333333
# 68828           0.333333
# 7057            0.333333
# 2062            0.000000
# 214643          0.000000
# 97021           0.666667
# 151256          1.000000
# 185007          0.000000
# 55898           1.000000
# 25477           0.666667
# 194611          0.000000
# 50877           0.250000
# 144400          0.500000
# 188312          0.500000
# 149800          0.500000
# 70608           0.500000
# 102074          0.000000
# 63141           0.000000
# 4663            0.333333
# 115943          1.000000
# 201289          0.000000
# 111271          0.000000
# 118810          0.400000
# 57847           1.000000
# 113936          0.666667
# 146490          0.000000
#
# [74067 rows x 25 columns]
